# %% [markdown]
# # 2. HTML-Code verarbeiten mit der BeautifulSoup-Bibliothek

# %% [markdown]
# Wie bereits erwähnt, besteht Webscraping im Wesentlichen aus zwei Schritten:
# 1. Webseite aufrufen und den HTML-Code der Seite herunterladen
# 2. gesuchte Informationen aus dem HTML-Code auslesen.
#
# Für den zweiten Schritt wird in Python häufig die [*BeautifulSoup*](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)-Bibliothek verwendet. Mit *BeautifulSoup* wird [HTML](https://de.wikipedia.org/wiki/Hypertext_Markup_Language)-Code (der Quellcode der jeweiligen Webseite) in Objekte umgewandelt, die es erlauben, durch diesen Code zu navigieren, in diesem Code nach spezifischen Inhalten zu suchen und diese Inhalte zu extrahieren. Diesen Prozess, bei dem der Quellcode in seine strukturellen Einzelteile zerlegt und analysiert wird, nennt man auch [*Parsen*](https://de.wikipedia.org/wiki/Parser).

# %% [markdown]
# ## Installieren und importieren der *BeautifulSoup*-Bibliothek

# %% [markdown]
# Die Python-Bibliothek *BeautifulSoup* muss vor der ersten Verwendung installiert werden. Die Installation geht folgendermaßen:

# %%
! python -m pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\programdata\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.2.1)

# %% [markdown]
# Mit `! python -m pip install --upgrade bs4` ist es möglich, die *BeautifulSoup*-Bibliothek zu aktualisieren.<br>
# Beide Codezeilen setzen voraus, dass das sowohl Python als auch das Paketverwaltungsprogramm *pip* installiert sind. Beides kann wie folgt überprüft werden:

# %%
! python --version
! python -m pip --version
# Out:
# Python 3.8.8
# pip 21.0.1 from C:\ProgramData\Anaconda3\lib\site-packages\pip (python 3.8)

# %% [markdown]
# Da *BeautifulSoup* eine Bibliothek ist und nicht zu den Kernbefehlen von Python gehört, muss sie erst *importiert* werden, bevor man sie verwenden kann:

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# Im vorherigen Notebook haben wir mit Hilfe der *requests*-Bibliothek den HTML-Quellcode der Hamburg-Seite der deutschen Wikipedia aus dem Internet geladen und in die Variable *html* gespeichert. Diese Variable haben wir dann mit Hilfe eines [*magic commands*](https://ipython.readthedocs.io/en/stable/interactive/magics.html) in die programmeigene IPython-Datenbank gespeichert, damit die Variable über verschiedene Notebooks hinweg verfügbar ist.<br>
# Mit folgendem *magic command* können wir die Variable wieder für dieses Notebook aus der IPython-Datenbank abrufen:

# %%
# %store -r html

# %% [markdown]
# ## HTML-Quellcode der Webseite an BeautifulSoup übergeben

# %% [markdown]
# Diese Variable wird nun als Input an *BeautifulSoup* übergeben und von *BeautifulSoup* in ein *BeautifulSoup*-Objekt umgewandelt. Dieses *BeautifulSoup*-Objekt wird dann der Variable *bs* zugewiesen:

# %%
bs = BeautifulSoup(html)

# %%
print(type(bs)) # Abfrage: Was für einen Datentyp liefert uns BeautifulSoup eigentlich? Was befindet sich in bs? Antwort: ein BeautifulSoup-Objekt!
# Out:
# <class 'bs4.BeautifulSoup'>

# %% [markdown]
# Mit Hilfe des *BeautifulSoup*-Objekts ist es nun möglich, die gesuchten Informationen aus dem HTML-Code (bzw. der HTML-Suppe, deshalb der Name *BeautifulSoup*) zu extrahieren. Um dieses Vorgehen zu verstehen, ist es hilfreich, rudimentäre Kenntnisse von HTML und [CSS](https://de.wikipedia.org/wiki/Cascading_Style_Sheets) zu haben.

# %% [markdown]
# ## Aufbau von HTML

# %% [markdown]
# HTML ist der Standard zur Erstellung von Webseiten. Immer wenn man im Internet eine Webseite aufruft, interpretiert der Webbrowser den "dahinterliegenden" HTML-Quellcode und stellt die Webseite entsprechend dar.<br>
# Während HTML die *Struktur* einer Webseite definiert (HTML ist eine [Auszeichnungssprache](https://de.wikipedia.org/wiki/Auszeichnungssprache)), wird mit CSS die *Gestaltung* der Webseite festgelegt (CSS ist eine [Stylesheetsprache](https://de.wikipedia.org/wiki/Stylesheet-Sprache)). Tutorials zu HTML und CSS findet man zahlreich im Netz, wie etwa diese hier:
# + [knappes HTML-Tutorial](https://htmldog.com/guides/html/) oder [ausführlicheres HTML-Tutorial](https://www.w3schools.com/html/default.asp)
# + [knappes CSS-Tutorial](https://htmldog.com/guides/css/) oder [ausführlicheres CSS-Tutorial](https://www.w3schools.com/css/default.asp)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tipp:</b> Im Webbrowser kann man sich den HTLM-Quellcode jeder Webseite folgendermaßen anzeigen lassen:
# <ol>
#   <li>Rechtsklick in einen freien Bereich der jeweiligen Webseite</li>
#   <li>"Seitenquelltext anzeigen" (oder ähnliches - je nach Browser) aus dem Kontextmenü auswählen.</li>
# </ol>
# </div>

# %% [markdown]
# HTML beschreibt die Struktur einer Webseite mit Hilfe sog. [*HTML-Elemente*](https://en.wikipedia.org/wiki/HTML_element). Diese Elemente bestehen in der Regel aus einem *Start-Tag*, einem *Inhalt* und einem *End-Tag*. Innerhalb des Start-Tags können darüber hinaus [*Attribute*](https://de.wikipedia.org/wiki/Attribut_(Auszeichnungssprache) über Attributname und Attributwert angegeben werden, die Eigenschaften des HTML-Elements beschreiben. Ein HTML-Element hat somit folgende Komponenten:

# %% [markdown]
# ![HTML-Element](https://wikimedia.org/api/rest_v1/media/math/render/svg/37506127f0730d9b6035530f46c706af4e2319d4)

# %% [markdown]
# Beispiele für HTML-Elemente:

# %% [markdown]
# ```html
# <h1>Dies ist eine große Überschrift</h1>
# <h3>Dies ist eine kleinere Überschrift</h3>
# <p>Dies ist ein Absatz</p>
# <div>Dies ist eine Untergliederung</div>
# <a href="https://www.wiso.uni-hamburg.de/fachbereich-sozoek.html">Das ist ein Link</a>
# ```

# %% [markdown]
# <h1>Dies ist eine große Überschrift</h1>
# <h3>Dies ist eine kleinere Überschrift</h3>
# <p>Dies ist ein Absatz</p>
# <div>Dies ist eine Untergliederung</div>
# <a href="https://www.wiso.uni-hamburg.de/fachbereich-sozoek.html">Das ist ein Link</a>

# %% [markdown]
# Eine Liste aller HTML-Tags findet sich [hier](https://www.w3schools.com/TAGS/default.ASP).
# Ein für das Webscraping wichtiges Tag ist *div*. Dieses Tag wird meist zur Gestaltung bestimmter Teile einer Webseite verwendet, indem diese Teile über die Attribute *id* oder *class* mit CSS-Gestaltungsangaben verküpft werden:

# %% [markdown]
# ```css
# .center {
#   text-align: center;
#   color: red;
# }
# ```
# ```html
# <div class="center">Dieser Teil ist über das Attribut class="center" gestaltet.</div>
# ```

# %% [markdown]
# ## Informationen aus HTML-Quellcode auslesen

# %% [markdown]
# Mit *BeautifulSoup* kann man nun Inhalte aus dem HTML-Quellcode extrahieren. Hierbei macht man es sich zu nutze, dass HTML-Quellcode üblicherweise eine gewisse Struktur aufweist. Gleichartige Informationen sind meist in gleichen HTML-Elementen zu finden oder sind über entsprechende CSS-Definitionen gleich gestaltet. Aus diesem Grund werden HTML-Dateien auch als [semi-strukturierte Daten](https://de.wikipedia.org/wiki/Semistrukturierte_Daten) bezeichnet. Diese Struktur- bzw. Gestaltungsinformationen kann man beim Webscraping nutzen, indem man die Informationen in genau diesen Elementen extrahiert.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tipp:</b> Wenn man die HTML-Elemente oder CSS-Definitionen im Quellcode identifizieren möchte, welche die Informationen beinhalten, die wir extrahieren möchten, ist der <i>Element-Inspektor</i> aus den <a href="https://www.youtube.com/watch?v=WUArM-7NFIo">Entwickler-Tools</a> des jeweiligen Browsers hilfreich.
# </div>

# %% [markdown]
# Dazu bietet *BeautifulSoup* unter anderem die Funktionen `find()` und `find_all()` an. In den Klammern gibt man z.B. HTML-Tags, Text, Attribute oder CSS-Selektoren an, die man extrahieren möchte. `find()` liefert nur die *erste* Instanz im Quellcode. `find_all()` liefert eine Liste aller Übereinstimmungen.<br>

# %% [markdown]
# ### Anwendungsbeispiel

# %% [markdown]
# Im Wikipedia-Beispiel gibt es nur ein *h1*-Tag, das die Hauptüberschrift der Webseite beeinhaltet. Somit ist die Funktion `find()` ausreichend, um diese Information aus dem Quellcode zu extrahieren. Die Funktion `find()` muss auf die Variable *bs* angewendet werden, die das *BeautifulSoup*-Objekt beinhaltet. Um das h1-Tag zu suchen und zu extrahieren, muss "h1" in der Funktion `find()` als Argument angegeben werden. Das Ergebnis wird in die Variable *h1_tag* gespeichert.

# %%
h1_tag = bs.find("h1")

# %% [markdown]
# Die Inhalte der Variable *h1_tag* bzw. Teile davon können dann über die Funktion `print()` ausgegeben werden:

# %%
print(h1_tag) # vollständiges HTML-Element ausgeben
print(type(h1_tag)) # Datentyp: BeautifulSoup-Tag-Objekt
print(100*'-')
print(h1_tag.attrs) # Tag-Attribute ausgeben
print(type(h1_tag.attrs)) # Datentyp: Python dictionary
print(100*'-')
print(h1_tag.string) # Element-Text ausgeben
print(type(h1_tag.string)) # Datentyp: BeautifulSoup-NavigableString-Objekt und kein normaler String!
# Out:
# <h1 class="firstHeading mw-first-heading" id="firstHeading">Hamburg</h1>
# <class 'bs4.element.Tag'>
# ----------------------------------------------------------------------------------------------------
# {'id': 'firstHeading', 'class': ['firstHeading', 'mw-first-heading']}
# <class 'dict'>
# ----------------------------------------------------------------------------------------------------
# Hamburg
# <class 'bs4.element.NavigableString'>

# %% [markdown]
# Benötigt man den Element-Text für die Weiterverarbeitung als normalen String, kann der Text mit der Funktion `get_text()` aus dem HTML-Element extrahiert werden:

# %%
h1_tag_str = h1_tag.get_text()
print(h1_tag_str)
print(type(h1_tag_str)) # Datentyp: string
# Out:
# Hamburg
# <class 'str'>

# %% [markdown]
# Möchte man alle HTML-Tags der gleichen Art extrahieren, muss die Funktion `find_all()` verwendet werden. Im Folgenden werden alle h2-Tags extrahiert.

# %%
h2_tag = bs.find_all("h2")

# %% [markdown]
# Da es nun mehrere Inhalte gibt, legt *BeautifulSoup* eine [Liste](https://www.w3schools.com/python/python_lists.asp) an. Eine Liste ist eine Art Datencontainer, der mehrere Elemente in einer festgelegten Reihenfolge beinhaltet.

# %%
print(h2_tag)
# Out:
# [<h2 id="mw-toc-heading">Inhaltsverzeichnis</h2>, <h2><span class="mw-headline" id="Geographie">Geographie</span></h2>, <h2><span class="mw-headline" id="Geschichte">Geschichte</span></h2>, <h2><span id="Bev.C3.B6lkerung"></span><span class="mw-headline" id="Bevölkerung">Bevölkerung</span></h2>, <h2><span class="mw-headline" id="Politik_und_Staat">Politik und Staat</span></h2>, <h2><span class="mw-headline" id="Kultur">Kultur</span></h2>, <h2><span class="mw-headline" id="Wirtschaft_und_Infrastruktur">Wirtschaft und Infrastruktur</span></h2>, <h2><span class="mw-headline" id="Siehe_auch">Siehe auch</span></h2>, <h2><span class="mw-headline" id="Literatur">Literatur</span></h2>, <h2><span class="mw-headline" id="Weblinks">Weblinks</span></h2>, <h2><span class="mw-headline" id="Einzelnachweise">Einzelnachweise</span></h2>, <h2>Navigationsmenü</h2>]

# %% [markdown]
# Listen kann man mit einer [for-Schleife](https://www.w3schools.com/python/python_for_loops.asp) elementweise bearbeiten. Hier wird jedes Element in *h2_tag* nacheinander der Indexvariable *h2* zugewiesen und dann der entsprechende Inhalt ausgegeben:

# %%
for h2 in h2_tag:
    print(h2.string)
# Out:
# Inhaltsverzeichnis
# Geographie
# Geschichte
# None
# Politik und Staat
# Kultur
# Wirtschaft und Infrastruktur
# Siehe auch
# Literatur
# Weblinks
# Einzelnachweise
# Navigationsmenü

# %% [markdown]
# Möchte man alle Links auf der Hamburg-Seite der deutschen Wikipedia extrahieren geht das folgendermaßen (es werden nur die Links extrahiert, bei denen das Attribut *href*, also der Hyperlink, vorhanden ist):

# %%
links = bs.find_all('a', href = True)

# %%
for l in links:
        print(l['href'])
# Out:
# #Vorlage_Lesenswert
# #mw-head
# #searchInput
# /wiki/Hamburg_(Begriffskl%C3%A4rung)
# /wiki/Datei:Flag_of_Hamburg.svg
# /wiki/Datei:Locator_map_Hamburg_in_Germany.svg
# /wiki/Landeswappen_Hamburgs#Flaggen
# /wiki/Datei:Wappen_der_Hamburgischen_B%C3%BCrgerschaft.svg
# /wiki/Landeswappen_Hamburgs#Großes_Staatswappen_und_Logo
# /wiki/Amtssprachen_innerhalb_Deutschlands
# /wiki/Deutsche_Sprache
# #cite_note-1
# /wiki/Staatsform
# /wiki/Parlamentarische_Republik
# /wiki/Souver%C3%A4nit%C3%A4t
# /wiki/Bundesstaat_(F%C3%B6deraler_Staat)
# /wiki/Postleitzahl_(Deutschland)
# /wiki/Neuwerk
# /wiki/Telefonvorwahl_(Deutschland)
# /wiki/Neuwerk
# /wiki/Kfz-Kennzeichen_(Deutschland)
# /wiki/Kaufkraft_(Konsum)
# #cite_note-GfK_Kaufkraft_2021-2
# /wiki/Kaufkraft_(Konsum)
# #cite_note-GfK_Kaufkraft_2021-2
# /wiki/Bruttoinlandsprodukt
# /wiki/Liste_der_deutschen_Bundesl%C3%A4nder_nach_Bruttoinlandsprodukt
# #cite_note-3
# /wiki/Liste_der_deutschen_Bundesl%C3%A4nder_nach_Bruttoinlandsprodukt
# /wiki/Schulden
# #cite_note-Schulden-4
# /wiki/Senat_der_Freien_und_Hansestadt_Hamburg
# /wiki/Rathausmarkt_(Hamburg)
# /wiki/Amtlicher_Gemeindeschl%C3%BCssel
# /wiki/ISO_3166-2:DE
# /wiki/UN/LOCODE
# https://www.hamburg.de/stadt-staat/
# /wiki/Einwohner
# #cite_note-statamt-5
# /wiki/Ausl%C3%A4nder
# #cite_note-Ausländer-6
# /wiki/Migrationshintergrund
# #cite_note-Statistik-Nord_2020-7
# #cite_note-Ausländer-6
# #cite_note-Statistik-Profile_2015-8
# /wiki/Metropolregion_Hamburg
# #cite_note-Metropolregion_Hamburg-9
# /wiki/Bev%C3%B6lkerungsdichte
# /wiki/Arbeitslosenstatistik
# #cite_note-10
# /wiki/Geographische_Koordinaten
# https://geohack.toolforge.org/geohack.php?pagename=Hamburg&language=de&params=53.550556_N_9.993333_E_dim:40000_region:DE-HH_type:adm1st(1773218)
# https://geohack.toolforge.org/geohack.php?pagename=Hamburg&language=de&params=53.550556_N_9.993333_E_dim:40000_region:DE-HH_type:adm1st(1773218)
# /wiki/H%C3%B6he
# /wiki/Normalh%C3%B6hennull
# /wiki/Fl%C3%A4cheninhalt
# /wiki/Gr%C3%B6%C3%9Fenordnung_(Fl%C3%A4che)#100_km²_bis_1000_km²
# #cite_note-11
# /wiki/Liste_der_deutschen_Bundesl%C3%A4nder_nach_Fl%C3%A4che
# /wiki/Liste_der_100_fl%C3%A4chengr%C3%B6%C3%9Ften_Gemeinden_Deutschlands
# #cite_note-BezVG-12
# /wiki/Bezirke_in_Hamburg
# /wiki/Erster_B%C3%BCrgermeister
# /wiki/Peter_Tschentscher
# /wiki/Erster_B%C3%BCrgermeister#Zweiter_Bürgermeister
# /wiki/Katharina_Fegebank
# /wiki/Pr%C3%A4sident_der_Hamburgischen_B%C3%BCrgerschaft
# /wiki/Carola_Veit
# /wiki/Politische_Partei
# /wiki/SPD
# /wiki/B%C3%BCndnis_90/Die_Gr%C3%BCnen
# /wiki/Liste_der_Mitglieder_der_Hamburgischen_B%C3%BCrgerschaft_(22._Wahlperiode)
# /wiki/Sitzverteilung_in_den_deutschen_Landesparlamenten
# #cite_note-13
# /wiki/SPD_Hamburg
# /wiki/B%C3%BCndnis_90/Die_Gr%C3%BCnen_Hamburg
# /wiki/CDU_Hamburg
# /wiki/Die_Linke_Hamburg
# /wiki/AfD_Hamburg
# /wiki/FDP_Hamburg
# /wiki/Politik_in_Hamburg
# /wiki/B%C3%BCrgerschaftswahl_in_Hamburg_2020
# /wiki/Politik_in_Hamburg
# /wiki/Wahl_zur_23._Hamburgischen_B%C3%BCrgerschaft
# /wiki/Bundesrat_(Deutschland)
# /wiki/Bezirke_in_Hamburg
# /wiki/Datei:Hamburg,_administrative_divisions_(%2Bdistricts_-boroughs_-pop)_-_de_-_colored.svg
# /wiki/Datei:Hamburg-logo.svg
# /wiki/Liste_der_IPA-Zeichen
# /wiki/Datei:GeoTrinity_Hamburg.ogg
# /wiki/Medium:GeoTrinity_Hamburg.ogg
# /wiki/Liste_der_IPA-Zeichen
# /wiki/Datei:GeoTrinity_Hamburch.ogg
# /wiki/Medium:GeoTrinity_Hamburch.ogg
# /wiki/Liste_der_IPA-Zeichen
# /wiki/Niederdeutsche_Sprache
# /wiki/ISO_3166-2:DE
# /wiki/Stadtstaat
# /wiki/Land_(Deutschland)
# /wiki/Deutschland
# /wiki/Geschichte_Hamburgs
# /wiki/Freie_und_Reichsst%C3%A4dte
# /wiki/Hanse
# #cite_note-Verfassung_Hamburg-14
# #cite_note-15
# /wiki/Liste_der_Gro%C3%9Fst%C3%A4dte_in_Deutschland
# /wiki/Liste_der_gr%C3%B6%C3%9Ften_St%C3%A4dte_im_deutschen_Sprachraum
# /wiki/Gemeinde_(Deutschland)
# /wiki/Bezirke_in_Hamburg
# #cite_note-BezVG-12
# #cite_note-Einteilung-16
# /wiki/Hamburg-Neuwerk
# /wiki/Nordsee
# /wiki/Hamburger_Hafen
# /wiki/Containerterminal#Umschlagdaten
# #cite_note-17
# /wiki/Flughafen_Hamburg
# /wiki/Logistik
# /wiki/Luft-_und_Raumfahrttechnik
# /wiki/Biowissenschaften
# /wiki/Informationstechnik
# /wiki/Konsumgut
# /wiki/Presse_(Medien)
# /wiki/Internationaler_Seegerichtshof
# #Tourismus
# /wiki/Lebensqualit%C3%A4t
# /wiki/Economist_Intelligence_Unit
# #cite_note-18
# /wiki/Speicherstadt
# /wiki/Kontorhausviertel
# /wiki/Welterbe_in_Deutschland
# #cite_note-UNESCO-en-19
# #cite_note-20
# /wiki/Liste_der_Kulturdenkm%C3%A4ler_in_Hamburg
# /wiki/Hamburger_Rathaus
# /wiki/Hamburger_Hauptkirchen
# /wiki/Klinker
# /wiki/Fleet
# /wiki/Hamburg-St._Pauli
# /wiki/Reeperbahn
# /wiki/Elbphilharmonie
# #Geographie
# #Lage
# #Fließgewässer
# #Schutzgebiete
# #Geologie
# #Verwaltungsgliederung
# #Bezirke
# #Exklaven
# #Nachbarstädte_und_Gemeinden
# #Klima
# #Umwelt
# #Naturschutz
# #Luft
# #Klimawandel
# #Geschichte
# #Bevölkerung
# #Bevölkerungsentwicklung
# #Bevölkerungsstruktur
# #Herkunft
# #Beschäftigung
# #Einkommen
# #Leistungsempfänger
# #Religionen_und_Weltanschauungen
# #Konfessionsstatistik
# #Religionsgeschichte
# #Sprache_und_Mundarten
# #Persönlichkeiten
# #Haustiere
# #Hunde
# #Pferde
# #Politik_und_Staat
# #Staatsrecht
# #Wahl_zur_Hamburgischen_Bürgerschaft_2020
# #Weitere_Wahlen
# #Vertretungen_und_Konsulate
# #Städtepartnerschaften
# #Hoheitszeichen
# #Wappen,_Logo,_Wappenzeichen
# #Flaggen_und_Admiralität
# #Hymne,_Stadtname,_Stadtpatrone,_Wahlsprüche
# #Auszeichnungen
# #Webauftritt
# #Hamburg_Welcome_Center
# #Kultur
# #Kulinarische_Spezialitäten
# #Hamburgensien
# #Hamburger_Liedgut
# #„Hamburger_Gruß“
# #Hamburger_Witze
# #Hamburger_Aalsuppe
# #Fliegender_Hamburger
# #Briefmarken
# #Regelmäßige_Veranstaltungen
# #Musik
# #Musicals
# #Oper_und_Ballett
# #Konzerthäuser
# #Theater
# #Besucherorganisationen
# #Öffentliche_Bücherhallen
# #Museen_und_Ausstellungen
# #Bauwerke_und_Stadtentwicklung
# #Brücken
# #Stolpersteine
# #Parks_und_Grünanlagen
# #Sport
# #Wirtschaft_und_Infrastruktur
# #Staatsverschuldung
# #Unternehmen
# #Verkehr
# #Verkehrsmittelverteilung
# #Straßenverkehr
# #Radverkehr
# #Öffentlicher_Personenverkehr
# #Schienenfernverkehr
# #Öffentlicher_Stadt-_und_Regionalverkehr
# #Wasserverkehr
# #Wasserwege
# #Fährdienste
# #Hafen
# #Luftverkehr
# #Versorger
# #Wasserversorgung
# #Energieversorgung
# #Industrie
# #Dienstleistungen
# #Tourismus
# #Medien
# #Informations-_und_Telekommunikationssektor
# #Finanzdienstleistungen
# #Banken
# #Versicherungen
# #Handel
# #Börse
# #Messen_und_Kongresse
# #Einzelhandel
# #Institutionen,_öffentliche_Einrichtungen_und_Stiftungen
# #Feuerwehr
# #Bildung_und_Forschung
# #Gesundheit
# #Siehe_auch
# #Literatur
# #Weblinks
# #Einzelnachweise
# /wiki/Datei:Hamburgfromair2.jpg
# /wiki/Datei:Hamburgfromair2.jpg
# /wiki/Hamburger_Hafen
# /wiki/Binnenalster
# /wiki/Au%C3%9Fenalster
# /wiki/Datei:Metropolregion_Hamburg_2017.png
# /wiki/Datei:Metropolregion_Hamburg_2017.png
# /wiki/Metropolregion_Hamburg
# /wiki/Norddeutschland
# /wiki/Bille
# /wiki/Alster
# /wiki/Unterelbe
# /wiki/Nordsee
# /wiki/Hamburg-Neuwerk
# /wiki/Elbe
# /wiki/Seehafen
# /wiki/Veddel
# /wiki/Hamburg-Finkenwerder
# /wiki/Norderelbe
# /wiki/Hamburg-St._Pauli
# /wiki/Bezirk_Altona
# /wiki/Hamburger_Elbbr%C3%BCcken
# /wiki/St._Pauli-Elbtunnel
# /wiki/Neuer_Elbtunnel
# /wiki/Geest
# /wiki/K%C3%A4nozoisches_Eiszeitalter#Gliederung_in_Mitteleuropa
# /wiki/Alt-_und_Jungmor%C3%A4ne
# /wiki/Marschland
# /wiki/Eindeichung
# /wiki/Deich
# /wiki/Normalh%C3%B6hennull
# /wiki/Hasselbrack
# /wiki/Harburger_Berge
# /wiki/Hamburger_Innenstadt
# /wiki/Mittelalter
# /wiki/Binnenalster
# /wiki/Fleet
# #Brücken
# #cite_note-21
# #cite_note-22
# /wiki/Hamburg-Wilhelmsburg
# /wiki/Heuckenlock
# /wiki/Schleswig-Holstein
# /wiki/Niedersachsen
# /wiki/Neuwerk
# #cite_note-23
# #cite_note-24
# #cite_note-25
# /wiki/Gro%C3%9F-Hamburg-Gesetz
# /wiki/Berlin
# /wiki/Liste_der_100_fl%C3%A4chengr%C3%B6%C3%9Ften_Gemeinden_Deutschlands
# /wiki/Liste_geographischer_Mittelpunkte
# /wiki/Hamburg-Uhlenhorst
# #cite_note-26
# /wiki/Krauel
# #cite_note-27
# /wiki/Elbe
# /wiki/Unterelbe
# /wiki/Reiherstieg
# /wiki/Dove_Elbe
# /wiki/Gose_Elbe
# /wiki/Seevekanal
# /wiki/Bille
# /wiki/Flottbek_(Fluss)
# /wiki/Este_(Fluss)
# /wiki/Alster
# /wiki/Wandse
# /wiki/Osterbek
# /wiki/Goldbekkanal
# /wiki/Isebekkanal
# /wiki/Tarpenbek
# /wiki/Saselbek
# /wiki/Rodenbek_(Alster)
# /wiki/Bredenbek_(Alster)
# /wiki/Ammersbek_(Alster)
# /wiki/Liste_von_Erhebungen_in_Hamburg
# /wiki/Liste_der_Naturdenkmale_in_Hamburg
# /wiki/Liste_der_Naturschutzgebiete_in_Hamburg
# /wiki/Liste_der_Landschaftsschutzgebiete_in_Hamburg
# /wiki/Liste_der_Wasserschutzgebiete_in_Hamburg
# /wiki/Hamburgs_geologischer_Untergrund
# /wiki/Bezirke_in_Hamburg
# /wiki/Datei:Hamburg,_administrative_divisions_(%2Bdistricts_-%2Bboroughs_-pop)_-_de_-_colored.svg
# /wiki/Datei:HamburgKarte_Version01_070527_150dpi.PNG
# /wiki/Datei:HamburgKarte_Version01_070527_150dpi.PNG
# /wiki/Alster#Alstersee
# /wiki/Verfassung_der_Freien_und_Hansestadt_Hamburg
# /wiki/Bezirksamt
# #cite_note-28
# #cite_note-BezVG-12
# #cite_note-Einteilung-16
# /wiki/Ortsamt_(Hamburg)
# #cite_note-29
# /wiki/Hamburg-Wilhelmsburg
# /wiki/Bezirk_Harburg
# /wiki/Bezirk_Hamburg-Mitte
# /wiki/Hamburg-Sternschanze
# /wiki/Bezirk_Altona
# /wiki/Hamburg-HafenCity
# #cite_note-RäumGiG-30
# #cite_note-31
# /wiki/Datei:F%C3%BChrt_kein_Wappen.svg
# /wiki/Bezirk_Hamburg-Mitte
# /wiki/Datei:DEU_Altona_COA.svg
# /wiki/Bezirk_Altona
# /wiki/Datei:Wappen_Eimsb%C3%BCttel1.svg
# /wiki/Bezirk_Eimsb%C3%BCttel
# /wiki/Datei:F%C3%BChrt_kein_Wappen.svg
# /wiki/Bezirk_Hamburg-Nord
# /wiki/Datei:Wappen_Hamburg-Wandsbek.svg
# /wiki/Bezirk_Wandsbek
# /wiki/Datei:Wappen_Hamburg-Bergedorf.png
# /wiki/Bezirk_Bergedorf
# /wiki/Datei:Wappen_Harburg-Wilhelmsburg.png
# /wiki/Bezirk_Harburg
# /wiki/Datei:DEU_Hamburg_COA.svg
# /wiki/Datei:11-09-04-fotoflug-nordsee-by-RalfR-001.jpg
# /wiki/Datei:11-09-04-fotoflug-nordsee-by-RalfR-001.jpg
# /wiki/Neuwerk
# /wiki/Datei:Hamburg_Sturmflut_1962.png
# /wiki/Datei:Hamburg_Sturmflut_1962.png
# /wiki/Exklave
# /wiki/Nordsee
# /wiki/Neuwerk
# /wiki/Scharh%C3%B6rn
# /wiki/Nigeh%C3%B6rn
# /wiki/Nationalpark_Hamburgisches_Wattenmeer
# /wiki/Hamburg-Neuwerk
# /wiki/Bezirk_Hamburg-Mitte
# /wiki/Ammersbek
# /wiki/Schleswig-Holstein
# /wiki/Bezirk_Wandsbek
# #cite_note-32
# /wiki/Cuxhaven-Vertrag
# /wiki/Gemeinde_(Deutschland)
# /wiki/Uhrzeigersinn
# /wiki/Kreis_Pinneberg
# /wiki/Wedel
# /wiki/Appen
# /wiki/Pinneberg
# /wiki/Schenefeld_(Kreis_Pinneberg)
# /wiki/Halstenbek
# /wiki/Rellingen
# /wiki/Ellerbek
# /wiki/Amt_Pinnau
# /wiki/B%C3%B6nningstedt
# /wiki/Kreis_Segeberg
# /wiki/Norderstedt
# /wiki/Kreis_Stormarn
# /wiki/Tangstedt_(Stormarn)
# /wiki/Jersbek
# /wiki/Amt_Bargteheide-Land
# /wiki/Ammersbek
# /wiki/Ahrensburg
# /wiki/Stapelfeld
# /wiki/Amt_Siek
# /wiki/Barsb%C3%BCttel
# /wiki/Oststeinbek
# /wiki/Glinde
# /wiki/Reinbek
# /wiki/Kreis_Herzogtum_Lauenburg
# /wiki/Wentorf_bei_Hamburg
# /wiki/B%C3%B6rnsen
# /wiki/Escheburg
# /wiki/Amt_Hohe_Elbgeest
# /wiki/Geesthacht
# /wiki/Landkreis_Harburg
# /wiki/Drage_(Elbe)
# /wiki/Samtgemeinde_Elbmarsch
# /wiki/Winsen_(Luhe)
# /wiki/Stelle_(Landkreis_Harburg)
# /wiki/Seevetal
# /wiki/Rosengarten_(Landkreis_Harburg)
# /wiki/Neu_Wulmstorf
# /wiki/Landkreis_Stade
# /wiki/Jork
# /wiki/Landkreis_Cuxhaven
# /wiki/Cuxhaven
# /wiki/Neuwerk
# /wiki/Liste_von_Klimadaten_am_Flughafen_Hamburg
# /wiki/Hamburg#Klimawandel
# /wiki/K%C3%BChlgem%C3%A4%C3%9Figtes_Klima
# /wiki/Seeklima
# /wiki/Jahresmitteltemperatur
# /wiki/Hamburg-Fuhlsb%C3%BCttel
# #cite_note-33
# /wiki/Schmuddelwetter
# #cite_note-34
# /wiki/Monatsmitteltemperatur
# /wiki/Niederschlagsmenge
# /wiki/Deutscher_Wetterdienst
# #cite_note-35
# /wiki/Monatsmitteltemperatur
# /wiki/Niederschlagsmenge
# /wiki/Sonnenstunden
# /wiki/Regentag
# /wiki/Luftfeuchtigkeit
# /wiki/Deutscher_Wetterdienst
# #cite_note-35
# /wiki/L%C3%A4rm
# #Verkehrsmittelverteilung
# /wiki/Umweltzone
# /wiki/Agglomeration
# /wiki/Luftverschmutzung
# /wiki/Heizung
# /wiki/M%C3%BCllverbrennung
# /wiki/Emissionen_durch_die_Schifffahrt#Luftbelastung_in_den_Häfen
# #cite_note-36
# /wiki/Beh%C3%B6rde_f%C3%BCr_Umwelt_und_Energie
# /wiki/Umwelthauptstadt_Europas_Hamburg_2011
# /wiki/Airbus
# /wiki/M%C3%BChlenberger_Loch#Wirtschaft_und_Naturschutz_–_Die_Airbus-Erweiterung
# /wiki/Kohlekraftwerk_Moorburg
# /wiki/Polychlorierte_Dibenzodioxine_und_Dibenzofurane
# /wiki/Boehringer_Ingelheim#Negative_Wahrnehmung
# /wiki/Hamburg-Billbrook
# /wiki/Parathion
# /wiki/Deponie_Georgswerder
# #cite_note-37
# /wiki/Gesamtkunstwerk_Freie_und_Hansestadt_Hamburg
# /wiki/Hamburg-Altenwerder
# #cite_note-38
# /wiki/Elbvertiefung
# /wiki/Luftverschmutzung
# /wiki/Stickstoffdioxid
# /wiki/Fahrzeugkatalysator
# /wiki/Luftreinhalteplan
# /wiki/Anordnung_(Recht)
# #cite_note-39
# /wiki/Feinstaub
# /wiki/PM10
# #cite_note-40
# #cite_note-41
# /wiki/Verwaltungsgericht_Hamburg
# #cite_note-42
# /wiki/Gesetzeskraft
# #cite_note-43
# #cite_note-44
# /wiki/Globale_Erw%C3%A4rmung
# /wiki/Sommertag
# /wiki/Hei%C3%9Fer_Tag
# /wiki/Tropennacht
# /wiki/Arbeitsproduktivit%C3%A4t
# /wiki/Konzentration_(Psychologie)
# /wiki/Frosttag
# /wiki/Eistag
# #cite_note-45
# /wiki/Meeresspiegelanstieg_seit_1850
# /wiki/Sturmflut
# /wiki/Brackwasser
# #cite_note-:0-46
# /wiki/Folgen_der_globalen_Erw%C3%A4rmung
# /wiki/Anpassung_an_die_globale_Erw%C3%A4rmung
# #cite_note-:0-46
# /wiki/Geschichte_Hamburgs
# /wiki/Claudius_Ptolem%C3%A4us
# /wiki/Treva
# /wiki/Sachsen_(Volk)
# /wiki/Hammaburg
# /wiki/Karl_der_Gro%C3%9Fe
# /wiki/Ludwig_der_Fromme
# /wiki/Bistum
# /wiki/Erzbistum
# /wiki/Vertrag_von_Verdun
# /wiki/Wikinger
# /wiki/Abodriten
# /wiki/Bremen
# /wiki/Datei:1730_Hamburg_Covens_%26_Mortier.JPG
# /wiki/Datei:1730_Hamburg_Covens_%26_Mortier.JPG
# /wiki/Adolf_III._(Schauenburg_und_Holstein)
# /wiki/Friedrich_I._(HRR)
# /w/index.php?title=Hafenrecht&action=edit&redlink=1
# #cite_note-47
# /wiki/Privileg
# /wiki/Unterelbe
# /wiki/Brauerei
# /wiki/Hanse
# /wiki/Freie_Reichsstadt
# /wiki/Hamburger_B%C3%B6rse
# /wiki/Oper_am_G%C3%A4nsemarkt
# /wiki/Oper
# /wiki/G%C3%A4nsemarkt
# /wiki/Reformation
# /wiki/Hamburgische_Entreprise
# /wiki/Aufkl%C3%A4rung
# /wiki/Industrialisierung
# /wiki/Drei%C3%9Figj%C3%A4hriger_Krieg
# /wiki/Heiliges_R%C3%B6misches_Reich
# /wiki/D%C3%A9partement
# /wiki/D%C3%A9partement_des_Bouches_de_l%E2%80%99Elbe
# /wiki/Hamburger_Franzosenzeit
# /wiki/Levin_August_von_Bennigsen
# /wiki/Wiener_Kongress
# /wiki/Deutscher_Bund
# /wiki/Otto_von_Bismarck
# /wiki/Norddeutscher_Bund
# /wiki/Hamburger_Brand
# /wiki/Choleraepidemie_von_1892
# /wiki/Gro%C3%9F-Hamburg-Gesetz
# /wiki/Operation_Gomorrha
# /wiki/J%C3%BCdische_Gemeinde_Hamburg
# /wiki/Geschichte_der_Juden_in_Hamburg
# /wiki/KZ_Neuengamme
# /wiki/KZ_Neuengamme#Die_Außenlager
# /wiki/Sturmflut_1962
# /wiki/Flugplatz_Hamburg-Finkenwerder
# /wiki/Flughafen_Hamburg
# /wiki/Hafenstra%C3%9Fe
# /wiki/Einwohnerentwicklung_von_Hamburg
# /wiki/Datei:Einwohnerentwicklung_von_Hamburg_-_ab_1871.svg
# /wiki/Datei:Einwohnerentwicklung_von_Hamburg_-_ab_1871.svg
# /wiki/Suburbanisierung
# #cite_note-48
# /wiki/Lebenserwartung
# #cite_note-49
# /wiki/Datei:Marco-Polo-Terrassen.jpg
# /wiki/Datei:Marco-Polo-Terrassen.jpg
# /wiki/Migrationshintergrund
# /wiki/Deutsche_Staatsangeh%C3%B6rigkeit
# #cite_note-Stadtteil_Profil_2013-50
# /wiki/Ausl%C3%A4nder
# /wiki/Aussiedler_und_Sp%C3%A4taussiedler
# #cite_note-Stadtteil_Profil_2013-50
# /wiki/T%C3%BCrkei
# /wiki/Polen
# /wiki/Afghanistan
# /wiki/Serbien_und_Montenegro
# /wiki/%C3%96ffentlicher_Dienst_(Deutschland)
# /wiki/Unternehmen
# #cite_note-51
# /wiki/Datei:Pincerno_-_Einkommen_2010.png
# /wiki/Datei:Pincerno_-_Einkommen_2010.png
# /wiki/Bezirke_in_Hamburg
# /wiki/Datei:Pincerno_-_Hartz_IV_2010.png
# /wiki/Datei:Pincerno_-_Hartz_IV_2010.png
# /wiki/Bezirke_in_Hamburg
# #cite_note-52
# /wiki/Elbvororte
# /wiki/Waldd%C3%B6rfer
# /wiki/Au%C3%9Fenalster
# /wiki/Hamburg-Marienthal
# /wiki/Hamburg-Nienstedten
# /wiki/Hamburg-Blankenese
# /wiki/Hamburg-Wohldorf-Ohlstedt
# /wiki/Hamburg-Harvestehude
# #cite_note-53
# /wiki/Reichtumsquote
# #cite_note-54
# /wiki/Einkommensmillion%C3%A4r
# #cite_note-55
# /wiki/Hamburg-Billstedt
# /wiki/Hamburger_Innenstadt
# /wiki/Hamburg-Wilhelmsburg
# /wiki/Hamburg-Veddel
# /wiki/Hamburg-Harburg
# /wiki/Hamburg-Altona-Altstadt
# /wiki/Hamburg-Altona-Nord
# /wiki/Hamburg-St._Pauli
# /wiki/Hamburg-Dulsberg
# /wiki/Hamburg-Barmbek-Nord
# /wiki/Hamburg-Steilshoop
# /wiki/Hamburg-Lurup
# /wiki/Hamburg-Kleiner_Grasbrook
# /wiki/Hamburg-Steinwerder
# /wiki/Hamburg-Rothenburgsort
# #cite_note-56
# /wiki/Zweites_Buch_Sozialgesetzbuch
# /wiki/Arbeitslosengeld_II
# /wiki/Freie_Hansestadt_Bremen
# /wiki/Bezirk_Bergedorf
# /wiki/Hamburg-Steilshoop
# /wiki/Hamburg-Hausbruch
# /wiki/Hamburg-Jenfeld
# /wiki/M%C3%BCmmelmannsberg
# /wiki/Kirchdorf-S%C3%BCd
# #cite_note-57
# /wiki/Datei:Sankt-Michaelis-Kirche_Hamburg.jpg
# /wiki/Datei:Sankt-Michaelis-Kirche_Hamburg.jpg
# /wiki/Hauptkirche_Sankt_Michaelis_(Hamburg)
# /wiki/Religion_in_Hamburg
# /wiki/Zensus_2011
# /wiki/R%C3%B6misch-katholische_Kirche
# /wiki/Konfessionslosigkeit
# #cite_note-58
# #cite_note-59
# /wiki/Evangelische_Kirche
# /wiki/Konkordienformel
# #cite_note-60
# /wiki/Baptisten
# /wiki/Mennonitengemeinde_zu_Hamburg_und_Altona
# /wiki/Kategorie:Apostolische_Gemeinschaften
# /wiki/Allgemeine_christliche_apostolische_Mission
# /wiki/Katholisch-apostolische_Gemeinden
# /wiki/Neuapostolische_Kirche
# #cite_note-61
# /wiki/R%C3%B6misch-katholische_Kirche
# /wiki/Erzbistum_Hamburg
# /wiki/St._Marien-Dom_(Hamburg)
# /wiki/Jesus_Freaks
# /wiki/Flussschifferkirche
# /wiki/Kirchenboot
# /wiki/Binnenhafen_(Hamburg)
# /wiki/Jehovas_Zeugen
# /wiki/J%C3%BCdische_Gemeinde_Hamburg
# /wiki/Liste_der_Synagogen_in_Hamburg
# /wiki/Novemberpogrome_1938
# /wiki/J%C3%BCdischer_Friedhof_Altona
# /wiki/Iberische_Halbinsel
# /wiki/Sephardim
# /wiki/Aschkenasim
# #cite_note-62
# /wiki/Talmud-Tora-Schule
# /wiki/Bezirk_Eimsb%C3%BCttel
# /wiki/Muslim
# /wiki/Stellingen
# /wiki/Fazle-Omar-Moschee
# /wiki/Zweiter_Weltkrieg
# /wiki/Ahmadiyya_Muslim_Jamaat
# /wiki/Buddhismus
# /wiki/Konvertit
# /wiki/Zen
# /wiki/Buddhismus_in_Tibet
# /wiki/Niederdeutsche_Sprache
# /wiki/Deutsche_Sprache
# /wiki/Verfassung_der_Freien_und_Hansestadt_Hamburg
# /wiki/Missingsch
# /wiki/Hamburger_Platt
# #cite_note-63
# /wiki/Hamburgisches_W%C3%B6rterbuch
# #cite_note-64
# /wiki/Ohnsorg-Theater
# /wiki/Hamburg-Altona
# /wiki/Hamburg-St._Georg
# /wiki/Veddel
# /wiki/Hamburg-Wilhelmsburg
# /wiki/Portugiesenviertel
# /wiki/Aussiedler
# /wiki/Sp%C3%A4taussiedler
# /wiki/D%C3%A4nische_Minderheit_in_Deutschland
# #cite_note-65
# /wiki/Europ%C3%A4ische_Charta_der_Regional-_oder_Minderheitensprachen
# /wiki/Niederdeutsch
# /wiki/Regionalsprache
# /wiki/Romani
# /wiki/Minderheitensprache
# /wiki/Hamburger_Dialekt
# /wiki/Liste_von_Pers%C3%B6nlichkeiten_der_Stadt_Hamburg
# #cite_note-66
# /wiki/Liste_der_Ehrenb%C3%BCrger_von_Hamburg
# /wiki/Liste_der_Hamburger_B%C3%BCrgermeister
# /wiki/Liste_der_Hamburger_Hauptpastoren
# /wiki/Hunderegister
# #cite_note-67
# /wiki/Hundezone
# /wiki/Hundeleine
# #cite_note-68
# /wiki/Gef%C3%A4hrlicher_Hund
# #cite_note-69
# /wiki/Hundef%C3%BChrerschein
# #cite_note-70
# /wiki/Alsterpark
# /wiki/H%C3%B6ltigbaum
# /wiki/Hamburg-Poppenb%C3%BCttel#Geografie
# /wiki/Galopprennbahn_Hamburg-Horn
# /wiki/%C3%96jendorfer_Park
# #cite_note-Zonen_Bezirke-71
# #cite_note-Zonen_Bezirke-71
# /wiki/Blindenf%C3%BChrhund
# #cite_note-72
# /wiki/Wochenmarkt
# /wiki/Volksfest
# /wiki/Hamburger_Dom_(Volksfest)
# /wiki/Hafengeburtstag
# #cite_note-73
# #cite_note-74
# /wiki/Hundegesetze
# /wiki/Tierkennzeichnung
# /wiki/Hunderegister
# /wiki/Tierhalterhaftpflichtversicherung
# /wiki/Windhundrennen
# /wiki/Norddeutscher_Windhund-Rennverein
# #cite_note-75
# /wiki/Pferdesport_in_Hamburg
# /wiki/Politik_in_Hamburg
# /wiki/Datei:HH_Rathaus_pano1.jpg
# /wiki/Hamburgische_B%C3%BCrgerschaft
# /wiki/Senat_der_Freien_und_Hansestadt_Hamburg
# /wiki/Hamburger_Rathaus
# /wiki/Historismus
# /wiki/Neorenaissance
# /wiki/Datei:Plenarsaal_Hamburgische_B%C3%BCrgerschaft_IMG_6403_6404_6405_edit.jpg
# /wiki/Hamburger_Rathaus
# /wiki/Datei:Hamburg.Oberlandesgericht.wmt.jpg
# /wiki/Hanseatisches_Oberlandesgericht
# /wiki/Stadtstaat
# /wiki/Land_(Deutschland)
# /wiki/Stadt
# /wiki/Einheitsgemeinde
# /wiki/Republik
# /wiki/Verfassung_der_Freien_und_Hansestadt_Hamburg
# /wiki/Demokratie
# /wiki/Sozialstaat
# /wiki/Rechtsstaat
# /wiki/Hamburgische_B%C3%BCrgerschaft
# /wiki/Volksgesetzgebung_in_Hamburg
# /wiki/Deputation_(Hamburg)
# /wiki/Senat_der_Freien_und_Hansestadt_Hamburg
# /wiki/Erster_B%C3%BCrgermeister
# /wiki/Geheime_Wahl_des_Regierungschefs_im_Parlament
# /wiki/Richtlinienkompetenz
# /wiki/Pr%C3%A4ses
# /wiki/Ministerium
# /wiki/Hamburgisches_Verfassungsgericht
# /wiki/Landesverfassungsgericht
# /wiki/Bezirke_in_Hamburg
# /wiki/Bezirksversammlung
# /wiki/Bundesrat_(Deutschland)
# /wiki/Direktmandat
# /wiki/Wahlkreis
# /wiki/Bundestagswahlkreis_Hamburg-Mitte
# /wiki/Bundestagswahlkreis_Hamburg-Altona
# /wiki/Bundestagswahlkreis_Hamburg-Eimsb%C3%BCttel
# /wiki/Bundestagswahlkreis_Hamburg-Nord
# /wiki/Bundestagswahlkreis_Hamburg-Wandsbek
# /wiki/Bundestagswahlkreis_Hamburg-Bergedorf_%E2%80%93_Harburg
# /wiki/Deutscher_Bundestag
# /wiki/Deutscher_St%C3%A4dtetag
# /wiki/Ausschuss_der_Regionen
# /wiki/Nordstaat
# /wiki/Metropolregion_Hamburg
# /wiki/Statistisches_Landesamt
# /wiki/B%C3%BCrgerschaftswahl_in_Hamburg_2020
# /wiki/Hamburgische_B%C3%BCrgerschaft
# /wiki/B%C3%BCrgerschaftswahl_in_Hamburg_2015
# /wiki/Wahl_zur_23._Hamburgischen_B%C3%BCrgerschaft
# #cite_note-erg2302-76
# /wiki/Sozialdemokratische_Partei_Deutschlands
# /wiki/B%C3%BCndnis_90/Die_Gr%C3%BCnen
# /wiki/Christlich_Demokratische_Union_Deutschlands
# /wiki/Die_Linke
# /wiki/Alternative_f%C3%BCr_Deutschland
# /wiki/Freie_Demokratische_Partei
# /wiki/Die_Partei
# /w/index.php?title=Vorlage:Wahldiagramm/Wartung/K%C3%BCrzel&action=edit&redlink=1
# /wiki/Volt_Deutschland
# /wiki/B%C3%BCrgerschaftswahl_in_Hamburg_2015
# /wiki/Sozialdemokratische_Partei_Deutschlands
# /wiki/B%C3%BCndnis_90/Die_Gr%C3%BCnen
# /wiki/Christlich_Demokratische_Union_Deutschlands
# /wiki/Die_Linke
# /wiki/Alternative_f%C3%BCr_Deutschland
# /wiki/Freie_Demokratische_Partei
# /wiki/Die_Partei
# /w/index.php?title=Vorlage:Wahldiagramm/Wartung/K%C3%BCrzel&action=edit&redlink=1
# /wiki/Volt_Deutschland
# /wiki/Senat_Tschentscher_I
# /wiki/Zweidrittelmehrheit
# /wiki/FDP_Hamburg
# /wiki/F%C3%BCnfprozenth%C3%BCrde
# /wiki/Anna-Elisabeth_von_Treuenfels-Frowein
# /wiki/Wahlkreis_Blankenese
# #cite_note-77
# /wiki/Sozialdemokratische_Partei_Deutschlands
# /wiki/B%C3%BCndnis_90/Die_Gr%C3%BCnen
# /wiki/Christlich_Demokratische_Union_Deutschlands
# /wiki/Freie_Demokratische_Partei
# /wiki/Alternative_f%C3%BCr_Deutschland
# /wiki/Die_Linke
# /wiki/Bundestagswahl_2021
# /wiki/Europawahl_in_Deutschland_2019
# /wiki/Bundestagswahl_2017
# /wiki/Europawahl_in_Deutschland_2014
# /wiki/Bundestagswahl_2013
# /wiki/Bundestagswahl_2009
# /wiki/Europawahl_in_Deutschland_2009
# /wiki/Bundestagswahl_2005
# /wiki/Europawahl_in_Deutschland_2004
# /wiki/Bundestagswahl_2002
# /wiki/Europawahl_in_Deutschland_1999
# /wiki/Bundestagswahl_1998
# /wiki/Partei_des_Demokratischen_Sozialismus
# /wiki/Datei:Consulate_General_USA_Hamburg_2.jpg
# /wiki/Datei:Consulate_General_USA_Hamburg_2.jpg
# /wiki/Amerikanisches_Generalkonsulat_in_Hamburg
# /wiki/Au%C3%9Fenwirtschaft
# /wiki/Konsul
# /wiki/New_York_City
# /wiki/Frankfurt_am_Main
# /wiki/Hongkong
# /wiki/Hanse
# /wiki/Amerikanisches_Generalkonsulat_in_Hamburg
# /wiki/Martin_Haller_(Architekt)
# #cite_note-78
# /wiki/Vertretung_der_Freien_und_Hansestadt_Hamburg_beim_Bund
# /wiki/Landesvertretung
# /wiki/Schleswig-Holstein
# /wiki/Hanse-Office
# /wiki/Europ%C3%A4ische_Union
# /wiki/Br%C3%BCssel
# /wiki/Sankt_Petersburg
# /wiki/Handelskammer_Hamburg
# /wiki/Shanghai
# /wiki/Dubai
# /wiki/HamburgAmbassador_Programm
# /wiki/Liste_der_Konsulate_und_Handelsvertretungen_in_Hamburg
# /wiki/Gemeindepartnerschaft
# #cite_note-79
# /wiki/Russland
# /wiki/Sankt_Petersburg
# /wiki/Russland
# /wiki/Frankreich
# /wiki/Marseille
# /wiki/Frankreich
# /wiki/Volksrepublik_China
# /wiki/Shanghai
# /wiki/Volksrepublik_China
# /wiki/Deutschland
# /wiki/Dresden
# /wiki/Japan
# /wiki/Osaka
# /wiki/Japan
# /wiki/Nicaragua
# /wiki/Le%C3%B3n_(Nicaragua)
# /wiki/Nicaragua
# /wiki/Tschechien
# /wiki/Prag
# /wiki/Tschechien
# /wiki/Vereinigte_Staaten
# /wiki/Chicago
# /wiki/Vereinigte_Staaten
# /wiki/Tansania
# /wiki/Daressalam
# /wiki/Tansania
# #cite_note-80
# /wiki/Senat_der_Freien_und_Hansestadt_Hamburg
# /wiki/Ausw%C3%A4rtiges_Amt
# /wiki/Sowjetunion
# #cite_note-81
# /wiki/Deutsch-franz%C3%B6sische_Beziehungen#Deutsch-französische_Freundschaft
# /wiki/Marseille
# /wiki/Hamburg-HafenCity
# /wiki/Eurom%C3%A9diterran%C3%A9e
# #cite_note-82
# #cite_note-Lasse_Lassen_2017-83
# #cite_note-84
# #cite_note-85
# /wiki/Tian%E2%80%99anmen-Massaker
# /wiki/Tian%E2%80%99anmen-Platz
# /w/index.php?title=China_Time&action=edit&redlink=1
# #cite_note-86
# /wiki/Lingang_New_City
# /wiki/Deutsche_Demokratische_Republik
# /wiki/Klaus_von_Dohnanyi
# /wiki/Erich_Honecker
# /wiki/Ost-Berlin
# #cite_note-87
# #cite_note-Lasse_Lassen_2017-83
# /wiki/Planten_un_Blomen
# /wiki/Tschechoslowakei
# /wiki/Henning_Voscherau
# /wiki/Oberb%C3%BCrgermeister
# /w/index.php?title=Jaroslav_Kor%C3%A1n&action=edit&redlink=1
# /wiki/Moldau_(Fluss)
# #cite_note-88
# #cite_note-Lasse_Lassen_2017-83
# /wiki/Yokohama
# /wiki/Kaohsiung
# /w/index.php?title=Republik_Taiwan_(China)&action=edit&redlink=1
# /wiki/Hafen_von_Shanghai
# /wiki/Montevideo
# /wiki/Uruguay
# /wiki/Shenzhen
# /wiki/Busan
# /wiki/S%C3%BCdkorea
# /wiki/Kanada
# /wiki/G%C3%B6teborg
# /wiki/Schweden
# #cite_note-89
# #cite_note-90
# #cite_note-91
# /wiki/Bezirk_Hamburg-Mitte
# /wiki/Hongkou
# /wiki/Bezirk_Eimsb%C3%BCttel
# /wiki/Warna
# /wiki/Bezirk_Wandsbek
# /wiki/London
# /wiki/Waltham_Forest
# #cite_note-92
# /wiki/W%C3%B6hrden
# /wiki/Dithmarschen
# /wiki/Schleswig-Holstein
# #cite_note-93
# /wiki/FabLab
# /wiki/Konsumg%C3%BCter
# #cite_note-94
# /wiki/Import
# /wiki/Abfallentsorgung
# /wiki/Open-Source-Hardware
# /wiki/Lokale_Produktion
# #cite_note-95
# /wiki/Datei:Wappen_der_Hamburgischen_B%C3%BCrgerschaft.svg
# /wiki/Datei:DEU_Hamburg_COA.svg
# /wiki/Datei:Hamburg-symbol.svg
# /wiki/Datei:Flagge_Hamburg.svg
# /wiki/Datei:Flag_of_Hamburg.svg
# /wiki/Datei:Admiralty_Coat_of_Arms_of_Hamburg.svg
# /wiki/Datei:Admiralty_flag_of_Hamburg.svg
# /wiki/Datei:Hamburg-logo.svg
# /wiki/Wappen
# /wiki/Flaggen
# /wiki/Wappenzeichen
# /wiki/Logografie
# /wiki/Stander
# /wiki/Hoheitszeichen
# /wiki/Verfassung_der_Freien_und_Hansestadt_Hamburg
# #cite_note-96
# /wiki/Hanseflaggen
# /wiki/Burg_(Heraldik)
# /wiki/Kreuz_(Heraldik)
# /wiki/Hamburger_Dom_(Alter_Mariendom)
# #cite_note-wappen-97
# /wiki/Peter_Schmidt_(Designer)
# /wiki/Weltoffenheit
# #cite_note-wappen-97
# #cite_note-wappen-97
# /wiki/Hamburgische_Admiralit%C3%A4t
# #cite_note-wappen-97
# /wiki/Landeswappen_Hamburgs
# /wiki/Liste_der_Flaggen_deutscher_L%C3%A4nder
# /wiki/Liste_der_Wappen_in_Deutschland
# /wiki/Landeshymne
# /wiki/Hamburg-Hymne
# /wiki/Hammonia
# /wiki/Latein
# /wiki/Jupiter_(Mythologie)
# /wiki/Hammaburg
# /wiki/Altniederdeutsche_Sprache
# /wiki/Kantate
# /wiki/Barthold_Heinrich_Brockes
# #cite_note-98
# /wiki/Allegorische_Malerei
# /wiki/Stadtpatron
# /wiki/Reformation
# /wiki/Maria_(Mutter_Jesu)
# /wiki/Hamburger_Dom_(Alter_Mariendom)
# /wiki/Hamburger_Rathaus
# /wiki/Libertatem_quam_peperere
# /wiki/Hamburger_Rathaus#Die_Vorgänger
# /wiki/Stadtstaat
# /wiki/Freie_Reichsstadt
# #cite_note-99
# /wiki/Freie_Stadt
# /wiki/Hansestadt
# #cite_note-100
# /wiki/Verfassung_der_Freien_und_Hansestadt_Hamburg
# /wiki/Hanseat#Auszeichnungen
# /wiki/Bundeskanzler_(Deutschland)
# /wiki/Helmut_Schmidt
# /wiki/Bundesverdienstorden
# /wiki/Senat_der_Freien_und_Hansestadt_Hamburg
# /wiki/Ehrenb%C3%BCrger
# /wiki/Liste_der_Ehrenb%C3%BCrger_von_Hamburg
# #cite_note-101
# /wiki/Portugaleser
# /wiki/B%C3%BCrgermeister-Stolten-Medaille
# /wiki/Biermann-Ratjen-Medaille
# /wiki/Lessing-Preis_der_Freien_und_Hansestadt_Hamburg
# /wiki/Bach-Preis_der_Freien_und_Hansestadt_Hamburg
# /wiki/Lichtwark-Preis
# /wiki/Fritz-Schumacher-Preis
# /wiki/Hubert-Fichte-Preis
# /wiki/Edwin-Scharff-Preis
# /wiki/Aby-M.-Warburg-Preis
# /wiki/Medaille_f%C3%BCr_treue_Arbeit_im_Dienste_des_Volkes
# #cite_note-102
# /wiki/Liste_staatlicher_Hamburger_Auszeichnungen
# /wiki/Hamburger_Sparkasse
# /wiki/Sparkasse_Harburg-Buxtehude
# #cite_note-103
# #cite_note-104
# /wiki/Beh%C3%B6rde_f%C3%BCr_Arbeit,_Gesundheit,_Soziales,_Familie_und_Integration
# /wiki/Beh%C3%B6rde_f%C3%BCr_Inneres_und_Sport
# /wiki/Agentur_f%C3%BCr_Arbeit
# /wiki/Jobcenter
# #cite_note-105
# /wiki/Kultur_in_Hamburg
# /wiki/Datei:Hamburg.jpg
# /wiki/Datei:Hamburg.jpg
# https://tools.wmflabs.org/zoomviewer/?flash=no&f=Hamburg.jpg
# /wiki/Theater
# /wiki/Museum
# /wiki/Musikverlag
# /wiki/Initiative_Musik
# #cite_note-fazemag_20210920-106
# #cite_note-clubstudie_2021-107
# #cite_note-Kulturbericht-108
# /wiki/Kino
# /wiki/Programmkino
# #cite_note-Kulturbericht-108
# #cite_note-109
# /wiki/Deutsche_Zentrale_f%C3%BCr_Tourismus
# /wiki/Miniatur_Wunderland
# /wiki/Beliebteste_Sehensw%C3%BCrdigkeiten_Deutschlands_(DZT)
# /wiki/Hamburger_K%C3%BCche
# /wiki/Birnen,_Bohnen_und_Speck
# /wiki/Scholle_Finkenwerder_Art
# /wiki/Stint
# /wiki/Gr%C3%BCnkohl
# /wiki/Aalsuppe#Hamburger_Aalsuppe
# /wiki/Labskaus
# /wiki/Snuten_un_Poten
# /wiki/Rundst%C3%BCck_warm
# /wiki/Rote_Gr%C3%BCtze
# /wiki/Schwarzsauer
# /wiki/Franzbr%C3%B6tchen
# /wiki/Hamburgensie
# /wiki/Hymne
# /wiki/Hamburg-Hymne
# /wiki/Hans_Albers
# /wiki/Heidi_Kabel
# /wiki/Shanty
# /wiki/Hamborger_Veermaster
# /wiki/Pankokenkapelle
# /wiki/An_de_Eck_steiht%E2%80%99n_Jung_mit%E2%80%99n_T%C3%BCdelband
# /wiki/Gebr%C3%BCder_Wolf
# /wiki/Lotto_King_Karl
# /wiki/Blumfeld
# /wiki/Die_Sterne
# /wiki/Tocotronic
# /wiki/Hamburger_Schule_(Popmusik)
# /wiki/Kettcar_(Band)
# /wiki/Tomte
# /wiki/Hip-Hop
# /wiki/Beginner
# /wiki/Samy_Deluxe
# /wiki/Fettes_Brot
# /wiki/Udo_Lindenberg
# /wiki/Hamburger_Szene
# /wiki/Datei:GraffitoHH.jpg
# /wiki/Datei:GraffitoHH.jpg
# /wiki/Hamburger_Gru%C3%9F
# /wiki/Hans_Hummel_(Stadtoriginal)
# /wiki/Plattdeutsch
# /wiki/G%C3%B6tz-Zitat
# /wiki/Hamburg-Neustadt
# /wiki/Wassertr%C3%A4ger
# /wiki/Moin
# /wiki/Tsch%C3%BCs
# /wiki/G%C3%B6re
# /wiki/Klein_Erna
# /wiki/Vera_M%C3%B6ller
# /wiki/Lakonisch
# /wiki/Pointe
# /wiki/He_l%C3%BCcht
# /wiki/Hamburger_Hafenrundfahrten
# /wiki/Aalsuppe
# /wiki/Trockenobst
# /wiki/DR_877
# /wiki/Deutsche_Reichsbahn_(1920%E2%80%931945)
# /wiki/Stromlinienzug
# /wiki/Datei:Timbre_de_Bergedorf.jpg
# /wiki/Datei:Timbre_de_Bergedorf.jpg
# /wiki/Dauermarke
# /wiki/Postgeschichte_und_Briefmarken_Bergedorfs
# /wiki/Postgeschichte_und_Briefmarken_Hamburgs
# /wiki/Postgeschichte_und_Briefmarken_Bergedorfs
# /wiki/Briefmarke
# /wiki/Datei:Hafengeburtstag_2017.jpg
# /wiki/Datei:Hafengeburtstag_2017.jpg
# /wiki/Hafengeburtstag
# /wiki/Altonaer_Fischmarkt
# /wiki/Hamburger_Dom_(Volksfest)
# /wiki/Jahrmarkt
# /wiki/Hafengeburtstag
# /wiki/Alstervergn%C3%BCgen
# /wiki/Binnenalster
# #cite_note-110
# /wiki/Filmfest_Hamburg
# /wiki/CineFest
# /wiki/Lesbisch_Schwule_Filmtage_Hamburg
# /wiki/Fantasy_Filmfest
# /wiki/Christopher_Street_Day
# /wiki/Harley-Davidson
# /wiki/Motorrad
# /wiki/Motorradgottesdienst
# /wiki/Altonale
# /wiki/Hamburger_Weihnachtsmarkt
# /wiki/Arabische_Kulturwochen_Hamburg
# /wiki/Datei:Hamburg_-_Wunder_von_Bern_-_K%C3%B6nig_der_L%C3%B6wen_-_2016.jpg
# /wiki/Datei:Hamburg_-_Wunder_von_Bern_-_K%C3%B6nig_der_L%C3%B6wen_-_2016.jpg
# /wiki/Theater_im_Hafen_Hamburg
# /wiki/Musical
# /wiki/New_York_City
# /wiki/Stage_Entertainment
# /wiki/Operettenhaus
# /wiki/Neue_Flora
# /wiki/Theater_im_Hafen_Hamburg
# /wiki/Theater_an_der_Elbe
# /wiki/Joop_van_den_Ende_Academy
# /wiki/Stage_School
# /wiki/St._Pauli_Theater
# /wiki/Delphi_Showpalast
# /wiki/Schmidt_Theater
# /wiki/Heiligengeistfeld
# #cite_note-111
# #cite_note-112
# /wiki/Hamburg-Hammerbrook
# #cite_note-113
# /wiki/Andrew_Lloyd_Webber
# /wiki/Cats
# /wiki/Friedrich_Kurz
# #cite_note-abendblatt.de-114
# /wiki/Das_Phantom_der_Oper_(Musical)
# #cite_note-abendblatt.de-114
# /wiki/Das_Phantom_der_Oper_(Musical)
# /wiki/Buddy_(Musical)
# /wiki/Tanz_der_Vampire_(Musical)
# /wiki/Dirty_Dancing_(Musical)
# /wiki/Mamma_Mia!_(Musical)
# /wiki/Ich_war_noch_niemals_in_New_York_(Musical)
# /wiki/Sister_Act_(Musical)
# /wiki/Tarzan_(Musical)
# /wiki/Der_K%C3%B6nig_der_L%C3%B6wen_(Musical)
# /wiki/Pretty_Woman_(Musical)
# /wiki/Theater_an_der_Elbe
# /wiki/Datei:Bundesarchiv_B_145_Bild-F004311-0001,_Hamburg,_Staatsoper,_Zuschauerraum.jpg
# /wiki/Datei:Bundesarchiv_B_145_Bild-F004311-0001,_Hamburg,_Staatsoper,_Zuschauerraum.jpg
# /wiki/Datei:Hamburg_Staatsoper_au%C3%9Fen_nachts_1.jpg
# /wiki/Datei:Hamburg_Staatsoper_au%C3%9Fen_nachts_1.jpg
# /wiki/Hamburgische_Staatsoper
# /wiki/Hamburgische_Staatsoper
# /wiki/Johann_Adam_Reincken
# /wiki/Oper_am_G%C3%A4nsemarkt
# /wiki/Georg_Friedrich_H%C3%A4ndel
# /wiki/Georg_Philipp_Telemann
# /wiki/Carl_Ludwig_Wimmel
# /wiki/Martin_Haller_(Architekt)
# /wiki/Montserrat_Caball%C3%A9
# /wiki/Pl%C3%A1cido_Domingo
# /wiki/Luciano_Pavarotti
# /wiki/Mirella_Freni
# /wiki/Birgit_Nilsson
# /wiki/Maria_Callas
# /wiki/Kent_Nagano
# /wiki/Philharmoniker_Hamburg
# /wiki/Georges_Delnon
# /wiki/Simone_Young
# /wiki/Hamburg_Ballett
# /wiki/John_Neumeier
# /wiki/Ballettschule_des_Hamburg_Ballett
# /wiki/Hamburg-Hamm
# /wiki/Datei:Laeiszhalle_-_Musikhalle.jpg
# /wiki/Datei:Laeiszhalle_-_Musikhalle.jpg
# /wiki/Laeiszhalle
# /wiki/Datei:Elbphilharmonie,_Hamburg.jpg
# /wiki/Datei:Elbphilharmonie,_Hamburg.jpg
# /wiki/Elbphilharmonie
# /wiki/Laeiszhalle
# /wiki/Carl_Laeisz
# /wiki/Martin_Haller_(Architekt)
# /wiki/Wilhelm_Emil_Meerwein
# /wiki/Johannes-Brahms-Platz
# #cite_note-115
# /wiki/Elbphilharmonie
# /wiki/Hamburg-HafenCity
# #cite_note-116
# #cite_note-117
# /wiki/Basel
# /wiki/Herzog_%26_de_Meuron
# /wiki/Datei:Hamburg_Deutsches_Schauspielhaus_9438.jpg
# /wiki/Datei:Hamburg_Deutsches_Schauspielhaus_9438.jpg
# /wiki/Deutsches_Schauspielhaus
# /wiki/Deutsches_Schauspielhaus
# /wiki/Thalia_Theater_(Hamburg)
# /wiki/Ohnsorg-Theater
# /wiki/Kampnagel
# /wiki/Kultur_in_Hamburg#Theater
# /wiki/Hamburger_Volksb%C3%BChne
# /wiki/Verein
# /wiki/TheaterGemeinde_Hamburg
# /wiki/Hamburger_%C3%96ffentliche_B%C3%BCcherhallen
# /wiki/Blu-ray_Disc
# /wiki/DVD
# #cite_note-118
# /wiki/Datei:Hamburg_Kunsthalle_2599.jpg
# /wiki/Datei:Hamburg_Kunsthalle_2599.jpg
# /wiki/Kunsthalle_Hamburg
# #cite_note-Kulturbericht-108
# /wiki/Hamburger_Kunsthalle
# /wiki/Museum_f%C3%BCr_Kunst_und_Gewerbe
# /wiki/Deichtorhallen
# /wiki/Bucerius_Kunst_Forum
# /wiki/Museum_f%C3%BCr_Hamburgische_Geschichte
# /wiki/Museum_der_Arbeit
# /wiki/Museum_am_Rothenbaum
# /wiki/Planetarium_Hamburg
# /wiki/Miniatur_Wunderland
# /wiki/Panoptikum_Hamburg
# /wiki/Internationales_Maritimes_Museum_Hamburg
# /wiki/Hamburger_Hafen#Kultur
# /wiki/BallinStadt
# /wiki/KZ_Neuengamme
# /wiki/Liste_der_Museen_in_Hamburg
# /wiki/Datei:Hamburg-Radisson-Telemichel.jpg
# /wiki/Au%C3%9Fenalster
# /wiki/Datei:Hh_kbrue.jpg
# /wiki/K%C3%B6hlbrandbr%C3%BCcke
# /wiki/Datei:Nikolaikirche001.jpg
# /wiki/Ehemalige_Hauptkirche_St._Nikolai_(Hamburg)
# /wiki/Neuwerk
# /wiki/Elbe
# /wiki/Leuchtturm_Neuwerk
# /wiki/Kirche_Sinstorf
# /wiki/Hamburg-Sinstorf
# /wiki/Datei:Grundtri%C3%9F_der_edlen_weitberumbte_Statt_Hamburg_Anno_1651.jpg
# /wiki/Datei:Grundtri%C3%9F_der_edlen_weitberumbte_Statt_Hamburg_Anno_1651.jpg
# /wiki/Datei:Hamburg,_Speicherstadt,_Wasserschloss_--_2016_--_2944-50_(cropped).jpg
# /wiki/Datei:Hamburg,_Speicherstadt,_Wasserschloss_--_2016_--_2944-50_(cropped).jpg
# /wiki/Wasserschloss_(Hamburg)
# /wiki/Speicherstadt
# /wiki/Hamburger_Hauptkirchen
# /wiki/Hauptkirche_Sankt_Petri_(Hamburg)
# /wiki/Hauptkirche_Sankt_Jacobi_(Hamburg)
# /wiki/Hauptkirche_Sankt_Katharinen_(Hamburg)
# /wiki/Hauptkirche_Sankt_Michaelis_(Hamburg)
# /wiki/Wahrzeichen
# /wiki/Ehemalige_Hauptkirche_St._Nikolai_(Hamburg)
# /wiki/Hamburger_Rathaus
# /wiki/Hamburger_B%C3%B6rse
# /wiki/Skyline
# /wiki/Hamburger_Wallanlagen
# /wiki/D%C3%A4nemark
# /wiki/Lombardsbr%C3%BCcke
# /wiki/Lombardsbr%C3%BCcke#Kennedybrücke
# /wiki/Planten_un_Blomen
# /wiki/Alter_Elbpark
# /wiki/St._Pauli-Landungsbr%C3%BCcken
# /wiki/Fleet
# /wiki/Deichstra%C3%9Fe_(Hamburg)
# /wiki/Nikolaifleet
# /wiki/G%C3%A4ngeviertel_(Hamburg)
# /wiki/Krameramtsstuben
# /wiki/Datei:Hamburg_Jungfernstieg_(1890-1900).jpg
# /wiki/Datei:Hamburg_Jungfernstieg_(1890-1900).jpg
# /wiki/Alsterpavillon
# /wiki/Altonaer_Rathaus
# /wiki/Hamburg-Altona-Altstadt
# /wiki/Hamburg-Altona#Geschichte
# /wiki/Hamburger_Sternwarte
# /wiki/Universit%C3%A4t_Hamburg
# #cite_note-119
# /wiki/Binnenalster
# /wiki/Jungfernstieg
# /wiki/Ballindamm
# /wiki/Alsterarkaden
# /wiki/Colonnaden
# /wiki/Speicherstadt
# /wiki/St._Pauli-Landungsbr%C3%BCcken
# /wiki/St._Pauli-Elbtunnel
# /wiki/Altonaer_Fischmarkt
# /wiki/Fischauktionshalle
# /wiki/Hamburg-Blankenese
# /wiki/Speicherstadt
# /wiki/Kontorhausviertel
# /wiki/UNESCO-Welterbe
# #cite_note-UNESCO-en-19
# #cite_note-UNESCO-de-120
# /wiki/Backstein
# /wiki/Klinker
# #cite_note-UNESCO-de-120
# /wiki/Chilehaus
# /wiki/Backsteinexpressionismus
# /wiki/Hamburger_Innenstadt
# /wiki/Hamburg_Hauptbahnhof
# /wiki/Bahnhof_Hamburg_Dammtor
# /wiki/Curiohaus
# /wiki/Justizforum_Hamburg
# /wiki/Hanseatisches_Oberlandesgericht
# /wiki/Laeiszhalle
# /wiki/Hamburg-Eimsb%C3%BCttel
# /wiki/Grindel_(Hamburg)
# /wiki/Hamburg-Eppendorf
# /wiki/Harvestehude
# /wiki/Elbvororte
# /wiki/Emporio-Hochhaus
# /wiki/Mundsburg
# /wiki/Heinrich-Hertz-Turm
# /wiki/Rundfunksender_Billwerder-Moorfleet
# /wiki/K%C3%B6hlbrandbr%C3%BCcke
# /wiki/Hamburger_Stadtpark
# /wiki/City_Nord
# #cite_note-121
# /wiki/Andreas_Dressel
# /wiki/Grundsteuer_C
# #cite_note-122
# /wiki/Hamburg-HafenCity
# /wiki/Elbphilharmonie
# /wiki/U-Bahn-Linie_4_(Hamburg)
# /wiki/Datei:S%C3%BCllberg_(Blankenese).JPG
# /wiki/S%C3%BCllberg_(Hamburg)
# /wiki/Blankenese
# /wiki/Datei:Rathaus_Altona_o.jpg
# /wiki/Altonaer_Rathaus
# /wiki/Datei:Kontorhaus_Stubbenhuk_neu.JPG
# /wiki/Datei:Elbbr%C3%BCcken_mit_Cruise_Center.JPG
# /wiki/Datei:Elbbr%C3%BCcken_mit_Cruise_Center.JPG
# /wiki/Hamburg_Cruise_Center_HafenCity
# /wiki/Liste_von_Br%C3%BCcken_in_Hamburg
# /wiki/Binnendelta
# /wiki/Elbe
# /wiki/Niederung
# /wiki/Alster
# /wiki/Bille
# /wiki/Fleet
# /wiki/Kanal_(Wasserbau)
# /wiki/Stra%C3%9Fennetz
# /wiki/Schienennetz
# /wiki/Hochbahn
# /wiki/U-Bahn_Hamburg
# /wiki/Landesbetrieb_Stra%C3%9Fen,_Br%C3%BCcken_und_Gew%C3%A4sser
# /wiki/Lichtes_Ma%C3%9F
# /wiki/St%C3%BCtzweite
# /wiki/Tunnel
# /wiki/Deutsche_Bahn
# #cite_note-123
# /wiki/Hamburg_Port_Authority
# /wiki/Hamburger_Hafenbahn
# /wiki/Hamburger_Hochbahn
# /wiki/AKN_Eisenbahn
# /wiki/Hagenbecks_Tierpark
# /wiki/Rohrunterst%C3%BCtzung
# /wiki/Fernw%C3%A4rme
# /wiki/Wasserleitung
# /wiki/Autobahn
# /wiki/Flughafen
# /wiki/Hamburg-Fuhlsb%C3%BCttel
# /wiki/Gunter_Demnig
# #cite_note-124
# /wiki/Stolpersteine
# /wiki/Zeit_des_Nationalsozialismus
# /wiki/Liste_der_Stolpersteine_in_Hamburg
# /wiki/Datei:Alte_Wallgraben_in_Planten_un_Blomen.jpg
# /wiki/Datei:Alte_Wallgraben_in_Planten_un_Blomen.jpg
# /wiki/Park
# #cite_note-125
# /wiki/Altonaer_Volkspark
# /wiki/Hamburger_Stadtpark
# /wiki/Planten_un_Blomen
# /wiki/Loki-Schmidt-Garten
# /wiki/Jenischpark
# /wiki/Vierlande
# /wiki/Marschlande
# /wiki/Hektar
# /wiki/Friedhof_Ohlsdorf
# /wiki/Alsterpark
# /wiki/Alster
# /wiki/Tierpark_Hagenbeck
# /wiki/Carl_Hagenbeck
# /wiki/Tierpark
# /wiki/Sport_in_Hamburg
# /wiki/Fu%C3%9Fball_in_Hamburg
# /wiki/Datei:Volksparkstadion_Panorama.jpg
# /wiki/Datei:Volksparkstadion_Panorama.jpg
# /wiki/Volksparkstadion
# /wiki/Hamburger_SV
# /wiki/Barclays_Arena
# /wiki/Volksparkstadion
# /wiki/Barclays_Arena
# /wiki/Alsterschwimmhalle
# /wiki/Sporthalle_Hamburg
# /wiki/Millerntor-Stadion
# /wiki/Hamburger_Stadtpark
# /wiki/Hamburger_Turnerschaft_von_1816
# /wiki/Hamburger_SV
# /wiki/Fu%C3%9Fball-Bundesliga
# /wiki/FC_St._Pauli
# /wiki/Hockey
# /wiki/Der_Club_an_der_Alster
# /wiki/Harvestehuder_THC
# /wiki/Uhlenhorster_HC
# /wiki/Unihockey
# /wiki/Eimsb%C3%BCtteler_TV
# /wiki/Unihockey-Bundesliga
# /wiki/Basketball
# /wiki/Hamburg_Towers
# /wiki/ProA
# /wiki/Basketball-Bundesliga
# /wiki/Baseball
# /wiki/Hamburg_Stealers
# /wiki/American_Football
# /wiki/Hamburg_Huskies
# /wiki/German_Football_League
# /wiki/Handball_Sport_Verein_Hamburg
# /wiki/Handball-Bundesliga
# /wiki/2._Handball-Bundesliga
# /wiki/Hamburg_Freezers
# /wiki/Deutsche_Eishockey_Liga
# /wiki/TV_Fischbek#Volleyball_(Frauen)
# /w/index.php?title=CU-Arena&action=edit&redlink=1
# /wiki/Hamburg-Marathon
# /wiki/Hamburg_Triathlon
# /wiki/Ironman_Hamburg
# /wiki/Vattenfall_Cyclassics
# /wiki/HSH_Nordbank_Run
# /wiki/Pferdesport_in_Hamburg
# /wiki/Deutsches_Derby
# /wiki/Deutsches_Spring_Derby
# /wiki/ATP_Hamburg
# /wiki/Fu%C3%9Fball-Weltmeisterschaft_1974
# /wiki/Fu%C3%9Fball-Weltmeisterschaft_2006
# /wiki/Handball-Weltmeisterschaft_der_M%C3%A4nner_2007
# /wiki/International_Triathlon_Union
# /wiki/Triathlon
# /wiki/Europa_League
# /wiki/Snooker
# /wiki/SC_Hamburg
# /wiki/1._Bundesliga_Snooker
# /wiki/Squash
# /wiki/Sportwerk_Hamburg_Waldd%C3%B6rfer
# /wiki/Billard
# /wiki/BC_Queue_Hamburg
# /wiki/2._Bundesliga_Pool
# /wiki/Sektion_Hamburg_und_Niederelbe_des_Deutschen_Alpenvereins
# /wiki/Sektion_(Alpenverein)
# /wiki/Liste_der_Sektionen_des_Deutschen_Alpenvereins
# /wiki/Schutzh%C3%BCtte
# /wiki/K%C3%BCnstliche_Kletteranlage
# #cite_note-126
# /wiki/Deutscher_Alpenverein
# /wiki/Klettern
# /wiki/Bouldern
# #cite_note-127
# /wiki/Olympische_Sommerspiele_2024
# /wiki/Hamburger_Olympia-B%C3%BCrgerschaftsreferendum
# /wiki/Olympische_Sommerspiele_2012
# /wiki/Leipzig
# /wiki/Hamburger_SV
# #cite_note-128
# /wiki/Basketball-Bundesliga
# /wiki/Basketball-Bundesliga_2019/20
# /wiki/Logistik
# /wiki/Maritime_Wirtschaft
# /wiki/Luftfahrtindustrie
# /wiki/Konsumg%C3%BCterindustrie
# /wiki/Chemie
# /wiki/Elektrotechnik
# /wiki/Maschinenbau
# /wiki/Fahrzeugbau
# /wiki/Schiffbau
# /wiki/Mineral%C3%B6l
# /wiki/Kreditinstitut
# /wiki/Massenmedien
# /wiki/Versicherer
# /wiki/Tourismus
# /wiki/Erneuerbare_Energien
# /wiki/Life_Sciences
# /wiki/Zukunftsatlas
# #cite_note-129
# /wiki/Handelskammer_Hamburg
# /wiki/Hamburger_B%C3%B6rse
# /wiki/Land_(Deutschland)
# /wiki/Bruttoinlandsprodukt
# /wiki/Bruttowertsch%C3%B6pfung
# /wiki/Europ%C3%A4ische_Union
# /wiki/Luxemburg
# /wiki/Kaufkraftstandard
# #cite_note-130
# /wiki/Kaufkraft_(Konsum)
# #cite_note-GfK_Kaufkraft_2021-2
# /wiki/Bayern
# /wiki/Baden-W%C3%BCrttemberg
# /wiki/Hessen
# /wiki/NUTS
# #cite_note-131
# /wiki/Senat_der_Freien_und_Hansestadt_Hamburg
# /wiki/Wahlspruch
# /wiki/Metropole
# /wiki/Endogen
# #cite_note-HK-CHINA-132
# #cite_note-HK-2030-133
# #cite_note-134
# #cite_note-135
# #cite_note-136
# /wiki/Statistisches_Bundesamt
# #cite_note-SchuldenstatistikInfo-137
# /wiki/GENESIS_(Statistik)
# #cite_note-Schuldenstatistik-138
# /wiki/%C3%96ffentlicher_Haushalt
# /wiki/B%C3%BCrgschaft_(Deutschland)
# #cite_note-139
# /wiki/HSH_Nordbank
# #cite_note-140
# #cite_note-141
# #cite_note-142
# #cite_note-143
# /wiki/DAX
# /wiki/MDAX
# /wiki/SDAX
# /wiki/Beiersdorf_AG
# /wiki/Alstria_office
# /wiki/Aurubis
# /wiki/Evotec
# /wiki/TAG_Immobilien
# /wiki/Deutsche_EuroShop
# /wiki/Encavis
# /wiki/Fielmann
# /wiki/Hamburger_Hafen_und_Logistik
# /wiki/Jungheinrich
# /wiki/XING
# /wiki/Airbus
# /wiki/Asklepios_Kliniken_Hamburg
# /wiki/Universit%C3%A4tsklinikum_Hamburg-Eppendorf
# #cite_note-144
# /wiki/HGV_(Unternehmen)
# /wiki/Medien_in_Hamburg
# /wiki/%C3%96ffentlicher_Personennahverkehr
# /wiki/Modal_Split
# #cite_note-Verkehr-2008-145
# /wiki/Berlin
# /wiki/Frankfurt_am_Main
# /wiki/M%C3%BCnchen
# /wiki/K%C3%B6ln
# #cite_note-146
# /wiki/Datei:Hamburg_Autobahnen.svg
# /wiki/Datei:Hamburg_Autobahnen.svg
# /wiki/Kraftfahrzeug
# /wiki/Personenkraftwagen
# #cite_note-147
# /wiki/Autobahn_(Deutschland)
# /wiki/Bundesautobahn_1
# /wiki/Europastra%C3%9Fe
# /wiki/Europastra%C3%9Fe_22
# /wiki/Bundesautobahn_7
# /wiki/Europastra%C3%9Fe_45
# /wiki/Bundesautobahn_23
# /wiki/Bundesautobahn_24
# /wiki/Europastra%C3%9Fe_26
# /wiki/Bundesautobahn_25
# /wiki/Bundesautobahn_252
# /wiki/Bundesautobahn_253
# /wiki/Bundesautobahn_255
# /wiki/Bundesautobahn_20
# /wiki/Prenzlau
# /wiki/Rostock
# /wiki/Bad_Segeberg
# /wiki/Umland
# /wiki/Bundesautobahn_26
# /wiki/Stade
# /wiki/Wesertunnel
# /wiki/Bundesautobahn_28
# /wiki/Bundesautobahn_29
# /wiki/Bundesstra%C3%9Fe
# /wiki/Bundesstra%C3%9Fe_3
# /wiki/Bundesstra%C3%9Fe_4
# /wiki/Bundesstra%C3%9Fe_5
# /wiki/Bundesstra%C3%9Fe_73
# /wiki/Bundesstra%C3%9Fe_75
# /wiki/Bundesstra%C3%9Fe_207
# /wiki/Bundesstra%C3%9Fe_431
# /wiki/Bundesstra%C3%9Fe_432
# /wiki/Bundesstra%C3%9Fe_433
# /wiki/Bundesstra%C3%9Fe_447
# /wiki/Radius
# /wiki/Tangente
# /wiki/Durchgangsverkehr
# /wiki/Stra%C3%9Fenring
# /wiki/Ring_1_(Hamburg)
# /wiki/Ring_2_(Hamburg)
# #cite_note-148
# /wiki/Tempo-30-Zone
# #cite_note-149
# #cite_note-150
# #cite_note-151
# /wiki/Datei:Hamburger_Fahrradh%C3%A4uschen2.jpg
# /wiki/Datei:Hamburger_Fahrradh%C3%A4uschen2.jpg
# /wiki/Datei:StadtRad_Station_Baumwall_Hafengeburtstag_2018.jpg
# /wiki/Datei:StadtRad_Station_Baumwall_Hafengeburtstag_2018.jpg
# /wiki/Fahrradklimatest
# /wiki/ADFC
# #cite_note-152
# /wiki/StadtRAD_Hamburg
# /wiki/Hamburger_Fahrradh%C3%A4uschen
# /wiki/Hamburg-Nord
# /wiki/Vandalismus
# /wiki/Velorouten_in_Hamburg
# /wiki/Fahrradstra%C3%9Fe
# /wiki/Wandse
# /wiki/Falkenstein_(Hamburg)#Falkensteiner_Ufer
# /wiki/Elberadweg
# #cite_note-153
# #cite_note-154
# /wiki/Einbahnstra%C3%9Fe
# #cite_note-155
# /wiki/Radfahrstreifen
# /wiki/Schutzstreifen_f%C3%BCr_Radfahrer
# #cite_note-156
# #cite_note-157
# /wiki/EuroVelo
# /wiki/Nordseek%C3%BCsten-Radweg
# #cite_note-158
# /wiki/Elberadweg
# #cite_note-159
# /wiki/Radfernweg_Hamburg%E2%80%93Bremen
# #cite_note-160
# /wiki/Senat_Scholz_II
# #cite_note-161
# /wiki/Radschnellweg
# /wiki/Loop_(Hamburg)
# /wiki/Deutscher_Fahrradpreis
# /wiki/Schienenverkehr_in_Hamburg
# /wiki/Datei:Hamburg_Hauptbahnhof_(13376981883).jpg
# /wiki/Datei:Hamburg_Hauptbahnhof_(13376981883).jpg
# /wiki/Hamburg_Hauptbahnhof
# /wiki/Eisenbahn
# /wiki/Nordeuropa
# #cite_note-162
# /wiki/Hamburg-Bergedorfer_Eisenbahn
# /wiki/Schienenpersonenfernverkehr
# /wiki/Intercity-Express
# /wiki/Liste_der_Intercity-Express-Linien
# /wiki/Intercity_(Deutschland)
# /wiki/Liste_der_Intercity-Linien_(Deutschland)
# /wiki/Kopenhagen
# /wiki/Basel
# /wiki/Breslau
# /wiki/Wien
# /wiki/Z%C3%BCrich
# /wiki/Hamburg_Hauptbahnhof
# /wiki/Bahnhof_Hamburg-Altona
# /wiki/Bahnhof_Hamburg_Dammtor
# /wiki/Bahnhof_Hamburg-Harburg
# /wiki/Bahnhof_Hamburg-Bergedorf
# /wiki/Zentraler_Omnibusbahnhof_Hamburg
# /wiki/Fernbusse_in_Deutschland
# /wiki/Baltikum
# /wiki/Polen
# /wiki/Maschen
# /wiki/Rangierbahnhof
# /wiki/Maschen_Rangierbahnhof
# /wiki/Hamburger_Hafenbahn
# /wiki/Hamburger_Hafen
# /wiki/Nahverkehr_in_Hamburg
# /wiki/Regionalbahn
# /wiki/Regional-Express
# /wiki/Elmshorn
# /wiki/Padborg
# /wiki/Stade
# /wiki/Cuxhaven
# /wiki/L%C3%BCneburg
# /wiki/%C3%96ffentlicher_Personennahverkehr
# /wiki/Schnellbahn#Stadtschnellbahn
# /wiki/S-Bahn_Hamburg
# /wiki/U-Bahn_Hamburg
# /wiki/Schnellbahn
# /wiki/AKN_Eisenbahn
# /wiki/Hamburg-HafenCity
# /wiki/Speicherstadt
# /wiki/Jungfernstieg
# /wiki/U-Bahn-Linie_4_(Hamburg)
# /wiki/U-Bahnhof_Billstedt
# /wiki/Stadtbus
# /wiki/Metrobus
# /wiki/Schnellbus
# /wiki/F%C3%A4hre
# /wiki/Nachtverkehr
# /wiki/Stra%C3%9Fenbahn_Hamburg
# /wiki/Stadtbahn_Hamburg
# /wiki/Hamburger_Verkehrsverbund
# /wiki/Verkehrsverbund
# /wiki/L%C3%A4nderticket
# /wiki/Datei:Bahnlinien_im_HVV.png
# /wiki/Hamburger_Verkehrsverbund
# /wiki/Datei:HHA_DT5_-_306-III.JPG
# /wiki/U-Bahn_Hamburg
# /wiki/HHA_Typ_DT5
# /wiki/Hamburger_Hochbahn
# /wiki/Datei:DB_490117_Near_Harburg.jpg
# /wiki/DB-Baureihe_490
# /wiki/Datei:HADAG_Elbphilharmonie.jpg
# /wiki/Datei:HADAG_Elbphilharmonie.jpg
# /wiki/Niederelbe
# /wiki/Nordsee
# /wiki/Seeschiff
# /wiki/Ostsee
# /wiki/Nord-Ostsee-Kanal
# /wiki/Hamburg_Cruise_Center
# /wiki/Wasserstra%C3%9Fe
# /wiki/Binnenschifffahrt
# /wiki/Elbe
# /wiki/Binnenwasserstra%C3%9Fe
# /wiki/Unterelbe
# /wiki/Elbe
# /wiki/Elbe-L%C3%BCbeck-Kanal
# /wiki/Elbe-Seitenkanal
# /wiki/Mittellandkanal
# /wiki/HADAG_Seetouristik_und_F%C3%A4hrdienst
# /wiki/Teufelsbr%C3%BCck
# /wiki/St._Pauli-Landungsbr%C3%BCcken
# /wiki/Schulau_(Wedel)
# /wiki/L%C3%BChe_(Jork)
# /wiki/Alsterdampfer
# /wiki/Hamburger_Hafen
# /wiki/Seehafen
# /wiki/Hafen_Rotterdam
# /wiki/Hafen_Antwerpen
# #cite_note-verkehrsrundschau_130213-163
# /wiki/Teppich
# /wiki/Hamburger_Hafen_und_Logistik
# /wiki/Eurogate
# /wiki/Hektar
# /wiki/Hamburger_Hafenrundfahrten
# /wiki/Barkasse
# /wiki/Raddampfer
# /wiki/Altonaer_Balkon
# /wiki/Elbvertiefung
# /wiki/JadeWeserPort
# /wiki/Hamburg-HafenCity
# #cite_note-164
# /wiki/Datei:Port_hamburg_panorama.jpg
# /wiki/Datei:HamburgerHafenLuftbild.jpg
# /wiki/Datei:Lufthansa_Technik_Hamburg_-_Airbus_A340.jpg
# /wiki/Datei:Lufthansa_Technik_Hamburg_-_Airbus_A340.jpg
# /wiki/Airbus_A340
# /wiki/Lufthansa_Technik
# /wiki/Flughafen_Hamburg
# /wiki/Helmut_Schmidt
# /wiki/Hamburg-Fuhlsb%C3%BCttel
# #cite_note-165
# /wiki/Dubai
# /wiki/New_York_City
# /wiki/Teheran
# /wiki/S-Bahn_Hamburg
# /wiki/Hamburger_Verkehrsverbund
# /wiki/Fernbus
# /wiki/Lufthansa_Technik
# /wiki/Einflugschneise
# /wiki/Nachtflugverbot
# /wiki/Flughafen_Kaltenkirchen
# /wiki/Kaltenkirchen
# /wiki/Airbus
# /wiki/Airbus_Group
# /wiki/Flugplatz_Hamburg-Finkenwerder
# /wiki/Airbus-A320-Familie
# /wiki/Toulouse
# /wiki/Airbus_A380
# /wiki/Airbus_Beluga
# /wiki/Flughafen_L%C3%BCbeck
# #cite_note-166
# /wiki/Billigfluggesellschaft
# /wiki/Ryanair
# /wiki/Datei:Pincerno_-_Wasserwerke_2009.png
# /wiki/Datei:Pincerno_-_Wasserwerke_2009.png
# /wiki/Wasserversorgung_in_Hamburg
# /wiki/Gleichordnungskonzern
# /wiki/Hamburg_Wasser
# #cite_note-167
# /wiki/Fernw%C3%A4rme
# /wiki/Hamburgische_Electricit%C3%A4ts-Werke
# #cite_note-168
# /wiki/Gaskraftwerk_Moorburg
# /wiki/Kohlekraftwerk_Moorburg
# #cite_note-:2-169
# /wiki/Aurubis
# /wiki/Abw%C3%A4rme
# /wiki/Kohlenstoffdioxid
# #cite_note-170
# /wiki/Datei:Hh-affi.jpg
# /wiki/Datei:Hh-affi.jpg
# /wiki/Airbus#Deutschland
# #cite_note-171
# /wiki/Diehl_Aerosystems
# /wiki/Werften_in_Hamburg
# /wiki/Blohm_%26_Voss
# /wiki/J._J._Sietas
# /wiki/Norderwerft
# /wiki/Neuenfelder_Maschinenfabrik
# /wiki/Muehlhan
# /wiki/Beiersdorf_AG
# /wiki/Nivea
# /wiki/Tesa
# /wiki/Mercedes-Benz_Cars#Mercedes-Benz_Werk_Hamburg
# /wiki/Daimler_AG
# /wiki/Vidal_%26_Sohn_Tempo-Werk
# /wiki/Harburger_Transporter
# /wiki/Philips
# /wiki/Philips_Deutschland
# /wiki/NXP_Semiconductors
# /wiki/Aurubis
# /wiki/Peute
# /wiki/Trimet_Aluminium
# /wiki/ArcelorMittal
# /wiki/Erd%C3%B6lraffinerie
# /wiki/Deutsche_Tamoil
# /wiki/H%26R_(Unternehmen)
# /wiki/Nynas
# /wiki/Sasol
# /wiki/K%C3%B6rber_AG
# /wiki/Hauni_Maschinenbau
# /wiki/Hidden_Champions
# /wiki/Harburg-Freudenberger
# /wiki/BW_Papersystems_Hamburg
# /wiki/Jungheinrich
# /wiki/Still_GmbH
# /wiki/Steinway_%26_Sons
# /wiki/Montblanc_(Unternehmen)
# /wiki/Wempe_Chronometerwerke
# /wiki/Dolmar_GmbH
# /wiki/Archer_Daniels_Midland
# /wiki/Nestl%C3%A9
# /wiki/Cargill
# /wiki/Ingredion
# /wiki/Holsten-Brauerei
# /wiki/Unilever
# /wiki/Carl_K%C3%BChne_KG
# /wiki/Senvion
# /wiki/Nordex_SE
# /wiki/Datei:HamburgKrugKoppelbr%C3%BCcke.JPG
# /wiki/Datei:HamburgKrugKoppelbr%C3%BCcke.JPG
# /wiki/Krugkoppelbr%C3%BCcke
# ...
# /wiki/Freistaat_Preu%C3%9Fen
# /wiki/Datei:State_flag_of_the_Saxony_(1815-1952).svg
# /wiki/Geschichte_Sachsens#Sachsen_ab_dem_20._Jahrhundert
# /wiki/Datei:Flagge_F%C3%BCrstentum_Schaumburg-Lippe.svg
# /wiki/Freistaat_Schaumburg-Lippe
# /wiki/Datei:Flag_of_Thuringia.svg
# /wiki/Land_Th%C3%BCringen_(1920%E2%80%931952)
# /wiki/Datei:Flagge_K%C3%B6nigreich_W%C3%BCrttemberg.svg
# /wiki/Volksstaat_W%C3%BCrttemberg
# /wiki/Datei:Flag_of_Saar_1920-1935.svg
# /wiki/Saargebiet
# /wiki/Datei:Flag_of_Germany_(3-2_aspect_ratio).svg
# /wiki/Volksstaat_Reu%C3%9F
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1826-1911).svg
# /wiki/Freistaat_Sachsen-Altenburg
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1911-1920).svg
# /wiki/Freistaat_Sachsen-Gotha
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1826-1911).svg
# /wiki/Freistaat_Sachsen-Meiningen
# /wiki/Datei:Flagge_Gro%C3%9Fherzogtum_Sachsen-Weimar-Eisenach_(1897-1920).svg
# /wiki/Freistaat_Sachsen-Weimar-Eisenach
# /wiki/Datei:Flagge_F%C3%BCrstent%C3%BCmer_Schwarzburg.svg
# /wiki/Freistaat_Schwarzburg-Rudolstadt
# /wiki/Datei:Flagge_F%C3%BCrstent%C3%BCmer_Schwarzburg.svg
# /wiki/Freistaat_Schwarzburg-Sondershausen
# /wiki/Datei:Flag_of_Germany_(3-2_aspect_ratio).svg
# /wiki/Waldeck
# /wiki/Carl_Eduard_(Sachsen-Coburg_und_Gotha)
# /wiki/Herzogtum_Sachsen-Coburg_und_Gotha
# /wiki/Freistaat_Coburg
# /wiki/Anhalt
# /wiki/Baden_(Land)
# /wiki/Geschichte_Bayerns#Bayern_unter_dem_Nationalsozialismus
# /wiki/Land_Braunschweig
# /wiki/Bremen_zur_Zeit_des_Nationalsozialismus
# /wiki/Hamburg_in_der_Zeit_des_Nationalsozialismus
# /wiki/Volksstaat_Hessen#Entwicklung
# /wiki/Freistaat_Lippe
# /wiki/Geschichte_der_Hansestadt_L%C3%BCbeck#20._Jahrhundert
# /wiki/Land_Mecklenburg
# /wiki/Freistaat_Oldenburg
# /wiki/Freistaat_Preu%C3%9Fen#Beginn_der_Zeit_des_Nationalsozialismus
# /wiki/Geschichte_des_Saarlandes#Teil_NS-Deutschlands_(1935_bis_1945)
# /wiki/Saargebiet
# /wiki/Geschichte_Sachsens#Nationalsozialismus_(1933_bis_1945)
# /wiki/Schaumburg-Lippe
# /wiki/Th%C3%BCringen_im_Nationalsozialismus
# /wiki/W%C3%BCrttemberg_zur_Zeit_des_Nationalsozialismus
# /wiki/Datei:Flag_of_Europe.svg
# /wiki/Umwelthauptstadt_Europas
# /wiki/Stockholm
# /wiki/Vitoria-Gasteiz
# /wiki/Nantes
# /wiki/Kopenhagen
# /wiki/Bristol
# /wiki/Ljubljana
# /wiki/Essen
# /wiki/Nijmegen
# /wiki/Oslo
# /wiki/Lissabon
# /wiki/Datei:Qsicon_lesenswert.svg
# /wiki/Spezial:Permanenter_Link/6291168
# /wiki/Wikipedia:Lesenswerte_Artikel
# /wiki/Gemeinsame_Normdatei
# https://d-nb.info/gnd/4023118-5
# https://swb.bsz-bw.de/DB=2.104/SET=1/TTL=1/CMD?retrace=0&trm_old=&ACT=SRCHA&IKT=2999&SRT=RLV&TRM=4023118-5
# https://beacon.findbuch.de/seemore/gnd-aks?format=sources&id=4023118-5
# /wiki/Library_of_Congress_Control_Number
# https://lccn.loc.gov/n81086822
# /wiki/Web_NDL_Authorities
# https://id.ndl.go.jp/auth/ndlna/00628973
# /wiki/Virtual_International_Authority_File
# https://viaf.org/viaf/148855657/
# https://de.wikipedia.org/w/index.php?title=Hamburg&oldid=222922636
wikipedia.org/wiki/%D9%87%D8%A7%D9%85%D8%A8%D9%88%D8%B1%D8%BA
# https://arc.wikipedia.org/wiki/%DC%97%DC%90%DC%A1%DC%92%DC%98%DC%AA%DC%93
# https://arz.wikipedia.org/wiki/%D9%87%D8%A7%D9%85%D8%A8%D9%88%D8%B1%D8%AC
# https://ast.wikipedia.org/wiki/Hamburgu
# https://ay.wikipedia.org/wiki/Hamburg
# https://az.wikipedia.org/wiki/Hamburq
# https://azb.wikipedia.org/wiki/%D9%87%D8%A7%D9%85%D8%A8%D9%88%D8%B1%D9%82
# https://ba.wikipedia.org/wiki/%D0%93%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://bar.wikipedia.org/wiki/Hamburg
# https://bat-smg.wikipedia.org/wiki/Hamburgs
# https://be.wikipedia.org/wiki/%D0%93%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://be-tarask.wikipedia.org/wiki/%D0%93%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://bg.wikipedia.org/wiki/%D0%A5%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://bh.wikipedia.org/wiki/%E0%A4%B9%E0%A5%88%E0%A4%AE%E0%A5%8D%E0%A4%AC%E0%A4%B0%E0%A5%8D%E0%A4%97
# https://bn.wikipedia.org/wiki/%E0%A6%B9%E0%A6%BE%E0%A6%AE%E0%A6%AC%E0%A7%81%E0%A6%B0%E0%A7%8D%E0%A6%97
# https://br.wikipedia.org/wiki/Hamburg
# https://bs.wikipedia.org/wiki/Hamburg
# https://bxr.wikipedia.org/wiki/%D2%BA%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://ca.wikipedia.org/wiki/Hamburg
# https://cdo.wikipedia.org/wiki/Hamburg
# https://ce.wikipedia.org/wiki/%D0%93%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://ceb.wikipedia.org/wiki/Free_and_Hanseatic_City_of_Hamburg
# https://ch.wikipedia.org/wiki/Hamburg
# https://ckb.wikipedia.org/wiki/%DA%BE%D8%A7%D9%85%D8%A8%D9%88%D8%B1%DA%AF
# https://co.wikipedia.org/wiki/Amburgu
# https://crh.wikipedia.org/wiki/Hamburg
# https://cs.wikipedia.org/wiki/Hamburk
# https://csb.wikipedia.org/wiki/Hamb%C3%B9rg
# https://cv.wikipedia.org/wiki/%D0%93%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://cy.wikipedia.org/wiki/Hamburg
# https://da.wikipedia.org/wiki/Hamborg
# https://diq.wikipedia.org/wiki/Hamburg
# https://dsb.wikipedia.org/wiki/Hamburg
# https://el.wikipedia.org/wiki/%CE%91%CE%BC%CE%B2%CE%BF%CF%8D%CF%81%CE%B3%CE%BF
# https://eml.wikipedia.org/wiki/Amb%C3%BBrg
# https://en.wikipedia.org/wiki/Hamburg
# https://eo.wikipedia.org/wiki/Hamburgo
# https://es.wikipedia.org/wiki/Hamburgo
# https://et.wikipedia.org/wiki/Hamburg
# https://eu.wikipedia.org/wiki/Hanburgo
# https://ext.wikipedia.org/wiki/Amburgu
# https://fa.wikipedia.org/wiki/%D9%87%D8%A7%D9%85%D8%A8%D9%88%D8%B1%DA%AF
# https://fi.wikipedia.org/wiki/Hampuri
# https://fj.wikipedia.org/wiki/Hamburg
# https://fo.wikipedia.org/wiki/Hamburg
# https://fr.wikipedia.org/wiki/Hambourg
# https://frr.wikipedia.org/wiki/Hamborj
# https://fur.wikipedia.org/wiki/Amburc
# https://fy.wikipedia.org/wiki/Hamburch
# https://ga.wikipedia.org/wiki/Hamburg
# https://gd.wikipedia.org/wiki/Hamburg
# https://gl.wikipedia.org/wiki/Hamburgo
# https://gn.wikipedia.org/wiki/Hamburgo
D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://th.wikipedia.org/wiki/%E0%B8%AE%E0%B8%B1%E0%B8%A1%E0%B8%9A%E0%B8%A7%E0%B8%A3%E0%B9%8C%E0%B8%84
# https://tl.wikipedia.org/wiki/Hamburg
# https://tr.wikipedia.org/wiki/Hamburg
# https://tt.wikipedia.org/wiki/%D2%BA%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://tum.wikipedia.org/wiki/Hamburg
# https://tw.wikipedia.org/wiki/Hamb%C9%94g
# https://ug.wikipedia.org/wiki/Hamburg
# https://uk.wikipedia.org/wiki/%D0%93%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://ur.wikipedia.org/wiki/%DB%81%D9%85_%D8%A8%D8%B1%DA%A9
# https://uz.wikipedia.org/wiki/Gamburg
# https://vec.wikipedia.org/wiki/Anburgo
# https://vep.wikipedia.org/wiki/Gamburg
# https://vi.wikipedia.org/wiki/Hamburg
# https://vls.wikipedia.org/wiki/Hamburg
# https://vo.wikipedia.org/wiki/Hamburg
# https://war.wikipedia.org/wiki/Hamburg
# https://wuu.wikipedia.org/wiki/%E6%B1%89%E5%A0%A1
# https://xh.wikipedia.org/wiki/Hamburg
# https://xmf.wikipedia.org/wiki/%E1%83%B0%E1%83%90%E1%83%9B%E1%83%91%E1%83%A3%E1%83%A0%E1%83%92%E1%83%98
# https://yi.wikipedia.org/wiki/%D7%94%D7%90%D7%9E%D7%91%D7%95%D7%A8%D7%92
# https://yo.wikipedia.org/wiki/Hamburg
# https://zh.wikipedia.org/wiki/%E6%B1%89%E5%A0%A1
# https://zh-classical.wikipedia.org/wiki/%E6%BC%A2%E5%A0%A1
# https://zh-min-nan.wikipedia.org/wiki/Hamburg
# https://zh-yue.wikipedia.org/wiki/%E6%BC%A2%E5%A0%A1
# https://www.wikidata.org/wiki/Special:EntityPage/Q1055#sitelinks-wikipedia
# https://pageviews.wmcloud.org/?pages=Hamburg&project=de.wikipedia.org
#  https://xtools.wmflabs.org/articleinfo-authorship/de.wikipedia.org/Hamburg?uselang=de
# https://de.wikipedia.org/wiki/Wikipedia:Lizenzbestimmungen_Creative_Commons_Attribution-ShareAlike_3.0_Unported
# https://foundation.wikimedia.org/wiki/Terms_of_Use/de
# https://meta.wikimedia.org/wiki/Privacy_policy/de
# https://meta.wikimedia.org/wiki/Privacy_policy/de
# /wiki/Wikipedia:%C3%9Cber_Wikipedia
# /wiki/Wikipedia:Impressum
# //de.m.wikipedia.org/w/index.php?title=Hamburg&mobileaction=toggle_view_mobile
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://stats.wikimedia.org/#/de.wikipedia.org
# https://foundation.wikimedia.org/wiki/Cookie_statement
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %% [markdown]
# Man sieht, dass auf der Seite viele Links zu finden sind. Es gibt
# - interne Verlinkungen innerhalb der Hamburgseite der Wikipedia (diese beginnen mit #)
# - Verlinkungen zu anderen Artikeln auf den Seiten innerhalb der Wikipedia (diese beginnen mit /wiki/)
# - Verlinkungen zu anderen Webseiten außerhalb der Wikipedia (diese beginnen mit http oder https).

# %% [markdown]
# Mit Hilfe von Bedingungen kann man die Links entsprechend filtern. Nur Verlinkungen zu anderen Wikipedia-Artikeln kann man folgendermaßen anzeigen lassen:

# %%
for l in links:
    if l['href'].startswith('/wiki'):
        print(l['href'])
# Out:
# /wiki/Hamburg_(Begriffskl%C3%A4rung)
# /wiki/Datei:Flag_of_Hamburg.svg
# /wiki/Datei:Locator_map_Hamburg_in_Germany.svg
# /wiki/Landeswappen_Hamburgs#Flaggen
# /wiki/Datei:Wappen_der_Hamburgischen_B%C3%BCrgerschaft.svg
# /wiki/Landeswappen_Hamburgs#Großes_Staatswappen_und_Logo
# /wiki/Amtssprachen_innerhalb_Deutschlands
# /wiki/Deutsche_Sprache
# /wiki/Staatsform
# /wiki/Parlamentarische_Republik
# /wiki/Souver%C3%A4nit%C3%A4t
# /wiki/Bundesstaat_(F%C3%B6deraler_Staat)
# /wiki/Postleitzahl_(Deutschland)
# /wiki/Neuwerk
# /wiki/Telefonvorwahl_(Deutschland)
# /wiki/Neuwerk
# /wiki/Kfz-Kennzeichen_(Deutschland)
# /wiki/Kaufkraft_(Konsum)
# /wiki/Kaufkraft_(Konsum)
# /wiki/Bruttoinlandsprodukt
# /wiki/Liste_der_deutschen_Bundesl%C3%A4nder_nach_Bruttoinlandsprodukt
# /wiki/Liste_der_deutschen_Bundesl%C3%A4nder_nach_Bruttoinlandsprodukt
# /wiki/Schulden
# /wiki/Senat_der_Freien_und_Hansestadt_Hamburg
# /wiki/Rathausmarkt_(Hamburg)
# /wiki/Amtlicher_Gemeindeschl%C3%BCssel
# /wiki/ISO_3166-2:DE
# /wiki/UN/LOCODE
# /wiki/Einwohner
# /wiki/Ausl%C3%A4nder
# /wiki/Migrationshintergrund
# /wiki/Metropolregion_Hamburg
# /wiki/Bev%C3%B6lkerungsdichte
# /wiki/Arbeitslosenstatistik
# /wiki/Geographische_Koordinaten
# /wiki/H%C3%B6he
# /wiki/Normalh%C3%B6hennull
# /wiki/Fl%C3%A4cheninhalt
# /wiki/Gr%C3%B6%C3%9Fenordnung_(Fl%C3%A4che)#100_km²_bis_1000_km²
# /wiki/Liste_der_deutschen_Bundesl%C3%A4nder_nach_Fl%C3%A4che
# /wiki/Liste_der_100_fl%C3%A4chengr%C3%B6%C3%9Ften_Gemeinden_Deutschlands
# /wiki/Bezirke_in_Hamburg
# /wiki/Erster_B%C3%BCrgermeister
# /wiki/Peter_Tschentscher
# /wiki/Erster_B%C3%BCrgermeister#Zweiter_Bürgermeister
# /wiki/Katharina_Fegebank
# /wiki/Pr%C3%A4sident_der_Hamburgischen_B%C3%BCrgerschaft
# /wiki/Carola_Veit
# /wiki/Politische_Partei
# /wiki/SPD
# /wiki/B%C3%BCndnis_90/Die_Gr%C3%BCnen
# /wiki/Liste_der_Mitglieder_der_Hamburgischen_B%C3%BCrgerschaft_(22._Wahlperiode)
# /wiki/Sitzverteilung_in_den_deutschen_Landesparlamenten
# /wiki/SPD_Hamburg
# /wiki/B%C3%BCndnis_90/Die_Gr%C3%BCnen_Hamburg
# /wiki/CDU_Hamburg
# /wiki/Die_Linke_Hamburg
# /wiki/AfD_Hamburg
# /wiki/FDP_Hamburg
# /wiki/Politik_in_Hamburg
# /wiki/B%C3%BCrgerschaftswahl_in_Hamburg_2020
# /wiki/Politik_in_Hamburg
# /wiki/Wahl_zur_23._Hamburgischen_B%C3%BCrgerschaft
# /wiki/Bundesrat_(Deutschland)
# /wiki/Bezirke_in_Hamburg
# /wiki/Datei:Hamburg,_administrative_divisions_(%2Bdistricts_-boroughs_-pop)_-_de_-_colored.svg
# /wiki/Datei:Hamburg-logo.svg
# /wiki/Liste_der_IPA-Zeichen
# /wiki/Datei:GeoTrinity_Hamburg.ogg
# /wiki/Medium:GeoTrinity_Hamburg.ogg
# /wiki/Liste_der_IPA-Zeichen
# /wiki/Datei:GeoTrinity_Hamburch.ogg
# /wiki/Medium:GeoTrinity_Hamburch.ogg
# /wiki/Liste_der_IPA-Zeichen
# /wiki/Niederdeutsche_Sprache
# /wiki/ISO_3166-2:DE
# /wiki/Stadtstaat
# /wiki/Land_(Deutschland)
# /wiki/Deutschland
# /wiki/Geschichte_Hamburgs
# /wiki/Freie_und_Reichsst%C3%A4dte
# /wiki/Hanse
# /wiki/Liste_der_Gro%C3%9Fst%C3%A4dte_in_Deutschland
# /wiki/Liste_der_gr%C3%B6%C3%9Ften_St%C3%A4dte_im_deutschen_Sprachraum
# /wiki/Gemeinde_(Deutschland)
# /wiki/Bezirke_in_Hamburg
# /wiki/Hamburg-Neuwerk
# /wiki/Nordsee
# /wiki/Hamburger_Hafen
# /wiki/Containerterminal#Umschlagdaten
# /wiki/Flughafen_Hamburg
# /wiki/Logistik
# /wiki/Luft-_und_Raumfahrttechnik
# /wiki/Biowissenschaften
# /wiki/Informationstechnik
# /wiki/Konsumgut
# /wiki/Presse_(Medien)
# /wiki/Internationaler_Seegerichtshof
# /wiki/Lebensqualit%C3%A4t
# /wiki/Economist_Intelligence_Unit
# /wiki/Speicherstadt
# /wiki/Kontorhausviertel
# /wiki/Welterbe_in_Deutschland
# /wiki/Liste_der_Kulturdenkm%C3%A4ler_in_Hamburg
# /wiki/Hamburger_Rathaus
# /wiki/Hamburger_Hauptkirchen
# /wiki/Klinker
# /wiki/Fleet
# /wiki/Hamburg-St._Pauli
# /wiki/Reeperbahn
# /wiki/Elbphilharmonie
# /wiki/Datei:Hamburgfromair2.jpg
# /wiki/Datei:Hamburgfromair2.jpg
# /wiki/Hamburger_Hafen
# /wiki/Binnenalster
# /wiki/Au%C3%9Fenalster
# /wiki/Datei:Metropolregion_Hamburg_2017.png
# /wiki/Datei:Metropolregion_Hamburg_2017.png
# /wiki/Metropolregion_Hamburg
# /wiki/Norddeutschland
# /wiki/Bille
# /wiki/Alster
# /wiki/Unterelbe
# /wiki/Nordsee
# /wiki/Hamburg-Neuwerk
# /wiki/Elbe
# /wiki/Seehafen
# /wiki/Veddel
# /wiki/Hamburg-Finkenwerder
# /wiki/Norderelbe
# /wiki/Hamburg-St._Pauli
# /wiki/Bezirk_Altona
# /wiki/Hamburger_Elbbr%C3%BCcken
# /wiki/St._Pauli-Elbtunnel
# /wiki/Neuer_Elbtunnel
# /wiki/Geest
# /wiki/K%C3%A4nozoisches_Eiszeitalter#Gliederung_in_Mitteleuropa
# /wiki/Alt-_und_Jungmor%C3%A4ne
# /wiki/Marschland
# /wiki/Eindeichung
# /wiki/Deich
# /wiki/Normalh%C3%B6hennull
# /wiki/Hasselbrack
# /wiki/Harburger_Berge
# /wiki/Hamburger_Innenstadt
# /wiki/Mittelalter
# /wiki/Binnenalster
# /wiki/Fleet
# /wiki/Hamburg-Wilhelmsburg
# /wiki/Heuckenlock
# /wiki/Schleswig-Holstein
# /wiki/Niedersachsen
# /wiki/Neuwerk
# /wiki/Gro%C3%9F-Hamburg-Gesetz
# /wiki/Berlin
# /wiki/Liste_der_100_fl%C3%A4chengr%C3%B6%C3%9Ften_Gemeinden_Deutschlands
# /wiki/Liste_geographischer_Mittelpunkte
# /wiki/Hamburg-Uhlenhorst
# /wiki/Krauel
# /wiki/Elbe
# /wiki/Unterelbe
# /wiki/Reiherstieg
# /wiki/Dove_Elbe
# /wiki/Gose_Elbe
# /wiki/Seevekanal
# /wiki/Bille
# /wiki/Flottbek_(Fluss)
# /wiki/Este_(Fluss)
# /wiki/Alster
# /wiki/Wandse
# /wiki/Osterbek
# /wiki/Goldbekkanal
# /wiki/Isebekkanal
# /wiki/Tarpenbek
# /wiki/Saselbek
# /wiki/Rodenbek_(Alster)
# /wiki/Bredenbek_(Alster)
# /wiki/Ammersbek_(Alster)
# /wiki/Liste_von_Erhebungen_in_Hamburg
# /wiki/Liste_der_Naturdenkmale_in_Hamburg
# /wiki/Liste_der_Naturschutzgebiete_in_Hamburg
# /wiki/Liste_der_Landschaftsschutzgebiete_in_Hamburg
# /wiki/Liste_der_Wasserschutzgebiete_in_Hamburg
# /wiki/Hamburgs_geologischer_Untergrund
# /wiki/Bezirke_in_Hamburg
# /wiki/Datei:Hamburg,_administrative_divisions_(%2Bdistricts_-%2Bboroughs_-pop)_-_de_-_colored.svg
# /wiki/Datei:HamburgKarte_Version01_070527_150dpi.PNG
# /wiki/Datei:HamburgKarte_Version01_070527_150dpi.PNG
# /wiki/Alster#Alstersee
# /wiki/Verfassung_der_Freien_und_Hansestadt_Hamburg
# /wiki/Bezirksamt
# /wiki/Ortsamt_(Hamburg)
# /wiki/Hamburg-Wilhelmsburg
# /wiki/Bezirk_Harburg
# /wiki/Bezirk_Hamburg-Mitte
# /wiki/Hamburg-Sternschanze
# /wiki/Bezirk_Altona
# /wiki/Hamburg-HafenCity
# /wiki/Datei:F%C3%BChrt_kein_Wappen.svg
# /wiki/Bezirk_Hamburg-Mitte
# /wiki/Datei:DEU_Altona_COA.svg
# /wiki/Bezirk_Altona
# /wiki/Datei:Wappen_Eimsb%C3%BCttel1.svg
# /wiki/Bezirk_Eimsb%C3%BCttel
# /wiki/Datei:F%C3%BChrt_kein_Wappen.svg
# /wiki/Bezirk_Hamburg-Nord
# /wiki/Datei:Wappen_Hamburg-Wandsbek.svg
# /wiki/Bezirk_Wandsbek
# /wiki/Datei:Wappen_Hamburg-Bergedorf.png
# /wiki/Bezirk_Bergedorf
# /wiki/Datei:Wappen_Harburg-Wilhelmsburg.png
# /wiki/Bezirk_Harburg
# /wiki/Datei:DEU_Hamburg_COA.svg
# /wiki/Datei:11-09-04-fotoflug-nordsee-by-RalfR-001.jpg
# /wiki/Datei:11-09-04-fotoflug-nordsee-by-RalfR-001.jpg
# /wiki/Neuwerk
# /wiki/Datei:Hamburg_Sturmflut_1962.png
# /wiki/Datei:Hamburg_Sturmflut_1962.png
# /wiki/Exklave
# /wiki/Nordsee
# /wiki/Neuwerk
# /wiki/Scharh%C3%B6rn
# /wiki/Nigeh%C3%B6rn
# /wiki/Nationalpark_Hamburgisches_Wattenmeer
# /wiki/Hamburg-Neuwerk
# /wiki/Bezirk_Hamburg-Mitte
# /wiki/Ammersbek
# /wiki/Schleswig-Holstein
# /wiki/Bezirk_Wandsbek
# /wiki/Cuxhaven-Vertrag
# /wiki/Gemeinde_(Deutschland)
# /wiki/Uhrzeigersinn
# /wiki/Kreis_Pinneberg
# /wiki/Wedel
# /wiki/Appen
# /wiki/Pinneberg
# /wiki/Schenefeld_(Kreis_Pinneberg)
# /wiki/Halstenbek
# /wiki/Rellingen
# /wiki/Ellerbek
# /wiki/Amt_Pinnau
# /wiki/B%C3%B6nningstedt
# /wiki/Kreis_Segeberg
# /wiki/Norderstedt
# /wiki/Kreis_Stormarn
# /wiki/Tangstedt_(Stormarn)
# /wiki/Jersbek
# /wiki/Amt_Bargteheide-Land
# /wiki/Ammersbek
# /wiki/Ahrensburg
# /wiki/Stapelfeld
# /wiki/Amt_Siek
# /wiki/Barsb%C3%BCttel
# /wiki/Oststeinbek
# /wiki/Glinde
# /wiki/Reinbek
# /wiki/Kreis_Herzogtum_Lauenburg
# /wiki/Wentorf_bei_Hamburg
# /wiki/B%C3%B6rnsen
# /wiki/Escheburg
# /wiki/Amt_Hohe_Elbgeest
# /wiki/Geesthacht
# /wiki/Landkreis_Harburg
# /wiki/Drage_(Elbe)
# /wiki/Samtgemeinde_Elbmarsch
# /wiki/Winsen_(Luhe)
# /wiki/Stelle_(Landkreis_Harburg)
# /wiki/Seevetal
# /wiki/Rosengarten_(Landkreis_Harburg)
# /wiki/Neu_Wulmstorf
# /wiki/Landkreis_Stade
# /wiki/Jork
# /wiki/Landkreis_Cuxhaven
# /wiki/Cuxhaven
# /wiki/Neuwerk
# /wiki/Liste_von_Klimadaten_am_Flughafen_Hamburg
# /wiki/Hamburg#Klimawandel
# /wiki/K%C3%BChlgem%C3%A4%C3%9Figtes_Klima
# /wiki/Seeklima
# /wiki/Jahresmitteltemperatur
# /wiki/Hamburg-Fuhlsb%C3%BCttel
# /wiki/Schmuddelwetter
# /wiki/Monatsmitteltemperatur
# /wiki/Niederschlagsmenge
# /wiki/Deutscher_Wetterdienst
# /wiki/Monatsmitteltemperatur
# /wiki/Niederschlagsmenge
# /wiki/Sonnenstunden
# /wiki/Regentag
# /wiki/Luftfeuchtigkeit
# /wiki/Deutscher_Wetterdienst
# /wiki/L%C3%A4rm
# /wiki/Umweltzone
# /wiki/Agglomeration
# /wiki/Luftverschmutzung
# /wiki/Heizung
# /wiki/M%C3%BCllverbrennung
# /wiki/Emissionen_durch_die_Schifffahrt#Luftbelastung_in_den_Häfen
# /wiki/Beh%C3%B6rde_f%C3%BCr_Umwelt_und_Energie
# /wiki/Umwelthauptstadt_Europas_Hamburg_2011
# /wiki/Airbus
# /wiki/M%C3%BChlenberger_Loch#Wirtschaft_und_Naturschutz_–_Die_Airbus-Erweiterung
# /wiki/Kohlekraftwerk_Moorburg
# /wiki/Polychlorierte_Dibenzodioxine_und_Dibenzofurane
# /wiki/Boehringer_Ingelheim#Negative_Wahrnehmung
# /wiki/Hamburg-Billbrook
# /wiki/Parathion
# /wiki/Deponie_Georgswerder
# /wiki/Gesamtkunstwerk_Freie_und_Hansestadt_Hamburg
# /wiki/Hamburg-Altenwerder
# /wiki/Elbvertiefung
# /wiki/Luftverschmutzung
# /wiki/Stickstoffdioxid
# /wiki/Fahrzeugkatalysator
# /wiki/Luftreinhalteplan
# /wiki/Anordnung_(Recht)
# /wiki/Feinstaub
# /wiki/PM10
# /wiki/Verwaltungsgericht_Hamburg
# /wiki/Gesetzeskraft
# /wiki/Globale_Erw%C3%A4rmung
# /wiki/Sommertag
# /wiki/Hei%C3%9Fer_Tag
# /wiki/Tropennacht
# /wiki/Arbeitsproduktivit%C3%A4t
# /wiki/Konzentration_(Psychologie)
# /wiki/Frosttag
# /wiki/Eistag
# /wiki/Meeresspiegelanstieg_seit_1850
# /wiki/Sturmflut
# /wiki/Brackwasser
# /wiki/Folgen_der_globalen_Erw%C3%A4rmung
# /wiki/Anpassung_an_die_globale_Erw%C3%A4rmung
# /wiki/Geschichte_Hamburgs
# /wiki/Claudius_Ptolem%C3%A4us
# /wiki/Treva
# /wiki/Sachsen_(Volk)
# /wiki/Hammaburg
# /wiki/Karl_der_Gro%C3%9Fe
# /wiki/Ludwig_der_Fromme
# /wiki/Bistum
# /wiki/Erzbistum
# /wiki/Vertrag_von_Verdun
# /wiki/Wikinger
# /wiki/Abodriten
# /wiki/Bremen
# /wiki/Datei:1730_Hamburg_Covens_%26_Mortier.JPG
# /wiki/Datei:1730_Hamburg_Covens_%26_Mortier.JPG
# /wiki/Adolf_III._(Schauenburg_und_Holstein)
# /wiki/Friedrich_I._(HRR)
# /wiki/Privileg
# /wiki/Unterelbe
# /wiki/Brauerei
# /wiki/Hanse
# /wiki/Freie_Reichsstadt
# /wiki/Hamburger_B%C3%B6rse
# /wiki/Oper_am_G%C3%A4nsemarkt
# /wiki/Oper
# /wiki/G%C3%A4nsemarkt
# /wiki/Reformation
# /wiki/Hamburgische_Entreprise
# /wiki/Aufkl%C3%A4rung
# /wiki/Industrialisierung
# /wiki/Drei%C3%9Figj%C3%A4hriger_Krieg
# /wiki/Heiliges_R%C3%B6misches_Reich
# /wiki/D%C3%A9partement
# /wiki/D%C3%A9partement_des_Bouches_de_l%E2%80%99Elbe
# /wiki/Hamburger_Franzosenzeit
# /wiki/Levin_August_von_Bennigsen
# /wiki/Wiener_Kongress
# /wiki/Deutscher_Bund
# /wiki/Otto_von_Bismarck
# /wiki/Norddeutscher_Bund
# /wiki/Hamburger_Brand
# /wiki/Choleraepidemie_von_1892
# /wiki/Gro%C3%9F-Hamburg-Gesetz
# /wiki/Operation_Gomorrha
# /wiki/J%C3%BCdische_Gemeinde_Hamburg
# /wiki/Geschichte_der_Juden_in_Hamburg
# /wiki/KZ_Neuengamme
# /wiki/KZ_Neuengamme#Die_Außenlager
# /wiki/Sturmflut_1962
# /wiki/Flugplatz_Hamburg-Finkenwerder
# /wiki/Flughafen_Hamburg
# /wiki/Hafenstra%C3%9Fe
# /wiki/Einwohnerentwicklung_von_Hamburg
# /wiki/Datei:Einwohnerentwicklung_von_Hamburg_-_ab_1871.svg
# /wiki/Datei:Einwohnerentwicklung_von_Hamburg_-_ab_1871.svg
# /wiki/Suburbanisierung
# /wiki/Lebenserwartung
# /wiki/Datei:Marco-Polo-Terrassen.jpg
# /wiki/Datei:Marco-Polo-Terrassen.jpg
# /wiki/Migrationshintergrund
# /wiki/Deutsche_Staatsangeh%C3%B6rigkeit
# /wiki/Ausl%C3%A4nder
# /wiki/Aussiedler_und_Sp%C3%A4taussiedler
# /wiki/T%C3%BCrkei
# /wiki/Polen
# /wiki/Afghanistan
# /wiki/Serbien_und_Montenegro
# /wiki/%C3%96ffentlicher_Dienst_(Deutschland)
# /wiki/Unternehmen
# /wiki/Datei:Pincerno_-_Einkommen_2010.png
# /wiki/Datei:Pincerno_-_Einkommen_2010.png
# /wiki/Bezirke_in_Hamburg
# /wiki/Datei:Pincerno_-_Hartz_IV_2010.png
# /wiki/Datei:Pincerno_-_Hartz_IV_2010.png
# /wiki/Bezirke_in_Hamburg
# /wiki/Elbvororte
# /wiki/Waldd%C3%B6rfer
# /wiki/Au%C3%9Fenalster
# /wiki/Hamburg-Marienthal
# /wiki/Hamburg-Nienstedten
# /wiki/Hamburg-Blankenese
# /wiki/Hamburg-Wohldorf-Ohlstedt
# /wiki/Hamburg-Harvestehude
# /wiki/Reichtumsquote
# /wiki/Einkommensmillion%C3%A4r
# /wiki/Hamburg-Billstedt
# /wiki/Hamburger_Innenstadt
# /wiki/Hamburg-Wilhelmsburg
# /wiki/Hamburg-Veddel
# /wiki/Hamburg-Harburg
# /wiki/Hamburg-Altona-Altstadt
# /wiki/Hamburg-Altona-Nord
# /wiki/Hamburg-St._Pauli
# /wiki/Hamburg-Dulsberg
# /wiki/Hamburg-Barmbek-Nord
# /wiki/Hamburg-Steilshoop
# /wiki/Hamburg-Lurup
# /wiki/Hamburg-Kleiner_Grasbrook
# /wiki/Hamburg-Steinwerder
# /wiki/Hamburg-Rothenburgsort
# /wiki/Zweites_Buch_Sozialgesetzbuch
# /wiki/Arbeitslosengeld_II
# /wiki/Freie_Hansestadt_Bremen
# /wiki/Bezirk_Bergedorf
# /wiki/Hamburg-Steilshoop
# /wiki/Hamburg-Hausbruch
# /wiki/Hamburg-Jenfeld
# /wiki/M%C3%BCmmelmannsberg
# /wiki/Kirchdorf-S%C3%BCd
# /wiki/Datei:Sankt-Michaelis-Kirche_Hamburg.jpg
# /wiki/Datei:Sankt-Michaelis-Kirche_Hamburg.jpg
# /wiki/Hauptkirche_Sankt_Michaelis_(Hamburg)
# /wiki/Religion_in_Hamburg
# /wiki/Zensus_2011
# /wiki/R%C3%B6misch-katholische_Kirche
# /wiki/Konfessionslosigkeit
# /wiki/Evangelische_Kirche
# /wiki/Konkordienformel
# /wiki/Baptisten
# /wiki/Mennonitengemeinde_zu_Hamburg_und_Altona
# /wiki/Kategorie:Apostolische_Gemeinschaften
# /wiki/Allgemeine_christliche_apostolische_Mission
# /wiki/Katholisch-apostolische_Gemeinden
# /wiki/Neuapostolische_Kirche
# /wiki/R%C3%B6misch-katholische_Kirche
# /wiki/Erzbistum_Hamburg
# /wiki/St._Marien-Dom_(Hamburg)
# /wiki/Jesus_Freaks
# /wiki/Flussschifferkirche
# /wiki/Kirchenboot
# /wiki/Binnenhafen_(Hamburg)
# /wiki/Jehovas_Zeugen
# /wiki/J%C3%BCdische_Gemeinde_Hamburg
# /wiki/Liste_der_Synagogen_in_Hamburg
# /wiki/Novemberpogrome_1938
# /wiki/J%C3%BCdischer_Friedhof_Altona
# /wiki/Iberische_Halbinsel
# /wiki/Sephardim
# /wiki/Aschkenasim
# /wiki/Talmud-Tora-Schule
# /wiki/Bezirk_Eimsb%C3%BCttel
# /wiki/Muslim
# /wiki/Stellingen
# /wiki/Fazle-Omar-Moschee
# /wiki/Zweiter_Weltkrieg
# /wiki/Ahmadiyya_Muslim_Jamaat
# /wiki/Buddhismus
# /wiki/Konvertit
# /wiki/Zen
# /wiki/Buddhismus_in_Tibet
# /wiki/Niederdeutsche_Sprache
# /wiki/Deutsche_Sprache
# /wiki/Verfassung_der_Freien_und_Hansestadt_Hamburg
# /wiki/Missingsch
# /wiki/Hamburger_Platt
# /wiki/Hamburgisches_W%C3%B6rterbuch
# /wiki/Ohnsorg-Theater
# /wiki/Hamburg-Altona
# /wiki/Hamburg-St._Georg
# /wiki/Veddel
# /wiki/Hamburg-Wilhelmsburg
# /wiki/Portugiesenviertel
# /wiki/Aussiedler
# /wiki/Sp%C3%A4taussiedler
# /wiki/D%C3%A4nische_Minderheit_in_Deutschland
# /wiki/Europ%C3%A4ische_Charta_der_Regional-_oder_Minderheitensprachen
# /wiki/Niederdeutsch
# /wiki/Regionalsprache
# /wiki/Romani
# /wiki/Minderheitensprache
# /wiki/Hamburger_Dialekt
# /wiki/Liste_von_Pers%C3%B6nlichkeiten_der_Stadt_Hamburg
# /wiki/Liste_der_Ehrenb%C3%BCrger_von_Hamburg
# /wiki/Liste_der_Hamburger_B%C3%BCrgermeister
# /wiki/Liste_der_Hamburger_Hauptpastoren
# /wiki/Hunderegister
# /wiki/Hundezone
# /wiki/Hundeleine
# /wiki/Gef%C3%A4hrlicher_Hund
# /wiki/Hundef%C3%BChrerschein
# /wiki/Alsterpark
# /wiki/H%C3%B6ltigbaum
# /wiki/Hamburg-Poppenb%C3%BCttel#Geografie
# /wiki/Galopprennbahn_Hamburg-Horn
# /wiki/%C3%96jendorfer_Park
# /wiki/Blindenf%C3%BChrhund
# /wiki/Wochenmarkt
# /wiki/Volksfest
# /wiki/Hamburger_Dom_(Volksfest)
# /wiki/Hafengeburtstag
# /wiki/Hundegesetze
# /wiki/Tierkennzeichnung
# /wiki/Hunderegister
# /wiki/Tierhalterhaftpflichtversicherung
# /wiki/Windhundrennen
# /wiki/Norddeutscher_Windhund-Rennverein
# /wiki/Pferdesport_in_Hamburg
# /wiki/Politik_in_Hamburg
# /wiki/Datei:HH_Rathaus_pano1.jpg
# /wiki/Hamburgische_B%C3%BCrgerschaft
# /wiki/Senat_der_Freien_und_Hansestadt_Hamburg
# /wiki/Hamburger_Rathaus
# /wiki/Historismus
# /wiki/Neorenaissance
# /wiki/Datei:Plenarsaal_Hamburgische_B%C3%BCrgerschaft_IMG_6403_6404_6405_edit.jpg
# /wiki/Hamburger_Rathaus
# /wiki/Datei:Hamburg.Oberlandesgericht.wmt.jpg
# /wiki/Hanseatisches_Oberlandesgericht
# /wiki/Stadtstaat
# /wiki/Land_(Deutschland)
# /wiki/Stadt
# /wiki/Einheitsgemeinde
# /wiki/Republik
# /wiki/Verfassung_der_Freien_und_Hansestadt_Hamburg
# /wiki/Demokratie
# /wiki/Sozialstaat
# /wiki/Rechtsstaat
# /wiki/Hamburgische_B%C3%BCrgerschaft
# /wiki/Volksgesetzgebung_in_Hamburg
# /wiki/Deputation_(Hamburg)
# /wiki/Senat_der_Freien_und_Hansestadt_Hamburg
# /wiki/Erster_B%C3%BCrgermeister
# /wiki/Geheime_Wahl_des_Regierungschefs_im_Parlament
# /wiki/Richtlinienkompetenz
# /wiki/Pr%C3%A4ses
# /wiki/Ministerium
# /wiki/Hamburgisches_Verfassungsgericht
# /wiki/Landesverfassungsgericht
# /wiki/Bezirke_in_Hamburg
# /wiki/Bezirksversammlung
# /wiki/Bundesrat_(Deutschland)
# /wiki/Direktmandat
# /wiki/Wahlkreis
# /wiki/Bundestagswahlkreis_Hamburg-Mitte
# /wiki/Bundestagswahlkreis_Hamburg-Altona
# /wiki/Bundestagswahlkreis_Hamburg-Eimsb%C3%BCttel
# /wiki/Bundestagswahlkreis_Hamburg-Nord
# /wiki/Bundestagswahlkreis_Hamburg-Wandsbek
# /wiki/Bundestagswahlkreis_Hamburg-Bergedorf_%E2%80%93_Harburg
# /wiki/Deutscher_Bundestag
# /wiki/Deutscher_St%C3%A4dtetag
# /wiki/Ausschuss_der_Regionen
# /wiki/Nordstaat
# /wiki/Metropolregion_Hamburg
# /wiki/Statistisches_Landesamt
# /wiki/B%C3%BCrgerschaftswahl_in_Hamburg_2020
# /wiki/Hamburgische_B%C3%BCrgerschaft
# /wiki/B%C3%BCrgerschaftswahl_in_Hamburg_2015
# /wiki/Wahl_zur_23._Hamburgischen_B%C3%BCrgerschaft
# /wiki/Sozialdemokratische_Partei_Deutschlands
# /wiki/B%C3%BCndnis_90/Die_Gr%C3%BCnen
# /wiki/Christlich_Demokratische_Union_Deutschlands
# /wiki/Die_Linke
# /wiki/Alternative_f%C3%BCr_Deutschland
# /wiki/Freie_Demokratische_Partei
# /wiki/Die_Partei
# /wiki/Volt_Deutschland
# /wiki/B%C3%BCrgerschaftswahl_in_Hamburg_2015
# /wiki/Sozialdemokratische_Partei_Deutschlands
# /wiki/B%C3%BCndnis_90/Die_Gr%C3%BCnen
# /wiki/Christlich_Demokratische_Union_Deutschlands
# /wiki/Die_Linke
# /wiki/Alternative_f%C3%BCr_Deutschland
# /wiki/Freie_Demokratische_Partei
# /wiki/Die_Partei
# /wiki/Volt_Deutschland
# /wiki/Senat_Tschentscher_I
# /wiki/Zweidrittelmehrheit
# /wiki/FDP_Hamburg
# /wiki/F%C3%BCnfprozenth%C3%BCrde
# /wiki/Anna-Elisabeth_von_Treuenfels-Frowein
# /wiki/Wahlkreis_Blankenese
# /wiki/Sozialdemokratische_Partei_Deutschlands
# /wiki/B%C3%BCndnis_90/Die_Gr%C3%BCnen
# /wiki/Christlich_Demokratische_Union_Deutschlands
# /wiki/Freie_Demokratische_Partei
# /wiki/Alternative_f%C3%BCr_Deutschland
# /wiki/Die_Linke
# /wiki/Bundestagswahl_2021
# /wiki/Europawahl_in_Deutschland_2019
# /wiki/Bundestagswahl_2017
# /wiki/Europawahl_in_Deutschland_2014
# /wiki/Bundestagswahl_2013
# /wiki/Bundestagswahl_2009
# /wiki/Europawahl_in_Deutschland_2009
# /wiki/Bundestagswahl_2005
# /wiki/Europawahl_in_Deutschland_2004
# /wiki/Bundestagswahl_2002
# /wiki/Europawahl_in_Deutschland_1999
# /wiki/Bundestagswahl_1998
# /wiki/Partei_des_Demokratischen_Sozialismus
# /wiki/Datei:Consulate_General_USA_Hamburg_2.jpg
# /wiki/Datei:Consulate_General_USA_Hamburg_2.jpg
# /wiki/Amerikanisches_Generalkonsulat_in_Hamburg
# /wiki/Au%C3%9Fenwirtschaft
# /wiki/Konsul
# /wiki/New_York_City
# /wiki/Frankfurt_am_Main
# /wiki/Hongkong
# /wiki/Hanse
# /wiki/Amerikanisches_Generalkonsulat_in_Hamburg
# /wiki/Martin_Haller_(Architekt)
# /wiki/Vertretung_der_Freien_und_Hansestadt_Hamburg_beim_Bund
# /wiki/Landesvertretung
# /wiki/Schleswig-Holstein
# /wiki/Hanse-Office
# /wiki/Europ%C3%A4ische_Union
# /wiki/Br%C3%BCssel
# /wiki/Sankt_Petersburg
# /wiki/Handelskammer_Hamburg
# /wiki/Shanghai
# /wiki/Dubai
# /wiki/HamburgAmbassador_Programm
# /wiki/Liste_der_Konsulate_und_Handelsvertretungen_in_Hamburg
# /wiki/Gemeindepartnerschaft
# /wiki/Russland
# /wiki/Sankt_Petersburg
# /wiki/Russland
# /wiki/Frankreich
# /wiki/Marseille
# /wiki/Frankreich
# /wiki/Volksrepublik_China
# /wiki/Shanghai
# /wiki/Volksrepublik_China
# /wiki/Deutschland
# /wiki/Dresden
# /wiki/Japan
# /wiki/Osaka
# /wiki/Japan
# /wiki/Nicaragua
# /wiki/Le%C3%B3n_(Nicaragua)
# /wiki/Nicaragua
# /wiki/Tschechien
# /wiki/Prag
# /wiki/Tschechien
# /wiki/Vereinigte_Staaten
# /wiki/Chicago
# /wiki/Vereinigte_Staaten
# /wiki/Tansania
# /wiki/Daressalam
# /wiki/Tansania
# /wiki/Senat_der_Freien_und_Hansestadt_Hamburg
# /wiki/Ausw%C3%A4rtiges_Amt
# /wiki/Sowjetunion
# /wiki/Deutsch-franz%C3%B6sische_Beziehungen#Deutsch-französische_Freundschaft
# /wiki/Marseille
# /wiki/Hamburg-HafenCity
# /wiki/Eurom%C3%A9diterran%C3%A9e
# /wiki/Tian%E2%80%99anmen-Massaker
# /wiki/Tian%E2%80%99anmen-Platz
# /wiki/Lingang_New_City
# /wiki/Deutsche_Demokratische_Republik
# /wiki/Klaus_von_Dohnanyi
# /wiki/Erich_Honecker
# /wiki/Ost-Berlin
# /wiki/Planten_un_Blomen
# /wiki/Tschechoslowakei
# /wiki/Henning_Voscherau
# /wiki/Oberb%C3%BCrgermeister
# /wiki/Moldau_(Fluss)
# /wiki/Yokohama
# /wiki/Kaohsiung
# /wiki/Hafen_von_Shanghai
# /wiki/Montevideo
# /wiki/Uruguay
# /wiki/Shenzhen
# /wiki/Busan
# /wiki/S%C3%BCdkorea
# /wiki/Kanada
# /wiki/G%C3%B6teborg
# /wiki/Schweden
# /wiki/Bezirk_Hamburg-Mitte
# /wiki/Hongkou
# /wiki/Bezirk_Eimsb%C3%BCttel
# /wiki/Warna
# /wiki/Bezirk_Wandsbek
# /wiki/London
# /wiki/Waltham_Forest
# /wiki/W%C3%B6hrden
# /wiki/Dithmarschen
# /wiki/Schleswig-Holstein
# /wiki/FabLab
# /wiki/Konsumg%C3%BCter
# /wiki/Import
# /wiki/Abfallentsorgung
# /wiki/Open-Source-Hardware
# /wiki/Lokale_Produktion
# /wiki/Datei:Wappen_der_Hamburgischen_B%C3%BCrgerschaft.svg
# /wiki/Datei:DEU_Hamburg_COA.svg
# /wiki/Datei:Hamburg-symbol.svg
# /wiki/Datei:Flagge_Hamburg.svg
# /wiki/Datei:Flag_of_Hamburg.svg
# /wiki/Datei:Admiralty_Coat_of_Arms_of_Hamburg.svg
# /wiki/Datei:Admiralty_flag_of_Hamburg.svg
# /wiki/Datei:Hamburg-logo.svg
# /wiki/Wappen
# /wiki/Flaggen
# /wiki/Wappenzeichen
# /wiki/Logografie
# /wiki/Stander
# /wiki/Hoheitszeichen
# /wiki/Verfassung_der_Freien_und_Hansestadt_Hamburg
# /wiki/Hanseflaggen
# /wiki/Burg_(Heraldik)
# /wiki/Kreuz_(Heraldik)
# /wiki/Hamburger_Dom_(Alter_Mariendom)
# /wiki/Peter_Schmidt_(Designer)
# /wiki/Weltoffenheit
# /wiki/Hamburgische_Admiralit%C3%A4t
# /wiki/Landeswappen_Hamburgs
# /wiki/Liste_der_Flaggen_deutscher_L%C3%A4nder
# /wiki/Liste_der_Wappen_in_Deutschland
# /wiki/Landeshymne
# /wiki/Hamburg-Hymne
# /wiki/Hammonia
# /wiki/Latein
# /wiki/Jupiter_(Mythologie)
# /wiki/Hammaburg
# /wiki/Altniederdeutsche_Sprache
# /wiki/Kantate
# /wiki/Barthold_Heinrich_Brockes
# /wiki/Allegorische_Malerei
# /wiki/Stadtpatron
# /wiki/Reformation
# /wiki/Maria_(Mutter_Jesu)
# /wiki/Hamburger_Dom_(Alter_Mariendom)
# /wiki/Hamburger_Rathaus
# /wiki/Libertatem_quam_peperere
# /wiki/Hamburger_Rathaus#Die_Vorgänger
# /wiki/Stadtstaat
# /wiki/Freie_Reichsstadt
# /wiki/Freie_Stadt
# /wiki/Hansestadt
# /wiki/Verfassung_der_Freien_und_Hansestadt_Hamburg
# /wiki/Hanseat#Auszeichnungen
# /wiki/Bundeskanzler_(Deutschland)
# /wiki/Helmut_Schmidt
# /wiki/Bundesverdienstorden
# /wiki/Senat_der_Freien_und_Hansestadt_Hamburg
# /wiki/Ehrenb%C3%BCrger
# /wiki/Liste_der_Ehrenb%C3%BCrger_von_Hamburg
# /wiki/Portugaleser
# /wiki/B%C3%BCrgermeister-Stolten-Medaille
# /wiki/Biermann-Ratjen-Medaille
# /wiki/Lessing-Preis_der_Freien_und_Hansestadt_Hamburg
# /wiki/Bach-Preis_der_Freien_und_Hansestadt_Hamburg
# /wiki/Lichtwark-Preis
# /wiki/Fritz-Schumacher-Preis
# /wiki/Hubert-Fichte-Preis
# /wiki/Edwin-Scharff-Preis
# /wiki/Aby-M.-Warburg-Preis
# /wiki/Medaille_f%C3%BCr_treue_Arbeit_im_Dienste_des_Volkes
# /wiki/Liste_staatlicher_Hamburger_Auszeichnungen
# /wiki/Hamburger_Sparkasse
# /wiki/Sparkasse_Harburg-Buxtehude
# /wiki/Beh%C3%B6rde_f%C3%BCr_Arbeit,_Gesundheit,_Soziales,_Familie_und_Integration
# /wiki/Beh%C3%B6rde_f%C3%BCr_Inneres_und_Sport
# /wiki/Agentur_f%C3%BCr_Arbeit
# /wiki/Jobcenter
# /wiki/Kultur_in_Hamburg
# /wiki/Datei:Hamburg.jpg
# /wiki/Datei:Hamburg.jpg
# /wiki/Theater
# /wiki/Museum
# /wiki/Musikverlag
# /wiki/Initiative_Musik
# /wiki/Kino
# /wiki/Programmkino
# /wiki/Deutsche_Zentrale_f%C3%BCr_Tourismus
# /wiki/Miniatur_Wunderland
# /wiki/Beliebteste_Sehensw%C3%BCrdigkeiten_Deutschlands_(DZT)
# /wiki/Hamburger_K%C3%BCche
# /wiki/Birnen,_Bohnen_und_Speck
# /wiki/Scholle_Finkenwerder_Art
# /wiki/Stint
# /wiki/Gr%C3%BCnkohl
# /wiki/Aalsuppe#Hamburger_Aalsuppe
# /wiki/Labskaus
# /wiki/Snuten_un_Poten
# /wiki/Rundst%C3%BCck_warm
# /wiki/Rote_Gr%C3%BCtze
# /wiki/Schwarzsauer
# /wiki/Franzbr%C3%B6tchen
# /wiki/Hamburgensie
# /wiki/Hymne
# /wiki/Hamburg-Hymne
# /wiki/Hans_Albers
# /wiki/Heidi_Kabel
# /wiki/Shanty
# /wiki/Hamborger_Veermaster
# /wiki/Pankokenkapelle
# /wiki/An_de_Eck_steiht%E2%80%99n_Jung_mit%E2%80%99n_T%C3%BCdelband
# /wiki/Gebr%C3%BCder_Wolf
# /wiki/Lotto_King_Karl
# /wiki/Blumfeld
# /wiki/Die_Sterne
# /wiki/Tocotronic
# /wiki/Hamburger_Schule_(Popmusik)
# /wiki/Kettcar_(Band)
# /wiki/Tomte
# /wiki/Hip-Hop
# /wiki/Beginner
# /wiki/Samy_Deluxe
# /wiki/Fettes_Brot
# /wiki/Udo_Lindenberg
# /wiki/Hamburger_Szene
# /wiki/Datei:GraffitoHH.jpg
# /wiki/Datei:GraffitoHH.jpg
# /wiki/Hamburger_Gru%C3%9F
# /wiki/Hans_Hummel_(Stadtoriginal)
# /wiki/Plattdeutsch
# /wiki/G%C3%B6tz-Zitat
# /wiki/Hamburg-Neustadt
# /wiki/Wassertr%C3%A4ger
# /wiki/Moin
# /wiki/Tsch%C3%BCs
# /wiki/G%C3%B6re
# /wiki/Klein_Erna
# /wiki/Vera_M%C3%B6ller
# /wiki/Lakonisch
# /wiki/Pointe
# /wiki/He_l%C3%BCcht
# /wiki/Hamburger_Hafenrundfahrten
# /wiki/Aalsuppe
# /wiki/Trockenobst
# /wiki/DR_877
# /wiki/Deutsche_Reichsbahn_(1920%E2%80%931945)
# /wiki/Stromlinienzug
# /wiki/Datei:Timbre_de_Bergedorf.jpg
# /wiki/Datei:Timbre_de_Bergedorf.jpg
# /wiki/Dauermarke
# /wiki/Postgeschichte_und_Briefmarken_Bergedorfs
# /wiki/Postgeschichte_und_Briefmarken_Hamburgs
# /wiki/Postgeschichte_und_Briefmarken_Bergedorfs
# /wiki/Briefmarke
# /wiki/Datei:Hafengeburtstag_2017.jpg
# /wiki/Datei:Hafengeburtstag_2017.jpg
# /wiki/Hafengeburtstag
# /wiki/Altonaer_Fischmarkt
# /wiki/Hamburger_Dom_(Volksfest)
# /wiki/Jahrmarkt
# /wiki/Hafengeburtstag
# /wiki/Alstervergn%C3%BCgen
# /wiki/Binnenalster
# /wiki/Filmfest_Hamburg
# /wiki/CineFest
# /wiki/Lesbisch_Schwule_Filmtage_Hamburg
# /wiki/Fantasy_Filmfest
# /wiki/Christopher_Street_Day
# /wiki/Harley-Davidson
# /wiki/Motorrad
# /wiki/Motorradgottesdienst
# /wiki/Altonale
# /wiki/Hamburger_Weihnachtsmarkt
# /wiki/Arabische_Kulturwochen_Hamburg
# /wiki/Datei:Hamburg_-_Wunder_von_Bern_-_K%C3%B6nig_der_L%C3%B6wen_-_2016.jpg
# /wiki/Datei:Hamburg_-_Wunder_von_Bern_-_K%C3%B6nig_der_L%C3%B6wen_-_2016.jpg
# /wiki/Theater_im_Hafen_Hamburg
# /wiki/Musical
# /wiki/New_York_City
# /wiki/Stage_Entertainment
# /wiki/Operettenhaus
# /wiki/Neue_Flora
# /wiki/Theater_im_Hafen_Hamburg
# /wiki/Theater_an_der_Elbe
# /wiki/Joop_van_den_Ende_Academy
# /wiki/Stage_School
# /wiki/St._Pauli_Theater
# /wiki/Delphi_Showpalast
# /wiki/Schmidt_Theater
# /wiki/Heiligengeistfeld
# /wiki/Hamburg-Hammerbrook
# /wiki/Andrew_Lloyd_Webber
# /wiki/Cats
# /wiki/Friedrich_Kurz
# /wiki/Das_Phantom_der_Oper_(Musical)
# /wiki/Das_Phantom_der_Oper_(Musical)
# /wiki/Buddy_(Musical)
# /wiki/Tanz_der_Vampire_(Musical)
# /wiki/Dirty_Dancing_(Musical)
# /wiki/Mamma_Mia!_(Musical)
# /wiki/Ich_war_noch_niemals_in_New_York_(Musical)
# /wiki/Sister_Act_(Musical)
# /wiki/Tarzan_(Musical)
# /wiki/Der_K%C3%B6nig_der_L%C3%B6wen_(Musical)
# /wiki/Pretty_Woman_(Musical)
# /wiki/Theater_an_der_Elbe
# /wiki/Datei:Bundesarchiv_B_145_Bild-F004311-0001,_Hamburg,_Staatsoper,_Zuschauerraum.jpg
# /wiki/Datei:Bundesarchiv_B_145_Bild-F004311-0001,_Hamburg,_Staatsoper,_Zuschauerraum.jpg
# /wiki/Datei:Hamburg_Staatsoper_au%C3%9Fen_nachts_1.jpg
# /wiki/Datei:Hamburg_Staatsoper_au%C3%9Fen_nachts_1.jpg
# /wiki/Hamburgische_Staatsoper
# /wiki/Hamburgische_Staatsoper
# /wiki/Johann_Adam_Reincken
# /wiki/Oper_am_G%C3%A4nsemarkt
# /wiki/Georg_Friedrich_H%C3%A4ndel
# /wiki/Georg_Philipp_Telemann
# /wiki/Carl_Ludwig_Wimmel
# /wiki/Martin_Haller_(Architekt)
# /wiki/Montserrat_Caball%C3%A9
# /wiki/Pl%C3%A1cido_Domingo
# /wiki/Luciano_Pavarotti
# /wiki/Mirella_Freni
# /wiki/Birgit_Nilsson
# /wiki/Maria_Callas
# /wiki/Kent_Nagano
# /wiki/Philharmoniker_Hamburg
# /wiki/Georges_Delnon
# /wiki/Simone_Young
# /wiki/Hamburg_Ballett
# /wiki/John_Neumeier
# /wiki/Ballettschule_des_Hamburg_Ballett
# /wiki/Hamburg-Hamm
# /wiki/Datei:Laeiszhalle_-_Musikhalle.jpg
# /wiki/Datei:Laeiszhalle_-_Musikhalle.jpg
# /wiki/Laeiszhalle
# /wiki/Datei:Elbphilharmonie,_Hamburg.jpg
# /wiki/Datei:Elbphilharmonie,_Hamburg.jpg
# /wiki/Elbphilharmonie
# /wiki/Laeiszhalle
# /wiki/Carl_Laeisz
# /wiki/Martin_Haller_(Architekt)
# /wiki/Wilhelm_Emil_Meerwein
# /wiki/Johannes-Brahms-Platz
# /wiki/Elbphilharmonie
# /wiki/Hamburg-HafenCity
# /wiki/Basel
# /wiki/Herzog_%26_de_Meuron
# /wiki/Datei:Hamburg_Deutsches_Schauspielhaus_9438.jpg
# /wiki/Datei:Hamburg_Deutsches_Schauspielhaus_9438.jpg
# /wiki/Deutsches_Schauspielhaus
# /wiki/Deutsches_Schauspielhaus
# /wiki/Thalia_Theater_(Hamburg)
# /wiki/Ohnsorg-Theater
# /wiki/Kampnagel
# /wiki/Kultur_in_Hamburg#Theater
# /wiki/Hamburger_Volksb%C3%BChne
# /wiki/Verein
# /wiki/TheaterGemeinde_Hamburg
# /wiki/Hamburger_%C3%96ffentliche_B%C3%BCcherhallen
# /wiki/Blu-ray_Disc
# /wiki/DVD
# /wiki/Datei:Hamburg_Kunsthalle_2599.jpg
# /wiki/Datei:Hamburg_Kunsthalle_2599.jpg
# /wiki/Kunsthalle_Hamburg
# /wiki/Hamburger_Kunsthalle
# /wiki/Museum_f%C3%BCr_Kunst_und_Gewerbe
# /wiki/Deichtorhallen
# /wiki/Bucerius_Kunst_Forum
# /wiki/Museum_f%C3%BCr_Hamburgische_Geschichte
# /wiki/Museum_der_Arbeit
# /wiki/Museum_am_Rothenbaum
# /wiki/Planetarium_Hamburg
# /wiki/Miniatur_Wunderland
# /wiki/Panoptikum_Hamburg
# /wiki/Internationales_Maritimes_Museum_Hamburg
# /wiki/Hamburger_Hafen#Kultur
# /wiki/BallinStadt
# /wiki/KZ_Neuengamme
# /wiki/Liste_der_Museen_in_Hamburg
# /wiki/Datei:Hamburg-Radisson-Telemichel.jpg
# /wiki/Au%C3%9Fenalster
# /wiki/Datei:Hh_kbrue.jpg
# /wiki/K%C3%B6hlbrandbr%C3%BCcke
# /wiki/Datei:Nikolaikirche001.jpg
# /wiki/Ehemalige_Hauptkirche_St._Nikolai_(Hamburg)
# /wiki/Neuwerk
# /wiki/Elbe
# /wiki/Leuchtturm_Neuwerk
# /wiki/Kirche_Sinstorf
# /wiki/Hamburg-Sinstorf
# /wiki/Datei:Grundtri%C3%9F_der_edlen_weitberumbte_Statt_Hamburg_Anno_1651.jpg
# /wiki/Datei:Grundtri%C3%9F_der_edlen_weitberumbte_Statt_Hamburg_Anno_1651.jpg
# /wiki/Datei:Hamburg,_Speicherstadt,_Wasserschloss_--_2016_--_2944-50_(cropped).jpg
# /wiki/Datei:Hamburg,_Speicherstadt,_Wasserschloss_--_2016_--_2944-50_(cropped).jpg
# /wiki/Wasserschloss_(Hamburg)
# /wiki/Speicherstadt
# /wiki/Hamburger_Hauptkirchen
# /wiki/Hauptkirche_Sankt_Petri_(Hamburg)
# /wiki/Hauptkirche_Sankt_Jacobi_(Hamburg)
# /wiki/Hauptkirche_Sankt_Katharinen_(Hamburg)
# /wiki/Hauptkirche_Sankt_Michaelis_(Hamburg)
# /wiki/Wahrzeichen
# /wiki/Ehemalige_Hauptkirche_St._Nikolai_(Hamburg)
# /wiki/Hamburger_Rathaus
# /wiki/Hamburger_B%C3%B6rse
# /wiki/Skyline
# /wiki/Hamburger_Wallanlagen
# /wiki/D%C3%A4nemark
# /wiki/Lombardsbr%C3%BCcke
# /wiki/Lombardsbr%C3%BCcke#Kennedybrücke
# /wiki/Planten_un_Blomen
# /wiki/Alter_Elbpark
# /wiki/St._Pauli-Landungsbr%C3%BCcken
# /wiki/Fleet
# /wiki/Deichstra%C3%9Fe_(Hamburg)
# /wiki/Nikolaifleet
# /wiki/G%C3%A4ngeviertel_(Hamburg)
# /wiki/Krameramtsstuben
# /wiki/Datei:Hamburg_Jungfernstieg_(1890-1900).jpg
# /wiki/Datei:Hamburg_Jungfernstieg_(1890-1900).jpg
# /wiki/Alsterpavillon
# /wiki/Altonaer_Rathaus
# /wiki/Hamburg-Altona-Altstadt
# /wiki/Hamburg-Altona#Geschichte
# /wiki/Hamburger_Sternwarte
# /wiki/Universit%C3%A4t_Hamburg
# /wiki/Binnenalster
# /wiki/Jungfernstieg
# /wiki/Ballindamm
# /wiki/Alsterarkaden
# /wiki/Colonnaden
# /wiki/Speicherstadt
# /wiki/St._Pauli-Landungsbr%C3%BCcken
# /wiki/St._Pauli-Elbtunnel
# /wiki/Altonaer_Fischmarkt
# /wiki/Fischauktionshalle
# /wiki/Hamburg-Blankenese
# /wiki/Speicherstadt
# /wiki/Kontorhausviertel
# /wiki/UNESCO-Welterbe
# /wiki/Backstein
# /wiki/Klinker
# /wiki/Chilehaus
# /wiki/Backsteinexpressionismus
# /wiki/Hamburger_Innenstadt
# /wiki/Hamburg_Hauptbahnhof
# /wiki/Bahnhof_Hamburg_Dammtor
# /wiki/Curiohaus
# /wiki/Justizforum_Hamburg
# /wiki/Hanseatisches_Oberlandesgericht
# /wiki/Laeiszhalle
# /wiki/Hamburg-Eimsb%C3%BCttel
# /wiki/Grindel_(Hamburg)
# /wiki/Hamburg-Eppendorf
# /wiki/Harvestehude
# /wiki/Elbvororte
# /wiki/Emporio-Hochhaus
# /wiki/Mundsburg
# /wiki/Heinrich-Hertz-Turm
# /wiki/Rundfunksender_Billwerder-Moorfleet
# /wiki/K%C3%B6hlbrandbr%C3%BCcke
# /wiki/Hamburger_Stadtpark
# /wiki/City_Nord
# /wiki/Andreas_Dressel
# /wiki/Grundsteuer_C
# /wiki/Hamburg-HafenCity
# /wiki/Elbphilharmonie
# /wiki/U-Bahn-Linie_4_(Hamburg)
# /wiki/Datei:S%C3%BCllberg_(Blankenese).JPG
# /wiki/S%C3%BCllberg_(Hamburg)
# /wiki/Blankenese
# /wiki/Datei:Rathaus_Altona_o.jpg
# /wiki/Altonaer_Rathaus
# /wiki/Datei:Kontorhaus_Stubbenhuk_neu.JPG
# /wiki/Datei:Elbbr%C3%BCcken_mit_Cruise_Center.JPG
# /wiki/Datei:Elbbr%C3%BCcken_mit_Cruise_Center.JPG
# /wiki/Hamburg_Cruise_Center_HafenCity
# /wiki/Liste_von_Br%C3%BCcken_in_Hamburg
# /wiki/Binnendelta
# /wiki/Elbe
# /wiki/Niederung
# /wiki/Alster
# /wiki/Bille
# /wiki/Fleet
# /wiki/Kanal_(Wasserbau)
# /wiki/Stra%C3%9Fennetz
# /wiki/Schienennetz
# /wiki/Hochbahn
# /wiki/U-Bahn_Hamburg
# /wiki/Landesbetrieb_Stra%C3%9Fen,_Br%C3%BCcken_und_Gew%C3%A4sser
# /wiki/Lichtes_Ma%C3%9F
# /wiki/St%C3%BCtzweite
# /wiki/Tunnel
# /wiki/Deutsche_Bahn
# /wiki/Hamburg_Port_Authority
# /wiki/Hamburger_Hafenbahn
# /wiki/Hamburger_Hochbahn
# /wiki/AKN_Eisenbahn
# /wiki/Hagenbecks_Tierpark
# /wiki/Rohrunterst%C3%BCtzung
# /wiki/Fernw%C3%A4rme
# /wiki/Wasserleitung
# /wiki/Autobahn
# /wiki/Flughafen
# /wiki/Hamburg-Fuhlsb%C3%BCttel
# /wiki/Gunter_Demnig
# /wiki/Stolpersteine
# /wiki/Zeit_des_Nationalsozialismus
# /wiki/Liste_der_Stolpersteine_in_Hamburg
# /wiki/Datei:Alte_Wallgraben_in_Planten_un_Blomen.jpg
# /wiki/Datei:Alte_Wallgraben_in_Planten_un_Blomen.jpg
# /wiki/Park
# /wiki/Altonaer_Volkspark
# /wiki/Hamburger_Stadtpark
# /wiki/Planten_un_Blomen
# /wiki/Loki-Schmidt-Garten
# /wiki/Jenischpark
# /wiki/Vierlande
# /wiki/Marschlande
# /wiki/Hektar
# /wiki/Friedhof_Ohlsdorf
# /wiki/Alsterpark
# /wiki/Alster
# /wiki/Tierpark_Hagenbeck
# /wiki/Carl_Hagenbeck
# /wiki/Tierpark
# /wiki/Sport_in_Hamburg
# /wiki/Fu%C3%9Fball_in_Hamburg
# /wiki/Datei:Volksparkstadion_Panorama.jpg
# /wiki/Datei:Volksparkstadion_Panorama.jpg
# /wiki/Volksparkstadion
# /wiki/Hamburger_SV
# /wiki/Barclays_Arena
# /wiki/Volksparkstadion
# /wiki/Barclays_Arena
# /wiki/Alsterschwimmhalle
# /wiki/Sporthalle_Hamburg
# /wiki/Millerntor-Stadion
# /wiki/Hamburger_Stadtpark
# /wiki/Hamburger_Turnerschaft_von_1816
# /wiki/Hamburger_SV
# /wiki/Fu%C3%9Fball-Bundesliga
# /wiki/FC_St._Pauli
# /wiki/Hockey
# /wiki/Der_Club_an_der_Alster
# /wiki/Harvestehuder_THC
# /wiki/Uhlenhorster_HC
# /wiki/Unihockey
# /wiki/Eimsb%C3%BCtteler_TV
# /wiki/Unihockey-Bundesliga
# /wiki/Basketball
# /wiki/Hamburg_Towers
# /wiki/ProA
# /wiki/Basketball-Bundesliga
# /wiki/Baseball
# /wiki/Hamburg_Stealers
# /wiki/American_Football
# /wiki/Hamburg_Huskies
# /wiki/German_Football_League
# /wiki/Handball_Sport_Verein_Hamburg
# /wiki/Handball-Bundesliga
# /wiki/2._Handball-Bundesliga
# /wiki/Hamburg_Freezers
# /wiki/Deutsche_Eishockey_Liga
# /wiki/TV_Fischbek#Volleyball_(Frauen)
# /wiki/Hamburg-Marathon
# /wiki/Hamburg_Triathlon
# /wiki/Ironman_Hamburg
# /wiki/Vattenfall_Cyclassics
# /wiki/HSH_Nordbank_Run
# /wiki/Pferdesport_in_Hamburg
# /wiki/Deutsches_Derby
# /wiki/Deutsches_Spring_Derby
# /wiki/ATP_Hamburg
# /wiki/Fu%C3%9Fball-Weltmeisterschaft_1974
# /wiki/Fu%C3%9Fball-Weltmeisterschaft_2006
# /wiki/Handball-Weltmeisterschaft_der_M%C3%A4nner_2007
# /wiki/International_Triathlon_Union
# /wiki/Triathlon
# /wiki/Europa_League
# /wiki/Snooker
# /wiki/SC_Hamburg
# /wiki/1._Bundesliga_Snooker
# /wiki/Squash
# /wiki/Sportwerk_Hamburg_Waldd%C3%B6rfer
# /wiki/Billard
# /wiki/BC_Queue_Hamburg
# /wiki/2._Bundesliga_Pool
# /wiki/Sektion_Hamburg_und_Niederelbe_des_Deutschen_Alpenvereins
# /wiki/Sektion_(Alpenverein)
# /wiki/Liste_der_Sektionen_des_Deutschen_Alpenvereins
# /wiki/Schutzh%C3%BCtte
# /wiki/K%C3%BCnstliche_Kletteranlage
# /wiki/Deutscher_Alpenverein
# /wiki/Klettern
# /wiki/Bouldern
# /wiki/Olympische_Sommerspiele_2024
# /wiki/Hamburger_Olympia-B%C3%BCrgerschaftsreferendum
# /wiki/Olympische_Sommerspiele_2012
# /wiki/Leipzig
# /wiki/Hamburger_SV
# /wiki/Basketball-Bundesliga
# /wiki/Basketball-Bundesliga_2019/20
# /wiki/Logistik
# /wiki/Maritime_Wirtschaft
# /wiki/Luftfahrtindustrie
# /wiki/Konsumg%C3%BCterindustrie
# /wiki/Chemie
# /wiki/Elektrotechnik
# /wiki/Maschinenbau
# /wiki/Fahrzeugbau
# /wiki/Schiffbau
# /wiki/Mineral%C3%B6l
# /wiki/Kreditinstitut
# /wiki/Massenmedien
# /wiki/Versicherer
# /wiki/Tourismus
# /wiki/Erneuerbare_Energien
# /wiki/Life_Sciences
# /wiki/Zukunftsatlas
# /wiki/Handelskammer_Hamburg
# /wiki/Hamburger_B%C3%B6rse
# /wiki/Land_(Deutschland)
# /wiki/Bruttoinlandsprodukt
# /wiki/Bruttowertsch%C3%B6pfung
# /wiki/Europ%C3%A4ische_Union
# /wiki/Luxemburg
# /wiki/Kaufkraftstandard
# /wiki/Kaufkraft_(Konsum)
# /wiki/Bayern
# /wiki/Baden-W%C3%BCrttemberg
# /wiki/Hessen
# /wiki/NUTS
# /wiki/Senat_der_Freien_und_Hansestadt_Hamburg
# /wiki/Wahlspruch
# /wiki/Metropole
# /wiki/Endogen
# /wiki/Statistisches_Bundesamt
# /wiki/GENESIS_(Statistik)
# /wiki/%C3%96ffentlicher_Haushalt
# /wiki/B%C3%BCrgschaft_(Deutschland)
# /wiki/HSH_Nordbank
# /wiki/DAX
# /wiki/MDAX
# /wiki/SDAX
# /wiki/Beiersdorf_AG
# /wiki/Alstria_office
# /wiki/Aurubis
# /wiki/Evotec
# /wiki/TAG_Immobilien
# /wiki/Deutsche_EuroShop
# /wiki/Encavis
# /wiki/Fielmann
# /wiki/Hamburger_Hafen_und_Logistik
# /wiki/Jungheinrich
# /wiki/XING
# /wiki/Airbus
# /wiki/Asklepios_Kliniken_Hamburg
# /wiki/Universit%C3%A4tsklinikum_Hamburg-Eppendorf
# /wiki/HGV_(Unternehmen)
# /wiki/Medien_in_Hamburg
# /wiki/%C3%96ffentlicher_Personennahverkehr
# /wiki/Modal_Split
# /wiki/Berlin
# /wiki/Frankfurt_am_Main
# /wiki/M%C3%BCnchen
# /wiki/K%C3%B6ln
# /wiki/Datei:Hamburg_Autobahnen.svg
# /wiki/Datei:Hamburg_Autobahnen.svg
# /wiki/Kraftfahrzeug
# /wiki/Personenkraftwagen
# /wiki/Autobahn_(Deutschland)
# /wiki/Bundesautobahn_1
# /wiki/Europastra%C3%9Fe
# /wiki/Europastra%C3%9Fe_22
# /wiki/Bundesautobahn_7
# /wiki/Europastra%C3%9Fe_45
# /wiki/Bundesautobahn_23
# /wiki/Bundesautobahn_24
# /wiki/Europastra%C3%9Fe_26
# /wiki/Bundesautobahn_25
# /wiki/Bundesautobahn_252
# /wiki/Bundesautobahn_253
# /wiki/Bundesautobahn_255
# /wiki/Bundesautobahn_20
# /wiki/Prenzlau
# /wiki/Rostock
# /wiki/Bad_Segeberg
# /wiki/Umland
# /wiki/Bundesautobahn_26
# /wiki/Stade
# /wiki/Wesertunnel
# /wiki/Bundesautobahn_28
# /wiki/Bundesautobahn_29
# /wiki/Bundesstra%C3%9Fe
# /wiki/Bundesstra%C3%9Fe_3
# /wiki/Bundesstra%C3%9Fe_4
# /wiki/Bundesstra%C3%9Fe_5
# /wiki/Bundesstra%C3%9Fe_73
# /wiki/Bundesstra%C3%9Fe_75
# /wiki/Bundesstra%C3%9Fe_207
# /wiki/Bundesstra%C3%9Fe_431
# /wiki/Bundesstra%C3%9Fe_432
# /wiki/Bundesstra%C3%9Fe_433
# /wiki/Bundesstra%C3%9Fe_447
# /wiki/Radius
# /wiki/Tangente
# /wiki/Durchgangsverkehr
# /wiki/Stra%C3%9Fenring
# /wiki/Ring_1_(Hamburg)
# /wiki/Ring_2_(Hamburg)
# /wiki/Tempo-30-Zone
# /wiki/Datei:Hamburger_Fahrradh%C3%A4uschen2.jpg
# /wiki/Datei:Hamburger_Fahrradh%C3%A4uschen2.jpg
# /wiki/Datei:StadtRad_Station_Baumwall_Hafengeburtstag_2018.jpg
# /wiki/Datei:StadtRad_Station_Baumwall_Hafengeburtstag_2018.jpg
# /wiki/Fahrradklimatest
# /wiki/ADFC
# /wiki/StadtRAD_Hamburg
# /wiki/Hamburger_Fahrradh%C3%A4uschen
# /wiki/Hamburg-Nord
# /wiki/Vandalismus
# /wiki/Velorouten_in_Hamburg
# /wiki/Fahrradstra%C3%9Fe
# /wiki/Wandse
# /wiki/Falkenstein_(Hamburg)#Falkensteiner_Ufer
# /wiki/Elberadweg
# /wiki/Einbahnstra%C3%9Fe
# /wiki/Radfahrstreifen
# /wiki/Schutzstreifen_f%C3%BCr_Radfahrer
# /wiki/EuroVelo
# /wiki/Nordseek%C3%BCsten-Radweg
# /wiki/Elberadweg
# /wiki/Radfernweg_Hamburg%E2%80%93Bremen
# /wiki/Senat_Scholz_II
# /wiki/Radschnellweg
# /wiki/Loop_(Hamburg)
# /wiki/Deutscher_Fahrradpreis
# /wiki/Schienenverkehr_in_Hamburg
# /wiki/Datei:Hamburg_Hauptbahnhof_(13376981883).jpg
# /wiki/Datei:Hamburg_Hauptbahnhof_(13376981883).jpg
# /wiki/Hamburg_Hauptbahnhof
# /wiki/Eisenbahn
# /wiki/Nordeuropa
# /wiki/Hamburg-Bergedorfer_Eisenbahn
# /wiki/Schienenpersonenfernverkehr
# /wiki/Intercity-Express
# /wiki/Liste_der_Intercity-Express-Linien
# /wiki/Intercity_(Deutschland)
# /wiki/Liste_der_Intercity-Linien_(Deutschland)
# /wiki/Kopenhagen
# /wiki/Basel
# /wiki/Breslau
# /wiki/Wien
# /wiki/Z%C3%BCrich
# /wiki/Hamburg_Hauptbahnhof
# /wiki/Bahnhof_Hamburg-Altona
# /wiki/Bahnhof_Hamburg_Dammtor
# /wiki/Bahnhof_Hamburg-Harburg
# /wiki/Bahnhof_Hamburg-Bergedorf
# /wiki/Zentraler_Omnibusbahnhof_Hamburg
# /wiki/Fernbusse_in_Deutschland
# /wiki/Baltikum
# /wiki/Polen
# /wiki/Maschen
# /wiki/Rangierbahnhof
# /wiki/Maschen_Rangierbahnhof
# /wiki/Hamburger_Hafenbahn
# /wiki/Hamburger_Hafen
# /wiki/Nahverkehr_in_Hamburg
# /wiki/Regionalbahn
# /wiki/Regional-Express
# /wiki/Elmshorn
# /wiki/Padborg
# /wiki/Stade
# /wiki/Cuxhaven
# /wiki/L%C3%BCneburg
# /wiki/%C3%96ffentlicher_Personennahverkehr
# /wiki/Schnellbahn#Stadtschnellbahn
# /wiki/S-Bahn_Hamburg
# /wiki/U-Bahn_Hamburg
# /wiki/Schnellbahn
# /wiki/AKN_Eisenbahn
# /wiki/Hamburg-HafenCity
# /wiki/Speicherstadt
# /wiki/Jungfernstieg
# /wiki/U-Bahn-Linie_4_(Hamburg)
# /wiki/U-Bahnhof_Billstedt
# /wiki/Stadtbus
# /wiki/Metrobus
# /wiki/Schnellbus
# /wiki/F%C3%A4hre
# /wiki/Nachtverkehr
# /wiki/Stra%C3%9Fenbahn_Hamburg
# /wiki/Stadtbahn_Hamburg
# /wiki/Hamburger_Verkehrsverbund
# /wiki/Verkehrsverbund
# /wiki/L%C3%A4nderticket
# /wiki/Datei:Bahnlinien_im_HVV.png
# /wiki/Hamburger_Verkehrsverbund
# /wiki/Datei:HHA_DT5_-_306-III.JPG
# /wiki/U-Bahn_Hamburg
# /wiki/HHA_Typ_DT5
# /wiki/Hamburger_Hochbahn
# /wiki/Datei:DB_490117_Near_Harburg.jpg
# /wiki/DB-Baureihe_490
# /wiki/Datei:HADAG_Elbphilharmonie.jpg
# /wiki/Datei:HADAG_Elbphilharmonie.jpg
# /wiki/Niederelbe
# /wiki/Nordsee
# /wiki/Seeschiff
# /wiki/Ostsee
# /wiki/Nord-Ostsee-Kanal
# /wiki/Hamburg_Cruise_Center
# /wiki/Wasserstra%C3%9Fe
# /wiki/Binnenschifffahrt
# /wiki/Elbe
# /wiki/Binnenwasserstra%C3%9Fe
# /wiki/Unterelbe
# /wiki/Elbe
# /wiki/Elbe-L%C3%BCbeck-Kanal
# /wiki/Elbe-Seitenkanal
# /wiki/Mittellandkanal
# /wiki/HADAG_Seetouristik_und_F%C3%A4hrdienst
# /wiki/Teufelsbr%C3%BCck
# /wiki/St._Pauli-Landungsbr%C3%BCcken
# /wiki/Schulau_(Wedel)
# /wiki/L%C3%BChe_(Jork)
# /wiki/Alsterdampfer
# /wiki/Hamburger_Hafen
# /wiki/Seehafen
# /wiki/Hafen_Rotterdam
# /wiki/Hafen_Antwerpen
# /wiki/Teppich
# /wiki/Hamburger_Hafen_und_Logistik
# /wiki/Eurogate
# /wiki/Hektar
# /wiki/Hamburger_Hafenrundfahrten
# /wiki/Barkasse
# /wiki/Raddampfer
# /wiki/Altonaer_Balkon
# /wiki/Elbvertiefung
# /wiki/JadeWeserPort
# /wiki/Hamburg-HafenCity
# /wiki/Datei:Port_hamburg_panorama.jpg
# /wiki/Datei:HamburgerHafenLuftbild.jpg
# /wiki/Datei:Lufthansa_Technik_Hamburg_-_Airbus_A340.jpg
# /wiki/Datei:Lufthansa_Technik_Hamburg_-_Airbus_A340.jpg
# /wiki/Airbus_A340
# /wiki/Lufthansa_Technik
# /wiki/Flughafen_Hamburg
# /wiki/Helmut_Schmidt
# /wiki/Hamburg-Fuhlsb%C3%BCttel
# /wiki/Dubai
# /wiki/New_York_City
# /wiki/Teheran
# /wiki/S-Bahn_Hamburg
# /wiki/Hamburger_Verkehrsverbund
# /wiki/Fernbus
# /wiki/Lufthansa_Technik
# /wiki/Einflugschneise
# /wiki/Nachtflugverbot
# /wiki/Flughafen_Kaltenkirchen
# /wiki/Kaltenkirchen
# /wiki/Airbus
# /wiki/Airbus_Group
# /wiki/Flugplatz_Hamburg-Finkenwerder
# /wiki/Airbus-A320-Familie
# /wiki/Toulouse
# /wiki/Airbus_A380
# /wiki/Airbus_Beluga
# /wiki/Flughafen_L%C3%BCbeck
# /wiki/Billigfluggesellschaft
# /wiki/Ryanair
# /wiki/Datei:Pincerno_-_Wasserwerke_2009.png
# /wiki/Datei:Pincerno_-_Wasserwerke_2009.png
# /wiki/Wasserversorgung_in_Hamburg
# /wiki/Gleichordnungskonzern
# /wiki/Hamburg_Wasser
# /wiki/Fernw%C3%A4rme
# /wiki/Hamburgische_Electricit%C3%A4ts-Werke
# /wiki/Gaskraftwerk_Moorburg
# /wiki/Kohlekraftwerk_Moorburg
# /wiki/Aurubis
# /wiki/Abw%C3%A4rme
# /wiki/Kohlenstoffdioxid
# /wiki/Datei:Hh-affi.jpg
# /wiki/Datei:Hh-affi.jpg
# /wiki/Airbus#Deutschland
# /wiki/Diehl_Aerosystems
# /wiki/Werften_in_Hamburg
# /wiki/Blohm_%26_Voss
# /wiki/J._J._Sietas
# /wiki/Norderwerft
# /wiki/Neuenfelder_Maschinenfabrik
# /wiki/Muehlhan
# /wiki/Beiersdorf_AG
# /wiki/Nivea
# /wiki/Tesa
# /wiki/Mercedes-Benz_Cars#Mercedes-Benz_Werk_Hamburg
# /wiki/Daimler_AG
# /wiki/Vidal_%26_Sohn_Tempo-Werk
# /wiki/Harburger_Transporter
# /wiki/Philips
# /wiki/Philips_Deutschland
# /wiki/NXP_Semiconductors
# /wiki/Aurubis
# /wiki/Peute
# /wiki/Trimet_Aluminium
# /wiki/ArcelorMittal
# /wiki/Erd%C3%B6lraffinerie
# /wiki/Deutsche_Tamoil
# /wiki/H%26R_(Unternehmen)
# /wiki/Nynas
# /wiki/Sasol
# /wiki/K%C3%B6rber_AG
# /wiki/Hauni_Maschinenbau
# /wiki/Hidden_Champions
# /wiki/Harburg-Freudenberger
# /wiki/BW_Papersystems_Hamburg
# /wiki/Jungheinrich
# /wiki/Still_GmbH
# /wiki/Steinway_%26_Sons
# /wiki/Montblanc_(Unternehmen)
# /wiki/Wempe_Chronometerwerke
# /wiki/Dolmar_GmbH
# /wiki/Archer_Daniels_Midland
# /wiki/Nestl%C3%A9
# /wiki/Cargill
# /wiki/Ingredion
# /wiki/Holsten-Brauerei
# /wiki/Unilever
# /wiki/Carl_K%C3%BChne_KG
# /wiki/Senvion
# /wiki/Nordex_SE
# /wiki/Datei:HamburgKrugKoppelbr%C3%BCcke.JPG
# /wiki/Datei:HamburgKrugKoppelbr%C3%BCcke.JPG
# /wiki/Krugkoppelbr%C3%BCcke
# /wiki/Ortstaxe
# /wiki/Hotelstern
# /wiki/Medien_in_Hamburg
# /wiki/Der_Spiegel
# /wiki/Stern_(Zeitschrift)
# /wiki/Die_Zeit
# /wiki/Gruner_%2B_Jahr
# /wiki/Bauer_Verlagsgruppe
# /wiki/Jahreszeiten_Verlag
# /wiki/Axel_Springer_SE
# /wiki/Berlin
# /wiki/Prinovis
# /wiki/Deutsche_Presse-Agentur
# /wiki/ARD
# /wiki/ARD-aktuell
# /wiki/Norddeutscher_Rundfunk
# /wiki/Tagesschau_(ARD)
# /wiki/Tagesthemen
# /wiki/Nachtmagazin
# /wiki/Tagesschau24
# /wiki/Warner_Music_Group
# /wiki/Edel_Music
# /wiki/Universal_Music_Group
# /wiki/Subventionierung
# /wiki/L%C3%A4nderfinanzausgleich
# /wiki/Norddeutscher_Rundfunk
# /wiki/Studio_Hamburg
# /wiki/Synchronisation_(Film)
# /wiki/Zweites_Deutsches_Fernsehen
# /wiki/RTL_Television
# /wiki/Sat.1
# /wiki/Hamburg_1
# /wiki/Filmf%C3%B6rderung_Hamburg_Schleswig-Holstein
# /wiki/Scholz_%26_Friends
# /wiki/Jung_von_Matt
# /wiki/TBWA
# /wiki/Peter_Schmidt_(Designer)
# /wiki/Landor_Associates
# /wiki/Liste_von_Sendeanlagen_in_Hamburg
# /wiki/Multimedia
# /wiki/SinnerSchrader
# /wiki/Tipp24
# /wiki/Social_Media
# /wiki/Xing_(soziales_Netzwerk)
# /wiki/ElitePartner
# /wiki/Parship
# /wiki/Google
# /wiki/Facebook
# /wiki/Twitter
# /wiki/Yelp,_Inc.
# /wiki/Dropbox
# /wiki/Freenet_Group
# /wiki/Internetanbieter
# /wiki/Bauer_Media_Group
# /wiki/Spiegel_Online
# /wiki/Google
# /wiki/Yahoo
# /wiki/Videospiel
# /wiki/Publisher
# /wiki/Dtp_entertainment
# /wiki/Codemasters
# /wiki/Eidos_Interactive
# /wiki/Bigpoint
# /wiki/InnoGames
# /wiki/Goodgame_Studios
# /wiki/Fishlabs
# /wiki/IBM
# /wiki/Lufthansa_Systems
# /wiki/Oracle
# /wiki/Adobe_Inc.
# /wiki/Logica
# /wiki/SAP
# /wiki/Synergie
# /wiki/Hamburg@work
# /wiki/.hamburg
# /wiki/Deutsche_Bundesbank
# /wiki/Hamburgische_M%C3%BCnze
# /wiki/HSH_Nordbank
# /wiki/Hamburger_Sparkasse
# /wiki/Sparkasse_Harburg-Buxtehude
# /wiki/Hanseatischer_Sparkassen-_und_Giroverband
# /wiki/Genossenschaftsbank
# /wiki/DZ_Hyp
# /wiki/Hamburger_Volksbank
# /wiki/Sparda-Bank_Hamburg
# /wiki/MKB_Mittelstandskreditbank
# /wiki/Edekabank
# /wiki/Netbank
# /wiki/Deutsche_Bank
# /wiki/Norddeutsche_Bank
# /wiki/Unicredit_Bank
# /wiki/Unicredit_Bank#Nach_der_zweiten_Fusion
# /wiki/UBS
# /wiki/Schr%C3%B6der,_M%C3%BCnchmeyer,_Hengst_%26_Co.
# /wiki/Commerzbank
# /wiki/M.M.Warburg_%26_CO
# /wiki/Berenberg_Bank
# /wiki/Bankhaus_W%C3%B6lbern_%26_Co.
# /wiki/Donner_%26_Reuschel
# /wiki/Signal_Iduna
# /wiki/Marcard,_Stein_%26_Co
# /wiki/Sutor_Bank
# /wiki/Otto_Group
# /wiki/Hanseatic_Bank
# /wiki/Versicherer
# /wiki/Versicherungsmakler_(Deutschland)
# /wiki/Versicherungsvermittler
# /wiki/Signal_Iduna
# /wiki/Deutscher_Ring
# /wiki/HanseMerkur_Versicherungsgruppe
# /wiki/Neue_leben
# /wiki/Hamburger_Pensionskasse_von_1905
# /wiki/Aon_Jauch_%26_H%C3%BCbener
# /wiki/Funk_Gruppe
# /wiki/Allianz_SE
# /wiki/Euler_Hermes
# /wiki/M%C3%BCnchener_R%C3%BCck
# /wiki/Ergo_Lebensversicherung
# /wiki/Generali_Deutschland
# /wiki/Volksf%C3%BCrsorge
# /wiki/Advocard_Rechtsschutzversicherung
# /wiki/R%2BV_Versicherung
# /wiki/R%2BV_Versicherung
# /wiki/KRAVAG
# /wiki/B%C3%A2loise
# /wiki/Deutscher_Ring
# /wiki/Techniker_Krankenkasse
# /wiki/Krankenkasse
# /wiki/Gesetzliche_Krankenversicherung
# /wiki/DAK-Gesundheit
# /wiki/HEK_%E2%80%93_Hanseatische_Krankenkasse
# /wiki/Continentale_Betriebskrankenkasse
# /wiki/Versicherungswirtschaft
# /wiki/Hamburger_Feuerkasse
# /wiki/Hamburger_B%C3%B6rse#Versicherungsbörse
# /wiki/Gesamtverband_der_Deutschen_Versicherungswirtschaft
# /wiki/Verband_Deutscher_Versicherungsmakler
# /wiki/Bund_der_Versicherten
# /wiki/B%C3%96AG_B%C3%B6rsen
# /wiki/Hamburger_B%C3%B6rse
# /wiki/B%C3%96AG_B%C3%B6rsen
# /wiki/Datei:Mess-Turm.jpg
# /wiki/Datei:Mess-Turm.jpg
# /wiki/Hamburg_Messe
# /wiki/Heinrich-Hertz-Turm
# /wiki/Congress_Center_Hamburg
# /wiki/Radisson_Blu_Hotel_Hamburg
# /wiki/Bahnhof_Hamburg_Dammtor
# /wiki/Planten_un_Blomen
# /wiki/Hamburg_Messe
# /wiki/Messe_(Wirtschaft)
# /wiki/Internorga
# /wiki/Hanseboot
# /wiki/Hamburg_Messe_und_Congress
# /wiki/Spitalerstra%C3%9Fe
# /wiki/M%C3%B6nckebergstra%C3%9Fe
# /wiki/Neuer_Wall
# /wiki/Europa_Passage
# /wiki/Internationaler_Seegerichtshof
# /wiki/Elbchaussee
# /wiki/Hanseatisches_Oberlandesgericht
# /wiki/Landgericht_Hamburg
# /wiki/Bundesforschungsanstalt_f%C3%BCr_Fischerei
# /wiki/Bundesamt_f%C3%BCr_Seeschifffahrt_und_Hydrographie
# /wiki/Deutscher_Wetterdienst
# /wiki/Bernhard-Nocht-Institut_f%C3%BCr_Tropenmedizin
# /wiki/Heinrich-Pette-Institut,_Leibniz-Institut_f%C3%BCr_Experimentelle_Virologie
# /wiki/Deutsches_Elektronen-Synchrotron
# /wiki/Gewerkschaft_Nahrung-Genuss-Gastst%C3%A4tten
# /wiki/Greenpeace
# /wiki/Stiftung_Schifffahrtsstandort_Deutschland
# /wiki/Hauptzollamt
# /wiki/Bundespolizei_(Deutschland)
# /wiki/Generalzolldirektion
# /wiki/Berufsgenossenschaft
# /wiki/F%C3%BChrungsakademie_der_Bundeswehr
# /wiki/Helmut-Schmidt-Universit%C3%A4t/Universit%C3%A4t_der_Bundeswehr_Hamburg
# /wiki/Bundeswehr
# /wiki/M%C3%A4zen
# /wiki/Feuerwehr_Hamburg
# /wiki/Berufsfeuerwehr
# /wiki/Feuerwehrhaus
# /wiki/Freiwillige_Feuerwehr
# /wiki/Datei:UniHHHauptgebaeude.jpg
# /wiki/Datei:UniHHHauptgebaeude.jpg
# /wiki/Bildung_und_Forschung_in_Hamburg
# /wiki/Allgemeinbildende_Schule
# /wiki/Berufsbildende_Schule
# /wiki/F%C3%B6rderschule_(Deutschland)
# /wiki/Sprachheilschule
# /wiki/Hochschule
# /wiki/Grundschule
# /wiki/Weiterf%C3%BChrende_Schule
# /wiki/Privatschule
# /wiki/Fachschule_(Deutschland)
# /wiki/Land_(Deutschland)
# /wiki/European_XFEL
# /wiki/Deutsches_Elektronen-Synchrotron
# /wiki/Datei:Portal.svg
# /wiki/Portal:Hamburg
# /wiki/Uwe_Bahnsen_(Journalist)
# /wiki/Spezial:ISBN-Suche/3934613896
# /wiki/Spezial:ISBN-Suche/9783868590784
# /wiki/Pahl-Rugenstein_Verlag
# /wiki/Spezial:ISBN-Suche/3760906540
# /wiki/Spezial:ISBN-Suche/9783838203874
# /wiki/Spezial:ISBN-Suche/9783838204574
# /wiki/Gert_K%C3%A4hler
# /wiki/Spezial:ISBN-Suche/9783862180318
# /wiki/Spezial:ISBN-Suche/9783861534730
# /wiki/J%C3%B6rg_Duppler
# /wiki/F%C3%BChrungsakademie_der_Bundeswehr
# /wiki/Spezial:ISBN-Suche/3813203182
# /wiki/J%C3%B6rn_D%C3%BCwel
# /wiki/Niels_Gutschow
# /wiki/Spezial:ISBN-Suche/9783869223209
# /wiki/Siegfried_Gr%C3%A4ff
# /wiki/Spezial:ISBN-Suche/3596160367
# /wiki/Georg_Hindrichson
# /wiki/Werner_Jochmann_(Historiker)
# /wiki/Hans-Dieter_Loose
# /wiki/Spezial:ISBN-Suche/3455087094
# /wiki/Spezial:ISBN-Suche/3455082556
# /wiki/Spezial:ISBN-Suche/9783867740098
# /wiki/Spezial:ISBN-Suche/9783898367844
# /wiki/Eckart_Kle%C3%9Fmann
# /wiki/Spezial:ISBN-Suche/3434525963
# /wiki/Franklin_Kopitzsch
# /wiki/Spezial:ISBN-Suche/9783831903733
# /wiki/Martin_Krieger_(Historiker)
# ...
# /wiki/F%C3%BCrth
# /wiki/G%C3%B6ttingen
# /wiki/G%C3%BCtersloh
# /wiki/Hagen
# /wiki/Halle_(Saale)
# /wiki/Hamm
# /wiki/Heidelberg
# /wiki/Heilbronn
# /wiki/Herne
# /wiki/Hildesheim
# /wiki/Ingolstadt
# /wiki/Jena
# /wiki/Kassel
# /wiki/Kiel
# /wiki/Koblenz
# /wiki/Krefeld
# /wiki/Leverkusen
# /wiki/L%C3%BCbeck
# /wiki/Ludwigshafen_am_Rhein
# /wiki/Magdeburg
# /wiki/Mainz
# /wiki/Moers
# /wiki/M%C3%BClheim_an_der_Ruhr
# /wiki/Neuss
# /wiki/Oberhausen
# /wiki/Offenbach_am_Main
# /wiki/Oldenburg_(Oldb)
# /wiki/Osnabr%C3%BCck
# /wiki/Paderborn
# /wiki/Pforzheim
# /wiki/Potsdam
# /wiki/Recklinghausen
# /wiki/Regensburg
# /wiki/Remscheid
# /wiki/Reutlingen
# /wiki/Rostock
# /wiki/Saarbr%C3%BCcken
# /wiki/Salzgitter
# /wiki/Siegen
# /wiki/Solingen
# /wiki/Trier
# /wiki/Ulm
# /wiki/Wolfsburg
# /wiki/W%C3%BCrzburg
# /wiki/Liste_der_Mitgliedstaaten_im_Deutschen_Bund
# /wiki/Deutscher_Bund
# /wiki/Datei:Flag_of_the_Habsburg_Monarchy.svg
# /wiki/Kaisertum_%C3%96sterreich
# /wiki/Datei:Wappen_Deutscher_Bund.svg
# /wiki/Datei:Flag_of_Bavaria_(striped).svg
# /wiki/K%C3%B6nigreich_Bayern
# /wiki/Datei:Flag_of_Hanover_1837-1866.svg
# /wiki/K%C3%B6nigreich_Hannover
# /wiki/Datei:Flag_of_the_Kingdom_of_Prussia_(1803-1892).svg
# /wiki/K%C3%B6nigreich_Preu%C3%9Fen
# /wiki/Datei:Flagge_K%C3%B6nigreich_Sachsen_(1815-1918).svg
# /wiki/K%C3%B6nigreich_Sachsen
# /wiki/Datei:Flagge_K%C3%B6nigreich_W%C3%BCrttemberg.svg
# /wiki/K%C3%B6nigreich_W%C3%BCrttemberg
# /wiki/Datei:Flag_of_Hesse.svg
# /wiki/Kurf%C3%BCrstentum_Hessen
# /wiki/Datei:Flag_of_the_Grand_Duchy_of_Baden_(1855%E2%80%931891).svg
# /wiki/Gro%C3%9Fherzogtum_Baden
# /wiki/Datei:Flagge_Gro%C3%9Fherzogtum_Hessen_ohne_Wappen.svg
# /wiki/Gro%C3%9Fherzogtum_Hessen
# /wiki/Datei:Flag_of_Luxembourg.svg
# /wiki/Luxemburg
# /wiki/Datei:Flagge_Gro%C3%9Fherzogt%C3%BCmer_Mecklenburg.svg
# /wiki/Mecklenburg-Schwerin
# /wiki/Datei:Flagge_Gro%C3%9Fherzogt%C3%BCmer_Mecklenburg.svg
# /wiki/Mecklenburg-Strelitz
# /wiki/Datei:Civil_flag_of_Oldenburg.svg
# /wiki/Gro%C3%9Fherzogtum_Oldenburg
# /wiki/Datei:Flagge_Gro%C3%9Fherzogtum_Sachsen-Weimar-Eisenach_(1813-1897).svg
# /wiki/Sachsen-Weimar-Eisenach
# /wiki/Datei:Flagge_Herzogtum_Anhalt.svg
# /wiki/Herzogtum_Anhalt
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1826-1911).svg
# /wiki/F%C3%BCrstentum_Anhalt-Bernburg
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1826-1911).svg
# /wiki/F%C3%BCrstentum_Anhalt-Dessau
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1826-1911).svg
# /wiki/F%C3%BCrstentum_Anhalt-K%C3%B6then
# /wiki/Datei:Flag_of_Tirol_and_Upper_Austria.svg
# /wiki/Herzogtum_Holstein
# /wiki/Datei:Flag_of_Lauenburg.svg
# /wiki/Herzogtum_Sachsen-Lauenburg
# /wiki/Datei:Limburg.svg
# /wiki/Herzogtum_Limburg_(1839%E2%80%931866)
# /wiki/Datei:Flagge_Herzogtum_Nassau_(1806-1866).svg
# /wiki/Herzogtum_Nassau
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1826-1911).svg
# /wiki/Herzogtum_Sachsen-Altenburg
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1826-1911).svg
# /wiki/Sachsen-Coburg-Saalfeld
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1826-1911).svg
# /wiki/Herzogtum_Sachsen-Coburg_und_Gotha
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1826-1911).svg
# /wiki/Herzogtum_Sachsen-Gotha-Altenburg
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1826-1911).svg
# /wiki/Herzogtum_Sachsen-Hildburghausen
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1826-1911).svg
# /wiki/Herzogtum_Sachsen-Meiningen
# /wiki/Datei:Flagge_Herzogtum_Braunschweig.svg
# /wiki/Herzogtum_Braunschweig
# /wiki/Datei:Hessen_HG_flag.svg
# /wiki/Hessen-Homburg
# /wiki/Datei:Flag_of_Hohenzollern-Hechingen_and_Sigmaringen.png
# /wiki/Hohenzollern-Hechingen
# /wiki/Datei:Flag_of_Hohenzollern-Hechingen_and_Sigmaringen.png
# /wiki/Hohenzollern-Sigmaringen
# /wiki/Datei:Flag_of_Liechtenstein_(1852%E2%80%931921).svg
# /wiki/Liechtenstein
# /wiki/Datei:Flagge_F%C3%BCrstentum_Lippe.svg
# /wiki/F%C3%BCrstentum_Lippe
# /wiki/Datei:Flagge_F%C3%BCrstentum_Reu%C3%9F_%C3%A4ltere_Linie.svg
# /wiki/Reu%C3%9F_%C3%A4lterer_Linie
# /wiki/Datei:Flagge_F%C3%BCrstentum_Reu%C3%9F_j%C3%BCngere_Linie.svg
# /wiki/Reu%C3%9F_j%C3%BCngerer_Linie
# /wiki/Datei:Flagge_F%C3%BCrstentum_Reu%C3%9F_j%C3%BCngere_Linie.svg
# /wiki/Reu%C3%9F-Ebersdorf
# /wiki/Datei:Flag_of_Reuss-Lobenstein.svg
# /wiki/Reu%C3%9F-Lobenstein
# /wiki/Datei:Flagge_F%C3%BCrstentum_Reu%C3%9F_j%C3%BCngere_Linie.svg
# /wiki/Reu%C3%9F-Ebersdorf
# /wiki/Datei:Flagge_F%C3%BCrstentum_Reu%C3%9F_j%C3%BCngere_Linie.svg
# /wiki/Reu%C3%9F-Schleiz
# /wiki/Datei:Flagge_F%C3%BCrstentum_Schaumburg-Lippe.svg
# /wiki/Schaumburg-Lippe
# /wiki/Datei:Flagge_F%C3%BCrstent%C3%BCmer_Schwarzburg.svg
# /wiki/Schwarzburg-Rudolstadt
# /wiki/Datei:Flagge_F%C3%BCrstent%C3%BCmer_Schwarzburg.svg
# /wiki/Schwarzburg-Sondershausen
# /wiki/Datei:Flag_of_Germany_(3-2_aspect_ratio).svg
# /wiki/Waldeck
# /wiki/Datei:Flag_of_Bremen.svg
# /wiki/Freie_Hansestadt_Bremen
# /wiki/Datei:Flag_of_the_Free_City_of_Frankfurt.svg
# /wiki/Freie_Stadt_Frankfurt
# /wiki/Datei:Flag_of_Hamburg.svg
# /wiki/Datei:Flag_of_the_Free_City_of_L%C3%BCbeck.svg
# /wiki/L%C3%BCbeck
# /wiki/Datei:ZollvereinBIG_1834.png
# /wiki/Deutscher_Zollverein
# /wiki/Datei:Flag_of_the_Kingdom_of_Prussia_(1803-1892).svg
# /wiki/K%C3%B6nigreich_Preu%C3%9Fen
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1826-1911).svg
# /wiki/Anhalt-Bernburg
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1826-1911).svg
# /wiki/Anhalt-Dessau
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1826-1911).svg
# /wiki/Anhalt-K%C3%B6then
# /wiki/Datei:Flagge_Herzogtum_Anhalt.svg
# /wiki/Anhalt
# /wiki/Datei:Flag_of_Germany_(3-2_aspect_ratio).svg
# /wiki/Waldeck
# /wiki/Datei:Flagge_F%C3%BCrstentum_Lippe.svg
# /wiki/F%C3%BCrstentum_Lippe
# /wiki/Datei:Flag_of_Lauenburg.svg
# /wiki/Herzogtum_Sachsen-Lauenburg
# /wiki/Datei:Flag_of_Schleswig-Holstein.svg
# /wiki/Provinz_Schleswig-Holstein
# /wiki/Datei:Flagge_Gro%C3%9Fherzogtum_Hessen_ohne_Wappen.svg
# /wiki/Gro%C3%9Fherzogtum_Hessen
# /wiki/Datei:Flag_of_Hesse.svg
# /wiki/Kurf%C3%BCrstentum_Hessen
# /wiki/Datei:Hessen_HG_flag.svg
# /wiki/Hessen-Homburg
# /wiki/Datei:Flag_of_Bavaria_(striped).svg
# /wiki/K%C3%B6nigreich_Bayern
# /wiki/Datei:Flagge_K%C3%B6nigreich_W%C3%BCrttemberg.svg
# /wiki/K%C3%B6nigreich_W%C3%BCrttemberg
# /wiki/Datei:Flag_of_Hohenzollern-Hechingen_and_Sigmaringen.png
# /wiki/Hohenzollern-Hechingen
# /wiki/Datei:Flag_of_Hohenzollern-Hechingen_and_Sigmaringen.png
# /wiki/Hohenzollern-Sigmaringen
# /wiki/Datei:Flagge_K%C3%B6nigreich_Sachsen_(1815-1918).svg
# /wiki/K%C3%B6nigreich_Sachsen
# /wiki/Zoll-_und_Handelsverein_der_Th%C3%BCringischen_Staaten
# /wiki/Datei:Flagge_Gro%C3%9Fherzogtum_Sachsen-Weimar-Eisenach_(1813-1897).svg
# /wiki/Sachsen-Weimar-Eisenach
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1826-1911).svg
# /wiki/Herzogtum_Sachsen-Altenburg
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1826-1911).svg
# /wiki/Herzogtum_Sachsen-Meiningen
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1826-1911).svg
# /wiki/Herzogtum_Sachsen-Coburg_und_Gotha
# /wiki/Datei:Flagge_F%C3%BCrstent%C3%BCmer_Schwarzburg.svg
# /wiki/Schwarzburg-Rudolstadt
# /wiki/Datei:Flagge_F%C3%BCrstent%C3%BCmer_Schwarzburg.svg
# /wiki/Schwarzburg-Sondershausen
# /wiki/Datei:Flagge_F%C3%BCrstentum_Reu%C3%9F_%C3%A4ltere_Linie.svg
# /wiki/Reu%C3%9F_%C3%A4lterer_Linie
# /wiki/Datei:Flagge_F%C3%BCrstentum_Reu%C3%9F_j%C3%BCngere_Linie.svg
# /wiki/Reu%C3%9F_j%C3%BCngerer_Linie
# /wiki/Datei:Flagge_F%C3%BCrstentum_Reu%C3%9F_j%C3%BCngere_Linie.svg
# /wiki/Reu%C3%9F-Schleiz
# /wiki/Datei:Flagge_F%C3%BCrstentum_Reu%C3%9F_j%C3%BCngere_Linie.svg
# /wiki/Reu%C3%9F-Ebersdorf
# /wiki/Datei:Flag_of_the_Grand_Duchy_of_Baden_(1855%E2%80%931891).svg
# /wiki/Gro%C3%9Fherzogtum_Baden
# /wiki/Datei:Flagge_Herzogtum_Nassau_(1806-1866).svg
# /wiki/Herzogtum_Nassau
# /wiki/Datei:Flag_of_the_Free_City_of_Frankfurt.svg
# /wiki/Freie_Stadt_Frankfurt
# /wiki/Datei:Flagge_Herzogtum_Braunschweig.svg
# /wiki/Herzogtum_Braunschweig
# /wiki/Datei:Flag_of_Luxembourg.svg
# /wiki/Luxemburg
# /wiki/Datei:Flag_of_Hanover_1837-1866.svg
# /wiki/K%C3%B6nigreich_Hannover
# /wiki/Datei:Flagge_F%C3%BCrstentum_Schaumburg-Lippe.svg
# /wiki/Schaumburg-Lippe
# /wiki/Datei:Civil_flag_of_Oldenburg.svg
# /wiki/Gro%C3%9Fherzogtum_Oldenburg
# /wiki/Datei:Flag_of_Hamburg.svg
# /wiki/Datei:Flag_of_Bremen.svg
# /wiki/Freie_Hansestadt_Bremen
# /wiki/Datei:Flag_of_the_Free_City_of_L%C3%BCbeck.svg
# /wiki/L%C3%BCbeck
# /wiki/Datei:Dienstflagge_Elsa%C3%9F-Lothringen_Kaiserreich.svg
# /wiki/Reichsland_Elsa%C3%9F-Lothringen
# /wiki/Datei:Flagge_Gro%C3%9Fherzogt%C3%BCmer_Mecklenburg.svg
# /wiki/Mecklenburg-Strelitz
# /wiki/Datei:Flagge_Gro%C3%9Fherzogt%C3%BCmer_Mecklenburg.svg
# /wiki/Mecklenburg-Schwerin
# /wiki/Deutsches_Kaiserreich
# /wiki/Datei:Flag_of_Bavaria_(striped).svg
# /wiki/K%C3%B6nigreich_Bayern
# /wiki/Datei:Flag_of_Prussia_(1892-1918).svg
# /wiki/K%C3%B6nigreich_Preu%C3%9Fen
# /wiki/Datei:Flagge_K%C3%B6nigreich_Sachsen_(1815-1918).svg
# /wiki/K%C3%B6nigreich_Sachsen
# /wiki/Datei:Flagge_K%C3%B6nigreich_W%C3%BCrttemberg.svg
# /wiki/K%C3%B6nigreich_W%C3%BCrttemberg
# /wiki/Datei:Flag_of_Germany_(1867%E2%80%931918).svg
# /wiki/Datei:Flagge_Gro%C3%9Fherzogtum_Baden_(1891%E2%80%931918).svg
# /wiki/Gro%C3%9Fherzogtum_Baden
# /wiki/Datei:Flagge_Gro%C3%9Fherzogtum_Hessen_ohne_Wappen.svg
# /wiki/Gro%C3%9Fherzogtum_Hessen
# /wiki/Datei:Flagge_Gro%C3%9Fherzogt%C3%BCmer_Mecklenburg.svg
# /wiki/Mecklenburg-Schwerin
# /wiki/Datei:Flagge_Gro%C3%9Fherzogt%C3%BCmer_Mecklenburg.svg
# /wiki/Mecklenburg-Strelitz
# /wiki/Datei:Civil_flag_of_Oldenburg.svg
# /wiki/Gro%C3%9Fherzogtum_Oldenburg
# /wiki/Datei:Flagge_Gro%C3%9Fherzogtum_Sachsen-Weimar-Eisenach_(1897-1920).svg
# /wiki/Sachsen-Weimar-Eisenach
# /wiki/Datei:Flagge_Herzogtum_Anhalt.svg
# /wiki/Anhalt
# /wiki/Datei:Flagge_Herzogtum_Braunschweig.svg
# /wiki/Herzogtum_Braunschweig
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1826-1911).svg
# /wiki/Sachsen-Altenburg
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1911-1920).svg
# /wiki/Herzogtum_Sachsen-Coburg_und_Gotha
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1826-1911).svg
# /wiki/Herzogtum_Sachsen-Meiningen
# /wiki/Datei:Flagge_F%C3%BCrstentum_Lippe.svg
# /wiki/F%C3%BCrstentum_Lippe
# /wiki/Datei:Flagge_F%C3%BCrstentum_Reu%C3%9F_%C3%A4ltere_Linie.svg
# /wiki/Reu%C3%9F_%C3%A4lterer_Linie
# /wiki/Datei:Flagge_F%C3%BCrstentum_Reu%C3%9F_j%C3%BCngere_Linie.svg
# /wiki/Reu%C3%9F_j%C3%BCngerer_Linie
# /wiki/Datei:Flagge_F%C3%BCrstentum_Schaumburg-Lippe.svg
# /wiki/Schaumburg-Lippe
# /wiki/Datei:Flagge_F%C3%BCrstent%C3%BCmer_Schwarzburg.svg
# /wiki/Schwarzburg-Rudolstadt
# /wiki/Datei:Flagge_F%C3%BCrstent%C3%BCmer_Schwarzburg.svg
# /wiki/Schwarzburg-Sondershausen
# /wiki/Datei:Flag_of_Germany_(3-2_aspect_ratio).svg
# /wiki/Waldeck
# /wiki/Datei:Flag_of_Bremen.svg
# /wiki/Freie_Hansestadt_Bremen
# /wiki/Datei:Flag_of_Hamburg.svg
# /wiki/Geschichte_Hamburgs#Deutsches_Reich
# /wiki/Datei:Flag_of_the_Free_City_of_L%C3%BCbeck.svg
# /wiki/L%C3%BCbeck
# /wiki/Datei:Dienstflagge_Elsa%C3%9F-Lothringen_Kaiserreich.svg
# /wiki/Reichsland_Elsa%C3%9F-Lothringen
# /wiki/Datei:Flag_of_Germany_(3-2_aspect_ratio).svg
# /wiki/Freistaat_Anhalt
# /wiki/Freistaat_Anhalt
# /wiki/Datei:Flagge_Gro%C3%9Fherzogtum_Baden_(1891%E2%80%931918).svg
# /wiki/Republik_Baden
# /wiki/Datei:Flag_of_Bavaria_(striped).svg
# /wiki/Geschichte_Bayerns#Bayern_zwischen_den_Weltkriegen
# /wiki/Datei:Flagge_Herzogtum_Braunschweig.svg
# /wiki/Freistaat_Braunschweig
# /wiki/Datei:Flag_of_Bremen.svg
# /wiki/Geschichte_der_Stadt_Bremen#20._Jahrhundert
# /wiki/Datei:Flag_of_Hamburg.svg
# /wiki/Geschichte_Hamburgs#Weimarer_Republik
# /wiki/Datei:Flagge_Gro%C3%9Fherzogtum_Hessen_ohne_Wappen.svg
# /wiki/Volksstaat_Hessen
# /wiki/Datei:Flagge_F%C3%BCrstentum_Lippe.svg
# /wiki/Freistaat_Lippe
# /wiki/Datei:Flagge_der_Hansestadt_L%C3%BCbeck.svg
# /wiki/Geschichte_der_Hansestadt_L%C3%BCbeck#20._Jahrhundert
# /wiki/Datei:Flagge_Gro%C3%9Fherzogt%C3%BCmer_Mecklenburg.svg
# /wiki/Mecklenburg-Schwerin#Freistaat_Mecklenburg-Schwerin_(1919–1933)
# /wiki/Datei:Flagge_Gro%C3%9Fherzogt%C3%BCmer_Mecklenburg.svg
# /wiki/Mecklenburg-Strelitz#Freistaat_Mecklenburg-Strelitz_(1918–1933)
# /wiki/Datei:Flag_of_Oldenburg_(Scandinavian_Cross).svg
# /wiki/Freistaat_Oldenburg
# /wiki/Datei:Flag_of_Prussia_(1918%E2%80%931933).svg
# /wiki/Freistaat_Preu%C3%9Fen
# /wiki/Datei:State_flag_of_the_Saxony_(1815-1952).svg
# /wiki/Geschichte_Sachsens#Sachsen_ab_dem_20._Jahrhundert
# /wiki/Datei:Flagge_F%C3%BCrstentum_Schaumburg-Lippe.svg
# /wiki/Freistaat_Schaumburg-Lippe
# /wiki/Datei:Flag_of_Thuringia.svg
# /wiki/Land_Th%C3%BCringen_(1920%E2%80%931952)
# /wiki/Datei:Flagge_K%C3%B6nigreich_W%C3%BCrttemberg.svg
# /wiki/Volksstaat_W%C3%BCrttemberg
# /wiki/Datei:Flag_of_Saar_1920-1935.svg
# /wiki/Saargebiet
# /wiki/Datei:Flag_of_Germany_(3-2_aspect_ratio).svg
# /wiki/Volksstaat_Reu%C3%9F
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1826-1911).svg
# /wiki/Freistaat_Sachsen-Altenburg
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1911-1920).svg
# /wiki/Freistaat_Sachsen-Gotha
# /wiki/Datei:Flagge_Herzogtum_Sachsen-Coburg-Gotha_(1826-1911).svg
# /wiki/Freistaat_Sachsen-Meiningen
# /wiki/Datei:Flagge_Gro%C3%9Fherzogtum_Sachsen-Weimar-Eisenach_(1897-1920).svg
# /wiki/Freistaat_Sachsen-Weimar-Eisenach
# /wiki/Datei:Flagge_F%C3%BCrstent%C3%BCmer_Schwarzburg.svg
# /wiki/Freistaat_Schwarzburg-Rudolstadt
# /wiki/Datei:Flagge_F%C3%BCrstent%C3%BCmer_Schwarzburg.svg
# /wiki/Freistaat_Schwarzburg-Sondershausen
# /wiki/Datei:Flag_of_Germany_(3-2_aspect_ratio).svg
# /wiki/Waldeck
# /wiki/Carl_Eduard_(Sachsen-Coburg_und_Gotha)
# /wiki/Herzogtum_Sachsen-Coburg_und_Gotha
# /wiki/Freistaat_Coburg
# /wiki/Anhalt
# /wiki/Baden_(Land)
# /wiki/Geschichte_Bayerns#Bayern_unter_dem_Nationalsozialismus
# /wiki/Land_Braunschweig
# /wiki/Bremen_zur_Zeit_des_Nationalsozialismus
# /wiki/Hamburg_in_der_Zeit_des_Nationalsozialismus
# /wiki/Volksstaat_Hessen#Entwicklung
# /wiki/Freistaat_Lippe
# /wiki/Geschichte_der_Hansestadt_L%C3%BCbeck#20._Jahrhundert
# /wiki/Land_Mecklenburg
# /wiki/Freistaat_Oldenburg
# /wiki/Freistaat_Preu%C3%9Fen#Beginn_der_Zeit_des_Nationalsozialismus
# /wiki/Geschichte_des_Saarlandes#Teil_NS-Deutschlands_(1935_bis_1945)
# /wiki/Saargebiet
# /wiki/Geschichte_Sachsens#Nationalsozialismus_(1933_bis_1945)
# /wiki/Schaumburg-Lippe
# /wiki/Th%C3%BCringen_im_Nationalsozialismus
# /wiki/W%C3%BCrttemberg_zur_Zeit_des_Nationalsozialismus
# /wiki/Datei:Flag_of_Europe.svg
# /wiki/Umwelthauptstadt_Europas
# /wiki/Stockholm
# /wiki/Vitoria-Gasteiz
# /wiki/Nantes
# /wiki/Kopenhagen
# /wiki/Bristol
# /wiki/Ljubljana
# /wiki/Essen
# /wiki/Nijmegen
# /wiki/Oslo
# /wiki/Lissabon
# /wiki/Datei:Qsicon_lesenswert.svg
# /wiki/Spezial:Permanenter_Link/6291168
# /wiki/Wikipedia:Lesenswerte_Artikel
# /wiki/Gemeinsame_Normdatei
# /wiki/Library_of_Congress_Control_Number
# /wiki/Web_NDL_Authorities
# /wiki/Virtual_International_Authority_File
# /wiki/Wikipedia:Kategorien
# /wiki/Kategorie:Wikipedia:Lesenswert
# /wiki/Kategorie:Hamburg
# /wiki/Kategorie:Bundesland_(Deutschland)
# /wiki/Kategorie:Kreisfreie_Stadt_in_Deutschland
# /wiki/Kategorie:Stadt_in_Deutschland
# /wiki/Kategorie:Deutsche_Landeshauptstadt
# /wiki/Kategorie:Gemeinde_in_Deutschland
# /wiki/Kategorie:Hansestadt
# /wiki/Kategorie:Ort_mit_Seehafen
# /wiki/Kategorie:Reichsstadt
# /wiki/Kategorie:Millionenstadt
# /wiki/Kategorie:Deutsche_Universit%C3%A4tsstadt
# /wiki/Kategorie:Umwelthauptstadt_Europas
# /wiki/Kategorie:Ort_an_der_Elbe
# /wiki/Kategorie:Ort_mit_Binnenhafen
# /wiki/Kategorie:Bundesstaat_(Deutsches_Kaiserreich)
# /wiki/Kategorie:Land_der_Weimarer_Republik
# /wiki/Kategorie:Mitgliedstaat_des_Deutschen_Zollvereins
# /wiki/Kategorie:Mitgliedstaat_des_Deutschen_Bundes
# /wiki/Kategorie:Stadt_als_Namensgeber_f%C3%BCr_einen_Asteroiden
# /wiki/Kategorie:Ersterw%C3%A4hnung_810
# /wiki/Kategorie:Wikipedia:Weblink_offline
# /wiki/Kategorie:Wikipedia:Veraltet_in_zwei_bis_drei_Jahren
# /wiki/Kategorie:Wikipedia:Veraltet_in_drei_bis_vier_Jahren
# /wiki/Spezial:Meine_Diskussionsseite
# /wiki/Spezial:Meine_Beitr%C3%A4ge
# /wiki/Hamburg
# /wiki/Diskussion:Hamburg
# /wiki/Hamburg
# /wiki/Wikipedia:Hauptseite
# /wiki/Wikipedia:Hauptseite
# /wiki/Portal:Wikipedia_nach_Themen
# /wiki/Spezial:Zuf%C3%A4llige_Seite
# /wiki/Wikipedia:Beteiligen
# /wiki/Hilfe:Neuen_Artikel_anlegen
# /wiki/Wikipedia:Autorenportal
# /wiki/Hilfe:%C3%9Cbersicht
# /wiki/Spezial:Letzte_%C3%84nderungen
# /wiki/Wikipedia:Kontakt
# /wiki/Spezial:Linkliste/Hamburg
# /wiki/Spezial:%C3%84nderungen_an_verlinkten_Seiten/Hamburg
# /wiki/Spezial:Spezialseiten
# /wiki/Wikipedia:%C3%9Cber_Wikipedia
# /wiki/Wikipedia:Impressum

# %% [markdown]
# Alle externen Verlinkungen kann man sich folgendermaßen ausgeben lassen:

# %%
for l in links:
    if l['href'].startswith('http'):
        print(l['href'])
# Out:
# https://www.hamburg.de/stadt-staat/
# https://geohack.toolforge.org/geohack.php?pagename=Hamburg&language=de&params=53.550556_N_9.993333_E_dim:40000_region:DE-HH_type:adm1st(1773218)
# https://geohack.toolforge.org/geohack.php?pagename=Hamburg&language=de&params=53.550556_N_9.993333_E_dim:40000_region:DE-HH_type:adm1st(1773218
# https://www.hamburg.de/contentblob/14125070/5bc0a496bee5bde5126e7c090ca64347/data/jahresbericht-2019.pdf
# https://wissenschaft.hamburg.de/hochschulen/
# http://mobil.abendblatt.de/hamburg/article2356243/Bildung-Das-aendert-sich-an-Hamburgs-Schulen.html
# http://mobil.abendblatt.de/hamburg/article2356243/Bildung-Das-aendert-sich-an-Hamburgs-Schulen.html
# https://www.xfel.eu/anlage/ueberblick/index_ger.html
# https://www.statistik-nord.de/fileadmin/Dokumente/Presseinformationen/SI16_149.pdf
# https://zdb-katalog.de/list.xhtml?t=iss%3D%221614-8045%22&key=cql
# https://www.statistik-nord.de/fileadmin/Dokumente/Jahrb%C3%BCcher/Hamburg/JB15HH_Gesamt_Internet_korr.pdf
# https://de.statista.com/statistik/daten/studie/318394/umfrage/selbstmordrate-in-deutschland-nach-bundeslaendern-und-geschlecht/
# https://www.hamburg.de/contentblob/3376572/data/handbuch2012-2013.pdf
# https://d-nb.info/gnd/4023118-5
# https://swb.bsz-bw.de/DB=2.104/SET=1/TTL=1/CMD?retrace=0&trm_old=&ACT=SRCHA&IKT=2999&SRT=RLV&TRM=4023118-5
# https://beacon.findbuch.de/seemore/gnd-aks?format=sources&id=4023118-5
# https://lccn.loc.gov/n81086822
# https://id.ndl.go.jp/auth/ndlna/00628973
# https://viaf.org/viaf/148855657/
# https://de.wikipedia.org/w/index.php?title=Hamburg&oldid=222922636
# https://www.wikidata.org/wiki/Special:EntityPage/Q1055
# https://commons.wikimedia.org/wiki/Hamburg
# https://de.wikinews.org/wiki/Kategorie:Hamburg
# https://de.wikiquote.org/wiki/Hamburg
# https://de.wikisource.org/wiki/Hamburg
# https://de.wikivoyage.org/wiki/Hamburg
# https://af.wikipedia.org/wiki/Hamburg
# https://als.wikipedia.org/wiki/Hamburg
# https://am.wikipedia.org/wiki/%E1%88%83%E1%88%9D%E1%89%A1%E1%88%AD%E1%8C%8D
# https://an.wikipedia.org/wiki/Hamburgo
# https://ang.wikipedia.org/wiki/Hamburg
# https://ar.wikipedia.org/wiki/%D9%87%D8%A7%D9%85%D8%A8%D9%88%D8%B1%D8%BA
# https://arc.wikipedia.org/wiki/%DC%97%DC%90%DC%A1%DC%92%DC%98%DC%AA%DC%93
# https://arz.wikipedia.org/wiki/%D9%87%D8%A7%D9%85%D8%A8%D9%88%D8%B1%D8%AC
# https://ast.wikipedia.org/wiki/Hamburgu
# https://ay.wikipedia.org/wiki/Hamburg
# https://az.wikipedia.org/wiki/Hamburq
# https://azb.wikipedia.org/wiki/%D9%87%D8%A7%D9%85%D8%A8%D9%88%D8%B1%D9%82
# https://ba.wikipedia.org/wiki/%D0%93%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://bar.wikipedia.org/wiki/Hamburg
# https://bat-smg.wikipedia.org/wiki/Hamburgs
# https://be.wikipedia.org/wiki/%D0%93%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://be-tarask.wikipedia.org/wiki/%D0%93%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://bg.wikipedia.org/wiki/%D0%A5%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://bh.wikipedia.org/wiki/%E0%A4%B9%E0%A5%88%E0%A4%AE%E0%A5%8D%E0%A4%AC%E0%A4%B0%E0%A5%8D%E0%A4%97
# https://bn.wikipedia.org/wiki/%E0%A6%B9%E0%A6%BE%E0%A6%AE%E0%A6%AC%E0%A7%81%E0%A6%B0%E0%A7%8D%E0%A6%97
# https://br.wikipedia.org/wiki/Hamburg
# https://bs.wikipedia.org/wiki/Hamburg
# https://bxr.wikipedia.org/wiki/%D2%BA%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://ca.wikipedia.org/wiki/Hamburg
# https://cdo.wikipedia.org/wiki/Hamburg
# https://ce.wikipedia.org/wiki/%D0%93%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://ceb.wikipedia.org/wiki/Free_and_Hanseatic_City_of_Hamburg
# https://ch.wikipedia.org/wiki/Hamburg
# https://ckb.wikipedia.org/wiki/%DA%BE%D8%A7%D9%85%D8%A8%D9%88%D8%B1%DA%AF
# https://co.wikipedia.org/wiki/Amburgu
# https://crh.wikipedia.org/wiki/Hamburg
# https://cs.wikipedia.org/wiki/Hamburk
# https://csb.wikipedia.org/wiki/Hamb%C3%B9rg
# https://cv.wikipedia.org/wiki/%D0%93%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://cy.wikipedia.org/wiki/Hamburg
# https://da.wikipedia.org/wiki/Hamborg
# https://diq.wikipedia.org/wiki/Hamburg
# https://dsb.wikipedia.org/wiki/Hamburg
# https://el.wikipedia.org/wiki/%CE%91%CE%BC%CE%B2%CE%BF%CF%8D%CF%81%CE%B3%CE%BF
# https://eml.wikipedia.org/wiki/Amb%C3%BBrg
# https://en.wikipedia.org/wiki/Hamburg
# https://eo.wikipedia.org/wiki/Hamburgo
# https://es.wikipedia.org/wiki/Hamburgo
# https://et.wikipedia.org/wiki/Hamburg
# https://eu.wikipedia.org/wiki/Hanburgo
# https://ext.wikipedia.org/wiki/Amburgu
# https://fa.wikipedia.org/wiki/%D9%87%D8%A7%D9%85%D8%A8%D9%88%D8%B1%DA%AF
# https://fi.wikipedia.org/wiki/Hampuri
# https://fj.wikipedia.org/wiki/Hamburg
# https://fo.wikipedia.org/wiki/Hamburg
# https://fr.wikipedia.org/wiki/Hambourg
# https://frr.wikipedia.org/wiki/Hamborj
# https://fur.wikipedia.org/wiki/Amburc
# https://fy.wikipedia.org/wiki/Hamburch
# https://ga.wikipedia.org/wiki/Hamburg
# https://gd.wikipedia.org/wiki/Hamburg
# https://gl.wikipedia.org/wiki/Hamburgo
# https://gn.wikipedia.org/wiki/Hamburgo
# https://got.wikipedia.org/wiki/%F0%90%8C%B7%F0%90%8C%B0%F0%90%8C%BC%F0%90%8C%BC%F0%90%8C%B0%F0%90%8C%B1%F0%90%8C%B0%F0%90%8C%BF%F0%90%8D%82%F0%90%8C%B2%F0%90%8D%83
# https://gv.wikipedia.org/wiki/Hamburg
# https://ha.wikipedia.org/wiki/Hamburg
# https://hak.wikipedia.org/wiki/Hamburg
# https://haw.wikipedia.org/wiki/Hamepuka
# https://he.wikipedia.org/wiki/%D7%94%D7%9E%D7%91%D7%95%D7%A8%D7%92
# https://hi.wikipedia.org/wiki/%E0%A4%B9%E0%A5%88%E0%A4%AE%E0%A5%8D%E0%A4%AC%E0%A4%B0%E0%A5%8D%E0%A4%97
# https://hr.wikipedia.org/wiki/Hamburg
# https://hsb.wikipedia.org/wiki/Hamburg
# https://hu.wikipedia.org/wiki/Hamburg
# https://hy.wikipedia.org/wiki/%D5%80%D5%A1%D5%B4%D5%A2%D5%B8%D6%82%D6%80%D5%A3
# https://hyw.wikipedia.org/wiki/%D5%80%D5%A1%D5%B4%D5%BA%D5%B8%D6%82%D6%80%D5%AF
# https://ia.wikipedia.org/wiki/Hamburg
# https://id.wikipedia.org/wiki/Hamburg
# https://ie.wikipedia.org/wiki/Hamburg
# https://ilo.wikipedia.org/wiki/Hamburg
# https://inh.wikipedia.org/wiki/%D0%93%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https
wikipedia.org/wiki/%D0%93%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://pa.wikipedia.org/wiki/%E0%A8%B9%E0%A8%BE%E0%A8%AE%E0%A8%AC%E0%A9%81%E0%A8%B0%E0%A8%95
# https://pam.wikipedia.org/wiki/Hamburg
# https://pap.wikipedia.org/wiki/Hamburg
# https://pcd.wikipedia.org/wiki/Hambourq
# https://pdc.wikipedia.org/wiki/Hamburg
# https://pfl.wikipedia.org/wiki/Hamburg
# https://pih.wikipedia.org/wiki/Hamburg
# https://pl.wikipedia.org/wiki/Hamburg
# https://pms.wikipedia.org/wiki/Amborgh
# https://pnb.wikipedia.org/wiki/%DB%81%D8%A7%D9%85%D8%A8%D8%B1%DA%AF
# https://pt.wikipedia.org/wiki/Hamburgo
# https://qu.wikipedia.org/wiki/Hamburg
# https://rm.wikipedia.org/wiki/Hamburg
# https://rmy.wikipedia.org/wiki/Hamburg
# https://ro.wikipedia.org/wiki/Hamburg
# https://ru.wikipedia.org/wiki/%D0%93%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://rue.wikipedia.org/wiki/%D0%93%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://sc.wikipedia.org/wiki/Amburgu
# https://scn.wikipedia.org/wiki/Amburgu
# https://sco.wikipedia.org/wiki/Hamburgh
# https://sd.wikipedia.org/wiki/%DA%BE%D8%A6%D9%85%D8%A8%D8%B1%DA%AF(%D8%B4%DA%BE%D8%B1)
# https://se.wikipedia.org/wiki/Hamborg
# https://sh.wikipedia.org/wiki/Hamburg
# https://simple.wikipedia.org/wiki/Hamburg
# https://sk.wikipedia.org/wiki/Hamburg
# https://sl.wikipedia.org/wiki/Hamburg
# https://sq.wikipedia.org/wiki/Hamburgu
# https://sr.wikipedia.org/wiki/%D0%A5%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://stq.wikipedia.org/wiki/Hambuurich
# https://su.wikipedia.org/wiki/Hamburg
# https://sv.wikipedia.org/wiki/Hamburg
# https://sw.wikipedia.org/wiki/Hamburg
# https://szl.wikipedia.org/wiki/Hamburg
# https://ta.wikipedia.org/wiki/%E0%AE%86%E0%AE%AE%E0%AF%8D%E0%AE%AA%E0%AE%B0%E0%AF%8D%E0%AE%95%E0%AF%81
# https://tg.wikipedia.org/wiki/%D2%B2%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://th.wikipedia.org/wiki/%E0%B8%AE%E0%B8%B1%E0%B8%A1%E0%B8%9A%E0%B8%A7%E0%B8%A3%E0%B9%8C%E0%B8%84
# https://tl.wikipedia.org/wiki/Hamburg
# https://tr.wikipedia.org/wiki/Hamburg
# https://tt.wikipedia.org/wiki/%D2%BA%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://tum.wikipedia.org/wiki/Hamburg
# https://tw.wikipedia.org/wiki/Hamb%C9%94g
# https://ug.wikipedia.org/wiki/Hamburg
# https://uk.wikipedia.org/wiki/%D0%93%D0%B0%D0%BC%D0%B1%D1%83%D1%80%D0%B3
# https://ur.wikipedia.org/wiki/%DB%81%D9%85_%D8%A8%D8%B1%DA%A9
# https://uz.wikipedia.org/wiki/Gamburg
# https://vec.wikipedia.org/wiki/Anburgo
# https://vep.wikipedia.org/wiki/Gamburg
# https://vi.wikipedia.org/wiki/Hamburg
# https://vls.wikipedia.org/wiki/Hamburg
# https://vo.wikipedia.org/wiki/Hamburg
# https://war.wikipedia.org/wiki/Hamburg
# https://wuu.wikipedia.org/wiki/%E6%B1%89%E5%A0%A1
# https://xh.wikipedia.org/wiki/Hamburg
# https://xmf.wikipedia.org/wiki/%E1%83%B0%E1%83%90%E1%83%9B%E1%83%91%E1%83%A3%E1%83%A0%E1%83%92%E1%83%98
# https://yi.wikipedia.org/wiki/%D7%94%D7%90%D7%9E%D7%91%D7%95%D7%A8%D7%92
# https://yo.wikipedia.org/wiki/Hamburg
# https://zh.wikipedia.org/wiki/%E6%B1%89%E5%A0%A1
# https://zh-classical.wikipedia.org/wiki/%E6%BC%A2%E5%A0%A1
# https://zh-min-nan.wikipedia.org/wiki/Hamburg
# https://zh-yue.wikipedia.org/wiki/%E6%BC%A2%E5%A0%A1
# https://www.wikidata.org/wiki/Special:EntityPage/Q1055#sitelinks-wikipedia
# https://pageviews.wmcloud.org/?pages=Hamburg&project=de.wikipedia.org
# https://de.wikipedia.org/wiki/Wikipedia:Lizenzbestimmungen_Creative_Commons_Attribution-ShareAlike_3.0_Unported
# https://foundation.wikimedia.org/wiki/Terms_of_Use/de
# https://meta.wikimedia.org/wiki/Privacy_policy/de
# https://meta.wikimedia.org/wiki/Privacy_policy/de
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://stats.wikimedia.org/#/de.wikipedia.org
# https://foundation.wikimedia.org/wiki/Cookie_statement
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %% [markdown]
# **Weiteres Anwendungsbeispiel:**
# Auf der Hamburgseite der deutschen Wikipedia befindet sich am rechten Rand innerhalb der Tabelle die Einwohnerzahl. Diese Information soll aus dem Quellcode extrahiert werden.

# %% [markdown]
# Man kann die Tabelle als Ganzes aus dem Code extrahieren:

# %%
table = bs.find('table')

# %%
print(hh_table)
# Out:
# [<table class="wikitable float-right hintergrundfarbe2 toptextcells">
# <tbody><tr>
# <th class="hintergrundfarbe5" colspan="2" style="font-size:1.3em;">Freie und Hansestadt Hamburg
# </th></tr>
# <tr>
# <td><div class="center"><div class="floatnone"><a class="image" href="/wiki/Datei:Flag_of_Hamburg.svg" title="Landesflagge der Freien und Hansestadt Hamburg"><img alt="Landesflagge der Freien und Hansestadt Hamburg" data-file-height="400" data-file-width="600" decoding="async" height="93" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/74/Flag_of_Hamburg.svg/140px-Flag_of_Hamburg.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/74/Flag_of_Hamburg.svg/210px-Flag_of_Hamburg.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/74/Flag_of_Hamburg.svg/280px-Flag_of_Hamburg.svg.png 2x" width="140"/></a></div></div>
# </td>
# <td rowspan="4"><div class="center"><div class="floatnone"><div class="noresize" style="height: 271px; width: 200px; "><map name="ImageMap_90f4e28b646220b9"><area alt="Berlin" coords="163,87,9" href="/wiki/Berlin" shape="circle" title="Berlin"/><area alt="Bremen" coords="64,67,9" href="/wiki/Freie_Hansestadt_Bremen" shape="circle" title="Bremen"/><area alt="Bremen" coords="61,52,6" href="/wiki/Freie_Hansestadt_Bremen" shape="circle" title="Bremen"/><area alt="Hamburg" coords="92,52,9" href="/wiki/Hamburg" shape="circle" title="Hamburg"/><area alt="Niedersachsen" coords="62,41,20,46,20,51,29,58,27,82,20,83,21,88,27,97,41,90,46,94,46,104,57,101,53,90,62,87,64,93,70,89,72,93,69,96,77,116,84,121,80,128,86,131,104,121,104,105,114,103,109,78,122,72,112,59,98,58,86,57,85,52,75,41" href="/wiki/Niedersachsen" shape="poly" title="Niedersachsen"/><area alt="Bayern" coords="70,191,68,172,91,156,104,167,122,161,133,161,148,176,178,214,179,226,156,240,164,257,160,262,114,266,98,268,82,260,93,256,91,233,102,219,96,207,92,193,86,184,78,184" href="/wiki/Bayern" shape="poly" title="Bayern"/><area alt="Saarland" coords="20,196,13" href="/wiki/Saarland" shape="circle" title="Saarland"/><area alt="Schleswig-Holstein" coords="67,40,51,8,53,1,65,0,81,6,
iki/Liste_der_deutschen_Bundesl%C3%A4nder_nach_Bruttoinlandsprodukt" title="Liste der deutschen Bundesländer nach Bruttoinlandsprodukt">1.</a>)</small> <small>(2017)</small><br/>
# </td></tr>
# <tr>
# <td><a href="/wiki/Schulden" title="Schulden">Schulden</a>:</td>
# <td>34,798 Mrd. EUR <small>(30. Juni 2020)</small><sup class="reference" id="cite_ref-Schulden_4-0"><a href="#cite_note-Schulden-4">[4]</a></sup>
# </td></tr>
# <tr>
# <td>Adresse des <a href="/wiki/Senat_der_Freien_und_Hansestadt_Hamburg" title="Senat der Freien und Hansestadt Hamburg">Senates</a>:</td>
# <td><a href="/wiki/Rathausmarkt_(Hamburg)" title="Rathausmarkt (Hamburg)">Rathausmarkt</a> 1<br/>20095 Hamburg
# </td></tr>
# <tr>
# <td><a href="/wiki/Amtlicher_Gemeindeschl%C3%BCssel" title="Amtlicher Gemeindeschlüssel">Gemeindeschlüssel</a>:</td>
# <td><span style="white-space:nowrap">02 0 00 000</span>
# </td></tr>
# <tr>
# <td><a href="/wiki/ISO_3166-2:DE" title="ISO 3166-2:DE">ISO 3166-2</a>:</td>
# <td>DE-HH
# </td></tr>
# <tr>
# <td><a href="/wiki/UN/LOCODE" title="UN/LOCODE">UN/LOCODE</a>:</td>
# <td><span style="white-space:nowrap">DE HAM</span>
# </td></tr>
# <tr>
# <td>Website:</td>
# <td><a class="external text" href="https://www.hamburg.de/stadt-staat/" rel="nofollow">www.hamburg.de</a>
# </td></tr>
# <tr>
# <th class="hintergrundfarbe5" colspan="2">Bevölkerung
# </th></tr>
# <tr>
# <td><a href="/wiki/Einwohner" title="Einwohner">Einwohner</a>:</td>
# <td>1.851.430 <small>(31. März 2021)</small><sup class="reference" id="cite_ref-statamt_5-0"><a href="#cite_note-statamt-5">[5]</a></sup>
# </td></tr>
# <tr>
# <td>– davon <a href="/wiki/Ausl%C3%A4nder" title="Ausländer">Ausländer</a>:</td>
# <td>312.802 <small>(März 2021)</small><sup class="reference" id="cite_ref-Ausländer_6-0"><a href="#cite_note-Ausländer-6">[6]</a></sup>
# </td></tr>
# <tr>
# <td>– davon mit<br/><a href="/wiki/Migrationshintergrund" title="Migrationshintergrund">Migrationshintergrund</a>:</td>
# <td>696.711 <small>(31. Dez. 2020)</small><sup class="reference" id="cite_ref-Statistik-Nord_2020_7-0"><a href="#cite_note-Statistik-Nord_2020-7">[7]</a></sup>
# </td></tr>
# <tr>
# <td>Ausländeranteil:</td>
# <td>16,9 % <small>(31. Dez. 2018)</small><sup class="reference" id="cite_ref-Ausländer_6-1"><a href="#cite_note-Ausländer-6">[6]</a></sup>
# </td></tr>
# <tr>
# <td>Migrationshintergrundanteil:</td>
# <td>36,7 % <small>(31. Dez. 2020)</small><sup class="reference" id="cite_ref-Statistik-Profile_2015_8-0"><a href="#cite_note-Statistik-Profile_2015-8">[8]</a></sup>
# </td></tr>
# <tr>
# <td>Einwohner <a href="/wiki/Metropolregion_Hamburg" title="Metropolregion Hamburg">Metropolregion</a>:</td>
# <td>~ 5.380.000 <small>(31. Dezember 2018)</small><sup class="reference" id="cite_ref-Metropolregion_Hamburg_9-0"><a href="#cite_note-Metropolregion_Hamburg-9">[9]</a></sup>
# </td></tr>
# <tr>
# <td><a href="/wiki/Bev%C3%B6lkerungsdichte" title="Bevölkerungsdichte">Bevölkerungsdichte</a>:</td>
# <td>2.522 Einw. pro km² <small>(31. Dez. 2019)</small>
# </td></tr>
# <tr>
# <td><a href="/wiki/Arbeitslosenstatistik" title="Arbeitslosenstatistik">Arbeitslosenquote</a>:</td>
# <td>6,5 % <small>(April 2022)</small><sup class="reference" id="cite_ref-10"><a href="#cite_note-10">[10]</a></sup>
# </td></tr>
# <tr>
# <th class="hintergrundfarbe5" colspan="2">Geographie
# </th></tr>
# <tr>
# <td><a href="/wiki/Geographische_Koordinaten" title="Geographische Koordinaten">geographische Lage</a>:</td>
# <td><span class="coordinates plainlinks-print" id="text_coordinates"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Hamburg&amp;language=de&amp;params=53.550556_N_9.993333_E_dim:40000_region:DE-HH_type:adm1st(1773218)"><span title="Breitengrad">53° 33′ <abbr title="Nord">N</abbr></span>, <span title="Längengrad">10° 0′ <abbr title="Ost">O</abbr></span></a></span><span class="geo noexcerpt" style="display:none"><span class="body"></span><span class="latitude">53.550556</span><span class="longitude">9.993333</span><span class="elevation"></span></span><span class="coordinates noprint" id="coordinates"><span title="Koordinatensystem WGS84">Koordinaten: </span><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Hamburg&amp;language=de&amp;params=53.550556_N_9.993333_E_dim:40000_region:DE-HH_type:adm1st(1773218)"><span title="Breitengrad">53° 33′ <abbr title="Nord">N</abbr></span>, <span title="Längengrad">10° 0′ <abbr title="Ost">O</abbr></span></a></span>
# </td></tr>
# <tr>
# <td><a href="/wiki/H%C3%B6he" title="Höhe">Höhe</a>:</td>
# <td><span style="border-width:0px; padding:0px; margin:0px;">6 <abbr title="Meter über Normalhöhennull">m ü. <a href="/wiki/Normalh%C3%B6hennull" title="Normalhöhennull">NHN</a></abbr></span>
# </td></tr>
# <tr>
# <td><a href="/wiki/Fl%C3%A4cheninhalt" title="Flächeninhalt">Fläche</a>:</td>
# <td><a class="mw-redirect" href="/wiki/Gr%C3%B6%C3%9Fenordnung_(Fl%C3%A4che)#100_km²_bis_1000_km²" title="Größenordnung (Fläche)">755,09 km²</a><sup class="reference" id="cite_ref-11"><a href="#cite_note-11">[11]</a></sup><br/><small>(Rang: <a href="/wiki/Liste_der_deutschen_Bundesl%C3%A4nder_nach_Fl%C3%A4che" title="Liste der deutschen Bundesländer nach Fläche">15. als Land</a>, <a class="mw-redirect" href="/wiki/Liste_der_100_fl%C3%A4chengr%C3%B6%C3%9Ften_Gemeinden_Deutschlands" title="Liste der 100 flächengrößten Gemeinden Deutschlands">2. als Gemeinde</a>)</small>
# </td></tr>
# <tr>
# <td>Stadtgliederung:<sup class="reference" id="cite_ref-BezVG_12-0"><a href="#cite_note-BezVG-12">[12]</a></sup></td>
# <td><a href="/wiki/Bezirke_in_Hamburg" title="Bezirke in Hamburg">7 Bezirke, 104 Stadtteile</a>
# </td></tr>
# <tr>
# <th class="hintergrundfarbe5" colspan="2">Politik
# </th></tr>
# <tr>
# <td><a href="/wiki/Erster_B%C3%BCrgermeister" title="Erster Bürgermeister">Erster Bürgermeister</a>:</td>
# <td><a href="/wiki/Peter_Tschentscher" title="Peter Tschentscher">Peter Tschentscher</a> (SPD)
# </td></tr>
# <tr>
# <td><a href="/wiki/Erster_B%C3%BCrgermeister#Zweiter_Bürgermeister" title="Erster Bürgermeister">Zweite Bürgermeisterin</a>:</td>
# <td><a href="/wiki/Katharina_Fegebank" title="Katharina Fegebank">Katharina Fegebank</a> (Grüne)
# </td></tr>
# <tr>
# <td><a href="/wiki/Pr%C3%A4sident_der_Hamburgischen_B%C3%BCrgerschaft" title="Präsident der Hamburgischen Bürgerschaft">Bürgerschaftspräsidentin</a>:</td>
# <td><a href="/wiki/Carola_Veit" title="Carola Veit">Carola Veit</a> (SPD)
# </td></tr>
# <tr>
# <td>Regierende <a href="/wiki/Politische_Partei" title="Politische Partei">Parteien</a>:</td>
# <td><a class="mw-redirect" href="/wiki/SPD" title="SPD">SPD</a> und <a href="/wiki/B%C3%BCndnis_90/Die_Gr%C3%BCnen" title="Bündnis 90/Die Grünen">Grüne</a>
# </td></tr>
# <tr>
# <td colspan="2" style="text-align: center;"><a href="/wiki/Liste_der_Mitglieder_der_Hamburgischen_B%C3%BCrgerschaft_(22._Wahlperiode)" title="Liste der Mitglieder der Hamburgischen Bürgerschaft (22. Wahlperiode)">Sitzverteilung der 22. Bürgerschaft</a><br/>
# <div class="centered diagram noprint" style="width:14.4em; height:7.2em; padding:0.9em; overflow:hidden; background:white; text-align:center;"><div style="width:14.4em; height:7.2em; position:relative; -o-transform-origin:bottom center;-moz-transform-origin:bottom center;-webkit-transform-origin:bottom center;-ms-transform-origin:bottom center;transform-origin:bottom center; -moz-border-radius-topleft:7.2em; -webkit-border-top-left-radius:7.2em; border-top-left-radius:7.2em; -moz-border-radius-topright:7.2em;-webkit-border-top-right-radius:7.2em;border-top-right-radius:7.2em; background:#BE3075;">
# <div style="-o-transform:rotate(19.024390243902deg);-moz-transform:rotate(19.024390243902deg);-webkit-transform:rotate(19.024390243902deg);-ms-transform:rotate(19.024390243902deg);transform:rotate(19.024390243902deg); width:14.4em; height:7.2em; position:relative; -o-transform-origin:bottom center;-moz-transform-origin:bottom center;-webkit-transform-origin:bottom center;-ms-transform-origin:bottom center;transform-origin:bottom center; -moz-border-radius-topleft:7.2em; -webkit-border-top-left-radius:7.2em; border-top-left-radius:7.2em; -moz-border-radius-topright:7.2em;-webkit-border-top-right-radius:7.2em;border-top-right-radius:7.2em; background:#E3000F;">
# <div style="-o-transform:rotate(79.024390243902deg);-moz-transform:rotate(79.024390243902deg);-webkit-transform:rotate(79.024390243902deg);-ms-transform:rotate(79.024390243902deg);transform:rotate(79.024390243902deg); width:14.4em; height:7.2em; position:relative; -o-transform-origin:bottom center;-moz-transform-origin:bottom center;-webkit-transform-origin:bottom center;-ms-transform-origin:bottom center;transform-origin:bottom center; -moz-border-radius-topleft:7.2em; -webkit-border-top-left-radius:7.2em; border-top-left-radius:7.2em; -moz-border-radius-topright:7.2em;-webkit-border-top-right-radius:7.2em;border-top-right-radius:7.2em; background:#46962b;">
# <div style="-o-transform:rotate(48.292682926829deg);-moz-transform:rotate(48.292682926829deg);-webkit-transform:rotate(48.292682926829deg);-ms-transform:rotate(48.292682926829deg);transform:rotate(48.292682926829deg); width:14.4em; height:7.2em; position:relative; -o-transform-origin:bottom center;-moz-transform-origin:bottom center;-webkit-transform-origin:bottom center;-ms-transform-origin:bottom center;transform-origin:bottom center; -moz-border-radius-topleft:7.2em; -webkit-border-top-left-radius:7.2em; border-top-left-radius:7.2em; -moz-border-radius-topright:7.2em;-webkit-border-top-right-radius:7.2em;border-top-right-radius:7.2em; background:#ffff00;">
# <div style="-o-transform:rotate(1.4634146341463deg);-moz-transform:rotate(1.4634146341463deg);-webkit-transform:rotate(1.4634146341463deg);-ms-transform:rotate(1.4634146341463deg);transform:rotate(1.4634146341463deg); width:14.4em; height:7.2em; position:relative; -o-transform-origin:bottom center;-moz-transform-origin:bottom center;-webkit-transform-origin:bottom center;-ms-transform-origin:bottom center;transform-origin:bottom center; -moz-border-radius-topleft:7.2em; -webkit-border-top-left-radius:7.2em; border-top-left-radius:7.2em; -moz-border-radius-topright:7.2em;-webkit-border-top-right-radius:7.2em;border-top-right-radius:7.2em; background:#000000;">
# <div style="-o-transform:rotate(21.951219512195deg);-moz-transform:rotate(21.951219512195deg);-webkit-transform:rotate(21.951219512195deg);-ms-transform:rotate(21.951219512195deg);transform:rotate(21.951219512195deg); width:14.4em; height:7.2em; position:relative; -o-transform-origin:bottom center;-moz-transform-origin:bottom center;-webkit-transform-origin:bottom center;-ms-transform-origin:bottom center;transform-origin:bottom center; -moz-border-radius-topleft:7.2em; -webkit-border-top-left-radius:7.2em; border-top-left-radius:7.2em; -moz-border-radius-topright:7.2em;-webkit-border-top-right-radius:7.2em;border-top-right-radius:7.2em; background:#009ee0;">
# <div style="-o-transform:rotate(10.243902439024deg);-moz-transform:rotate(10.243902439024deg);-webkit-transform:rotate(10.243902439024deg);-ms-transform:rotate(10.243902439024deg);transform:rotate(10.243902439024deg); width:14.4em; height:7.2em; -o-transform-origin:bottom center;-moz-transform-origin:bottom center;-webkit-transform-origin:bottom center;-ms-transform-origin:bottom center;transform-origin:bottom center; background:white;"><div style="-o-transform:scale(0);-moz-transform:scale(0);-webkit-transform:scale(0);-ms-transform:scale(0);transform:scale(0); width:100%;"><span style="display:inline-block;background:#BE3075;width:10.569105691057%;overflow:hidden;"> </span><span style="display:inline-block;background:#E3000F;width:43.90243902439%;overflow:hidden;"> </span><span style="display:inline-block;background:#46962b;width:26.829268292683%;overflow:hidden;"> </span><span style="display:inline-block;background:#ffff00;width:0.81300813008128%;overflow:hidden;"> </span><span style="display:inline-block;background:#000000;width:12.195121951219%;overflow:hidden;"> </span><span style="display:inline-block;background:#009ee0;width:5.6910569105689%;overflow:hidden;"> </span></div>
# </div>
# </div></div></div></div></div></div><div style="width:5.4em; height:5.4em; margin:-2.7em auto; -moz-border-radius:2.7em; -webkit-border-radius:2.7em; border-radius:2.7em; -o-transform:translate(0,0);-moz-transform:translate(0,0);-webkit-transform:translate(0,0);-ms-transform:translate(0,0);transform:translate(0,0); background:white;"></div>
# </div>
# <p><br/>
# </p>
# </td></tr>
# <tr>
# <td><a href="/wiki/Sitzverteilung_in_den_deutschen_Landesparlamenten" title="Sitzverteilung in den deutschen Landesparlamenten">Sitzverteilung in der<br/>Hamburgischen<br/>Bürgerschaft</a> 2020<br/>(123 Sitze):<sup class="reference" id="cite_ref-13"><a href="#cite_note-13">[13]</a></sup></td>
# <td>
# <table>
# <tbody><tr>
# <td><li style="list-style-type: none; list-style-image: none; margin: 0;"><span style="border-left: 1.2em solid; border-left-color: #E3000F; padding-left: 0.4em;" title="Farbe #E3000F">﻿</span><a href="/wiki/SPD_Hamburg" title="SPD Hamburg">SPD</a></li></td>
# <td>54
# </td></tr>
# <tr>
# <td><li style="list-style-type: none; list-style-image: none; margin: 0;"><span style="border-left: 1.2em solid; border-left-color: #46962b; padding-left: 0.4em;" title="Farbe #46962b">﻿</span><a href="/wiki/B%C3%BCndnis_90/Die_Gr%C3%BCnen_Hamburg" title="Bündnis 90/Die Grünen Hamburg">Grüne</a></li></td>
# <td>33
# </td></tr>
# <tr>
# <td><li style="list-style-type: none; list-style-image: none; margin: 0;"><span style="border-left: 1.2em solid; border-left-color:
r>
# <td><li style="list-style-type: none; list-style-image: none; margin: 0;"><span style="border-left: 1.2em solid; border-left-color: #E3000F; padding-left: 0.4em;" title="Farbe #E3000F">﻿</span><a href="/wiki/SPD_Hamburg" title="SPD Hamburg">SPD</a></li></td>
# <td>54
# </td></tr>
# <tr>
# <td><li style="list-style-type: none; list-style-image: none; margin: 0;"><span style="border-left: 1.2em solid; border-left-color: #46962b; padding-left: 0.4em;" title="Farbe #46962b">﻿</span><a href="/wiki/B%C3%BCndnis_90/Die_Gr%C3%BCnen_Hamburg" title="Bündnis 90/Die Grünen Hamburg">Grüne</a></li></td>
# <td>33
# </td></tr>
# <tr>
# <td><li style="list-style-type: none; list-style-image: none; margin: 0;"><span style="border-left: 1.2em solid; border-left-color: #000000; padding-left: 0.4em;" title="Schwarz">﻿</span><a href="/wiki/CDU_Hamburg" title="CDU Hamburg">CDU</a></li></td>
# <td>15
# </td></tr>
# <tr>
# <td><li style="list-style-type: none; list-style-image: none; margin: 0;"><span style="border-left: 1.2em solid; border-left-color: #BE3075; padding-left: 0.4em;" title="Farbe #BE3075">﻿</span><a href="/wiki/Die_Linke_Hamburg" title="Die Linke Hamburg">Linke</a></li></td>
# <td>13
# </td></tr>
# <tr>
# <td><li style="list-style-type: none; list-style-image: none; margin: 0;"><span style="border-left: 1.2em solid; border-left-color: #009ee0; padding-left: 0.4em;" title="Farbe #009ee0">﻿</span><a href="/wiki/AfD_Hamburg" title="AfD Hamburg">AfD</a></li></td>
# <td><span style="visibility:hidden;">0</span>7
# </td></tr>
# <tr>
# <td><li style="list-style-type: none; list-style-image: none; margin: 0;"><span style="border-left: 1.2em solid; border-left-color: #ffff00; padding-left: 0.4em;" title="Gelb">﻿</span><a href="/wiki/FDP_Hamburg" title="FDP Hamburg">FDP</a></li></td>
# <td><span style="visibility:hidden;">0</span>1
# </td></tr></tbody></table>, <table class="wikitable sortable zebra" style="text-align:center">
# <caption>Liste der Hamburger Bezirke <small>(Daten vom 02. November 2021)</small><sup class="reference" id="cite_ref-31"><a href="#cite_note-31">[31]</a></sup>
# </caption>
# <tbody><tr class="hintergrundfarbe5">
# <th>Nr.</th>
# <th>Bezirk</th>
# <th>Einwohner</th>
# <th>Fläche<br/>in km²</th>
# <th>Flächenanteil<br/>in Prozent</th>
# <th>Einwohner<br/>je km²
# </th></tr>
# <tr>
# <td>1</td>
# <td align="left" data-sort-value="4"><a class="image" href="/wiki/Datei:F%C3%BChrt_kein_Wappen.svg"><img alt="Führt kein Wappen.svg" class="noviewer" data-file-height="490" data-file-width="410" decoding="async" height="24" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/72/F%C3%BChrt_kein_Wappen.svg/20px-F%C3%BChrt_kein_Wappen.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/72/F%C3%BChrt_kein_Wappen.svg/30px-F%C3%BChrt_kein_Wappen.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/72/F%C3%BChrt_kein_Wappen.svg/40px-F%C3%BChrt_kein_Wappen.svg.png 2x" width="20"/></a> <a href="/wiki/Bezirk_Hamburg-Mitte" title="Bezirk Hamburg-Mitte">Hamburg-Mitte</a></td>
# <td>301.231</td>
# <td data-sort-value="1422">142,2</td>
# <td data-sort-value="1416">18,8</td>
# <td>2.118
# </td></tr>
# <tr>
# <td>2</td>
# <td align="left" data-sort-value="1"><a class="image" href="/wiki/Datei:DEU_Altona_COA.svg" title="Wappen des Bezirks Altona"><img alt="Wappen des Bezirks Altona" class="noviewer" data-file-height="492" data-file-width="432" decoding="async" height="23" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/89/DEU_Altona_COA.svg/20px-DEU_Altona_COA.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/89/DEU_Altona_COA.svg/30px-DEU_Altona_COA.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/89/DEU_Altona_COA.svg/40px-DEU_Altona_COA.svg.png 2x" width="20"/></a> <a href="/wiki/Bezirk_Altona" title="Bezirk Altona">Altona</a></td>
# <td>275.664</td>
# <td data-sort-value="783"><span style="visibility:hidden;">0</span>77,9</td>
# <td data-sort-value="1035">10,3</td>
# <td>3.539
# </td></tr>
# <tr>
# <td>3</td>
# <td align="left" data-sort-value="3"><a class="image" href="/wiki/Datei:Wappen_Eimsb%C3%BCttel1.svg" title="Wappen des Bezirks Eimsbüttel"><img alt="Wappen des Bezirks Eimsbüttel" class="noviewer" data-file-height="682" data-file-width="589" decoding="async" height="23" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/38/Wappen_Eimsb%C3%BCttel1.svg/20px-Wappen_Eimsb%C3%BCttel1.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/38/
.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/0e/Wappen_Harburg-Wilhelmsburg.png/40px-Wappen_Harburg-Wilhelmsburg.png 2x" width="20"/></a> <a href="/wiki/Bezirk_Harburg" title="Bezirk Harburg">Harburg</a></td>
# <td>169.221</td>
# <td data-sort-value="1252">125,2</td>
# <td data-sort-value="1658">16,6</td>
# <td>1.352
# </td></tr>
# <tr class="sortbottom hintergrundfarbe5">
# <td></td>
# <td style="text-align:left"><a class="image" href="/wiki/Datei:DEU_Hamburg_COA.svg" title="(Kleines) Wappen der Freien und Hansestadt Hamburg"><img alt="(Kleines) Wappen der Freien und Hansestadt Hamburg" class="noviewer" data-file-height="315" data-file-width="225" decoding="async" height="28" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/5d/DEU_Hamburg_COA.svg/20px-DEU_Hamburg_COA.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/5d/DEU_Hamburg_COA.svg/30px-DEU_Hamburg_COA.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/5d/DEU_Hamburg_COA.svg/40px-DEU_Hamburg_COA.svg.png 2x" width="20"/></a> Freie und Hansestadt Hamburg (Gesamt)</td>
# <td>1.904.444<span style="visibility:hidden;">0.</span></td>
# <td>755,2</td>
# <td>100,0<span style="visibility:hidden;">0</span></td>
# <td>2.522
# </td></tr></tbody></table>, <table cellpadding="0" cellspacing="0" class="infobox" style="width: 19.5em; float: right; clear: right; margin-left:1em;margin-right:0em; text-align: center; border: solid 1px silver;position:relative;z-index:100">
# <tbody><tr><th>Hamburg</th></tr>
# <tr><th style="font-size: 90%">Klimadiagramm</th></tr>
# <tr><td><table cellpadding="0" cellspacing="0" style="width: 100%; margin: 0; text-align: center; border: none; font-size: 90%">
# <tbody><tr><td>J</td><td>F</td><td>M</td><td>A</td><td>M</td><td>J</td><td>J</td><td>A</td><td>S</td><td>O</td><td>N</td><td>D</td></tr>
# <tr>
# <td><div style="width:1.6em;height:20em;position:relative;z-index:-1;padding:0;margin:0">
# <div style="height:8em;bottom:2em;width:1.6em;position:absolute;left:0;border-top:dotted 1px #cba;border-bottom:dotted 1px #abc;z-index:1;padding:0;margin:-1px 0"> </div>
# <div style="background:#ace;position:absolute;bottom:2em;left:.2em;width:1.2em;height:1.288em;z-index:3;overflow:hidden"> </div>
# <div style="color:blue;position:absolute;bottom:.5em;left:0;width:1.6em;height:1.5em;text-align:center"><span style="font-size:70%">64</span></div><div style="overflow:hidden;background:#e44;position:absolute;left:.4em;width:0.8em;z-index:4;bottom:9.72em;height:0.98em;"> </div>
# <div style="color:red;position:absolute;bottom:10.7em; left:-.4em;width:1.6em;height:1.5em;text-align:right;z-index:4"><span style="font-size:80%">4</span></div>
# <div style="color:red;position:absolute;bottom:8.22em; left:-.4em;width:1.6em;height:1.5em;text-align:right;z-index:4"><span style="font-size:80%">-1</span></div>
# </div>
# </td>
# <td><div style="width:1.6em;height:20em;position:relative;z-index:-1;padding:0;margin:0">
# <div style="height:8em;bottom:2em;width:1.6em;position:absolute;left:0;border-top:dotted 1px #cba;border-bottom:dotted 1px #abc;z-index:1;padding:0;margin:-1px 0"> </div>
# <div style="background:#ace;position:absolute;bottom:2em;left:.2em;width:1.2em;height:0.848em;z-index:3;overflow:hidden"> </div>
# <div style="color:blue;position:absolute;bottom:.5em;left:0;width:1.6em;height:1.5em;text-align:center"><span style="font-size:70%">42</span></div><div style="overflow:hidden;background:#e44;position:absolute;left:.4em;width:0.8em;z-index:4;bottom:9.76em;height:1.12em;"> </div>
# <div style="color:red;position:absolute;bottom:10.88em; left:-.4em;width:1.6em;height:1.5em;text-align:right;z-index:4"><span style="font-size:80%">4</span></div>
# <div style="color:red;position:absolute;bottom:8.26em; left:-.4em;width:1.6em;height:1.5em;text-align:right;z-index:4"><span style="font-size:80%">-1</span></div>
# </div>
# </td>
# <td><div style="width:1.6em;height:20em;position:relative;z-index:-1;padding:0;margin:0">
# <div style="height:8em;bottom:2em;width:1.6em;position:absolute;left:0;border-top:dotted 1px #cba;border-bottom:dotted 1px #abc;z-index:1;padding:0;margin:-1px 0"> </div>
# <div style="background:#ace;position:absolute;bottom:2em;left:.2em;width:1.2em;height:1.258em;z-index:3;overflow:hidden"> </div>
# <div style="color:blue;position:absolute;bottom:.5em;left:0;width:1.6em;height:1.5em;text-align:center"><span style="font-size:70%">63</span></div><div style="overflow:hidden;background:#e44;position:absolute;left:.4em;width:0.8em;z-index:4;bottom:10.22em;height:1.38em;"> </div>
# <div style="color:red;position:absolute;bottom:11.6em; left:-.4em;width:1.6em;height:1.5em;text-align:right;z-index:4"><span style="font-size:80%">8</span></div>
# <div style="color:red;position:absolute;bottom:8.72em; left:-.4em;width:1.6em;height:1.5em;text-align:right;z-index:4"><span style="font-size:80%">1</span></div>
# </div>
# </td>
# <td><div style="width:1.6em;height:20em;position:relative;z-index:-1;padding:0;margin:0">
# <div style="height:8em;bottom:2em;width:1.6em;position:absolute;left:0;border-top:dotted 1px #cba;border-bottom:dotted 1px #abc;z-index:1;padding:0;margin:-1px 0"> </div>
# <div style="background:#ace;position:absolute;bottom:2em;left:.2em;width:1.2em;height:0.912em;z-index:3;overflow:hidden"> </div>
# <div style="color:blue;position:absolute;bottom:.5em;left:0;width:1.6em;height:1.5em;text-align:center"><span style="font-size:70%">46</span></div><div style="overflow:hidden;background:#e44;position:absolute;left:.4em;width:0.8em;z-index:4;bottom:10.66em;height:1.8em;"> </div>
# <div style="color:red;position:absolute;bottom:12.46em; left:-.4em;width:1.6em;height:1.5em;text-align:right;z-index:4"><span style="font-size:80%">12</span></div>
# <div style="color:red;position:absolute;bottom:9.16em; left:-.4em;width:1.6em;height:1.5em;text-align:right;z-index:4"><span style="font-size:80%">3</span></div>
# </div>
# </td>
# <td><div style="width:1.6em;height:20em;position:relative;z-index:-1;padding:0;margin:0">
# <div style="height:8em;bottom:2em;width:1.6em;position:absolute;left:0;border-top:dotted 1px #cba;border-bottom:dotted 1px #abc;z-index:1;padding:0;margin:-1px 0"> </div>
# <div style="background:#ace;position:absolute;bottom:2em;left:.2em;width:1.2em;height:1.074em;z-index:3;overflow:hidden"> </div>
# <div style="color:blue;position:absolute;bottom:.5em;left:0;width:1.6em;height:1.5em;text-align:center"><span style="font-size:70%">54</span></div><div style="overflow:hidden;background:#e44;position:absolute;left:.4em;width:0.8em;z-index:4;bottom:11.48em;height:2.02em;"> </div>
# <div style="color:red;position:absolute;bottom:13.5em; left:-.4em;width:1.6em;height:1.5em;text-align:right;z-index:4"><span style="font-size:80%">18</span></div>
# <div style="color:red;position:absolute;bottom:9.98em; left:-.4em;width:1.6em;height:1.5em;text-align:right;z-index:4"><span style="font-size:80%">7</span></div>
# </div>
# </td>
# <td><div style="width:1.6em;height:20em;position:relative;z-index:-1;padding:0;margin:0">
# <div style="height:8em;bottom:2em;width:1.6em;position:absolute;left:0;border-top:dotted 1px #cba;border-bottom:dotted 1px #abc;z-index:1;padding:0;margin:-1px 0"> </div>
# <div style="background:#ace;position:absolute;bottom:2em;left:.2em;width:1.2em;height:1.538em;z-index:3;overflow:hidden"> </div>
# <div style="color:blue;position:absolute;bottom:.5em;left:0;width:1.6em;height:1.5em;text-align:center"><span style="font-size:70%">77</span></div><div style="overflow:hidden;background:#e44;position:absolute;left:.4em;width:0.8em;z-index:4;bottom:12.1em;height:1.88em;"> </div>
# <div style="color:red;position:absolute;bottom:13.98em; left:-.4em;width:1.6em;height:1.5em;text-align:right;z-index:4"><span style="font-size:80%">20</span></div>
# <div style="color:red;position:absolute;bottom:10.6em; left:-.4em;width:1.6em;height:1.5em;text-align:right;z-index:4"><span style="font-size:80%">11</span></div>
# </div>
# </td>
# <td><div style="width:1.6em;height:20em;position:relative;z-index:-1;padding:0;margin:0">
# <div style="height:8em;bottom:2em;width:1.6em;position:absolute;left:0;border-top:dotted 1px #cba;border-bottom:dotted 1px #abc;z-index:1;padding:0;margin:-1px 0"> </div>
# <div style="background:#ace;position:absolute;bottom:2em;left:.2em;width:1.2em;height:1.494em;z-index:3;overflow:hidden"> </div>
# <div style="color:blue;position:absolute;bottom:.5em;left:0;width:1.6em;height:1.5em;text-align:center"><span style="font-size:70%">75</span></div><div style="overflow:hidden;background:#e44;position:absolute;left:.4em;width:0.8em;z-index:4;bottom:12.54em;height:1.88em;"> </div>
# <div style="color:red;position:absolute;bottom:14.42em; left:-.4em;width:1.6em;height:1.5em;text-align:right;z-index:4"><span style="font-size:80%">22</span></div>
# <div style="color:red;position:absolute;bottom:11.04em; left:-.4em;width:1.6em;height:1.5em;text-align:right;z-index:4"><span style="font-size:80%">13</span></div>
# </div>
# </td>
# <td><div style="width:1.6em;height:20em;position:relative;z-index:-1;padding:0;margin:0">
# <div style="height:8em;bottom:2em;width:1.6em;position:absolute;left:0;border-top:dotted 1px #cba;border-bottom:dotted 1px #abc;z-index:1;padding:0;margin:-1px 0"> </div>
# <div style="background:#ace;position:absolute;bottom:2em;left:.2em;width:1.2em;height:1.46em;z-index:3;overflow:hidden"> </div>
# <div style="color:blue;position:absolute;bottom:.5em;left:0;width:1.6em;height:1.5em;text-align:center"><span style="font-size:70%">73</span></div><div style="overflow:hidden;background:#e44;position:absolute;left:.4em;width:0.8em;z-index:4;bottom:12.5em;height:1.94em;"> </div>
# <div style="color:red;position:absolute;bottom:14.44em; left:-.4em;width:1.6em;height:1.5em;text-align:right;z-index:4"><span style="font-size:80%">22</span></div>
# <div style="color:red;position:absolute;bottom:11em; left:-.4em;width:1.6em;height:1.5em;text-align:right;z-index:4"><span style="font-size:80%">13</span></div>
# </div>
# </td>
# <td><div style="width:1.6em;height:20em;position:relative;z-index:-1;padding:0;margin:0">
# <div style="height:8em;bottom:2em;width:1.6em;position:absolute;left:0;border-top:dotted 1px #cba;border-bottom:dotted 1px #abc;z-index:1;padding:0;margin:-1px 0"> </div>
# <div style="background:#ace;position:absolute;bottom:2em;left:.2em;width:1.2em;height:1.368em;z-index:3;overflow:hidden"> </div>
# <div style="color:blue;position:absolute;bottom:.5em;left:0;width:1.6em;height:1.5em;text-align:center"><span style="font-size:70%">68</span></div><div style="overflow:hidden;background:#e44;position:absolute;left:.4em;width:0.8em;z-index:4;bottom:11.92em;height:1.66em;"> </div>
# <div style="color:red;position:absolute;bottom:13.58em; left:-.4em;width:1.6em;height:1.5em;text-align:right;z-index:4"><span style="font-size:80%">18</span></div>
# <div style="color:red;position:absolute;bottom:10.42em; left:-.4em;width:1.6em;height:1.5em;text-align:right;z-index:4"><span style="font-size:80%">10</span></div>
# </div>
# </td>
# <td><div style="width:1.6em;height:20em;position:relative;z-index:-1;padding:0;margin:0">
# <div style="height:8em;bottom:2em;width:1.6em;position:absolute;left:0;border-top:dotted 1px #cba;border-bottom:dotted 1px #abc;z-index:1;padding:0;margin:-1px 0"> </div>
# <div style="background:#ace;position:absolute;bottom:2em;left:.2em;width:1.2em;height:1.272em;z-index:3;overflow:hidden"> </div>
# ...
# <a class="image" href="/wiki/Datei:Flagge_Gro%C3%9Fherzogtum_Sachsen-Weimar-Eisenach
svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/98/Dienstflagge_Elsa%C3%9F-Lothringen_Kaiserreich.svg/40px-Dienstflagge_Elsa%C3%9F-Lothringen_Kaiserreich.svg.png 2x" width="20"/></a> <a href="/wiki/Reichsland_Elsa%C3%9F-Lothringen" title="Reichsland Elsaß-Lothringen">Elsaß-Lothringen</a>
# </p>
# </td></tr>
# </tbody></table>]

# %% [markdown]
# Nun muss man einen Weg finden, die Einwohnerzahl zu isolieren. Eine Lösung: Die Zeilennummer finden und die entsprechende Zeile extrahieren:

# %%
rows = table.find_all('tr')

# %% [markdown]
# Insgesamt gibt es 55 Zeilen:

# %%
len(rows)
# Out:
# 55

# %% [markdown]
# Lässt man sich Zeilennummer und Zeileninhalt ausgeben, erkennt man, dass die Eiwohnerzahl in der 22. Zeile steht:

# %%
print([list((i, rows[i])) for i in range(len(rows))])
# Out:
# [[0, <tr>
# <th class="hintergrundfarbe5" colspan="2" style="font-size:1.3em;">Freie und Hansestadt Hamburg
# </th></tr>], [1, <tr>
# <td><div class="center"><div class="floatnone"><a class="image" href="/wiki/Datei:Flag_of_Hamburg.svg" title="Landesflagge der Freien und Hansestadt Hamburg"><img alt="Landesflagge der Freien und Hansestadt Hamburg" data-file-height="400" data-file-width="600" decoding="async" height="93" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/74/Flag_of_Hamburg.svg/140px-Flag_of_Hamburg.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/74/Flag_of_Hamburg.svg/210px-Flag_of_Hamburg.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/74/Flag_of_Hamburg.svg/280px-Flag_of_Hamburg.svg.png 2x" width="140"/></a></div></div>
# </td>
# <td rowspan="4"><div class="center"><div class="floatnone"><div class="noresize" style="height: 271px; width: 200px; "><map name="ImageMap_90f4e28b646220b9"><area alt="Berlin" coords="163,87,9" href="/wiki/Berlin" shape="circle" title="Berlin"/><area alt="Bremen" coords="64,67,9" href="/wiki/Freie_Hansestadt_Bremen" shape="circle" title="Bremen"/><area alt="Bremen" coords="61,52,6" href="/wiki/Freie_Hansestadt_Bremen" shape="circle" title="Bremen"/><area alt="Hamburg" coords="92,52,9" href="/wiki/Hamburg" shape="circle" title="Hamburg"/><area alt="Niedersachsen" coords="62,41,20,46,20,51,29,58,27,82,20,83,21,88,27,97,41,90,46,94,46,104,57,101,53,90,62,87,64,93,70,89,72,93,69,96,77,116,84,121,80,128,86,131,104,121,104,105,114,103,109,78,122,72,112,59,98,58,86,57,85,52,75,41" href="/wiki/Niedersachsen" shape="poly" title="Niedersachsen"/><area alt="Bayern" coords="70,191,68,172,91,156,104,167,122,161,133,161,148,176,178,214,179,226,156,240,164,257,160,262,114,266,98,268,82,260,93,256,91,233,102,219,96,207,92,193,86,184,78,184" href="/wiki/Bayern" shape="poly" title="Bayern"/><area alt="Saarland" coords="20,196,13" href="/wiki/Saarland" shape="circle" title="Saarland"/><area alt="Schleswig-Holstein" coords="67,40,51,8,53,1,65,0,81,6,116,18,118,22,109,38,109,49,103,57,97,57,95,46,84,50,76,40" href="/wiki/Schleswig-Holstein" shape="poly" title="Schleswig-Holstein"/><area alt="Brandenburg" coords="122,71,137,76,138,100,158,110,159,125,178,125,179,120,194,118,191,85,180,73,183,57,170,52,163,62,149,64,133,57,119,66" href="/wiki/Brandenburg" shape="poly" title
src="//upload.wikimedia.org/wikipedia/commons/thumb/6/63/Wappen_der_Hamburgischen_B%C3%BCrgerschaft.svg/150px-Wappen_der_Hamburgischen_B%C3%BCrgerschaft.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/63/Wappen_der_Hamburgischen_B%C3%BCrgerschaft.svg/225px-Wappen_der_Hamburgischen_B%C3%BCrgerschaft.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/63/Wappen_der_Hamburgischen_B%C3%BCrgerschaft.svg/300px-Wappen_der_Hamburgischen_B%C3%BCrgerschaft.svg.png 2x" width="150"/></a></div></div>
# </td></tr>], [4, <tr style="text-align:center;">
# <td><a href="/wiki/Landeswappen_Hamburgs#Großes_Staatswappen_und_Logo" title="Landeswappen Hamburgs">Großes Staatswappen</a>
# </td></tr>], [5, <tr>
# <th class="hintergrundfarbe5">Basisdaten
# </th>
# <th>
# </th></tr>], [6, <tr>
# <td><a href="/wiki/Amtssprachen_innerhalb_Deutschlands" title="Amtssprachen innerhalb Deutschlands">Amtssprache</a>:</td>
# <td><a href="/wiki/Deutsche_Sprache" title="Deutsche Sprache">Deutsch</a><sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>
# </td></tr>], [7, <tr>
# <td><a href="/wiki/Staatsform" title="Staatsform">Staatsform</a>:</td>
# <td><a class="mw-redirect" href="/wiki/Parlamentarische_Republik" title="Parlamentarische Republik">parlamentarische Republik</a>,<br/><a href="/wiki/Souver%C3%A4nit%C3%A4t" title="Souveränität">teilsouveräner Gliedstaat</a><br/>eines <a href="/wiki/Bundesstaat_(F%C3%B6deraler_Staat)" title="Bundesstaat (Föderaler Staat)">Bundesstaates</a>
# </td></tr>], [8, <tr>
# <td><a href="/wiki/Postleitzahl_(Deutschland)" title="Postleitzahl (Deutschland)">Postleitzahlen</a>:</td>
# <td>20095–21149,<br/>22041–22769,<br/><a href="/wiki/Neuwerk" title="Neuwerk">27499</a>
# </td></tr>], [9, <tr>
# <td><a href="/wiki/Telefonvorwahl_(Deutschland)" title="Telefonvorwahl (Deutschland)">Telefonvorwahlen</a>:</td>
# <td>040, <a href="/wiki/Neuwerk" title="Neuwerk">04721</a>
# </td></tr>], [10, <tr>
# <td><a href="/wiki/Kfz-Kennzeichen_(Deutschland)" title="Kfz-Kennzeichen (Deutschland)">Kfz-Kennzeichen</a>:</td>
# <td>HH
# </td></tr>], [11, <tr>
# <td><a href="/wiki/Kaufkraft_(Konsum)" title="Kaufkraft (Konsum)">Kaufkraftindex</a>:</td>
# <td>108,3 % <small>(2021)</small><sup class="reference" id="cite_ref-GfK_Kaufkraft_2021_2-0"><a href="#cite_note-GfK_Kaufkraft_2021-2">[2]</a></sup>
# </td></tr>], [12, <tr>
# <td><a href="/wiki/Kaufkraft_(Konsum)" title="Kaufkraft (Konsum)">Kaufkraft</a> je Einwohner:</td>
# <td>25.607 EUR <small>(2021)</small><sup class="reference" id="cite_ref-GfK_Kaufkraft_2021_2-1"><a href="#cite_note-GfK_Kaufkraft_2021-2">[2]</a></sup>
# </td></tr>], [13, <tr>
# <td><a href="/wiki/Bruttoinlandsprodukt" title="Bruttoinlandsprodukt">BIP</a> (nominal):</td>
# <td>117,6 Mrd. EUR <small>(<a href="/wiki/Liste_der_deutschen_Bundesl%C3%A4nder_nach_Bruttoinlandsprodukt" title="Liste der deutschen Bundesländer nach Bruttoinlandsprodukt">9.</a>)</small> <small>(2017)</small><sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup>
# </td></tr>], [14, <tr>
# <td>BIP pro Einwohner:</td>
# <td>64.957 EUR <small>(<a href="/wiki/Liste_der_deutschen_Bundesl%C3%A4nder_nach_Bruttoinlandsprodukt" title="Liste der deutschen Bundesländer nach Bruttoinlandsprodukt">1.</a>)</small> <small>(2017)</small><br/>
# </td></tr>], [15, <tr>
# <td><a href="/wiki/Schulden" title="Schulden">Schulden</a>:</td>
# <td>34,798 Mrd. EUR <small>(30. Juni 2020)</small><sup class="reference" id="cite_ref-Schulden_4-0"><a href="#cite_note-Schulden-4">[4]</a></sup>
# </td></tr>], [16, <tr>
# <td>Adresse des <a href="/wiki/Senat_der_Freien_und_Hansestadt_Hamburg" title="Senat der Freien und Hansestadt Hamburg">Senates</a>:</td>
# <td><a href="/wiki/Rathausmarkt_(Hamburg)" title="Rathausmarkt (Hamburg)">Rathausmarkt</a> 1<br/>20095 Hamburg
# </td></tr>], [17, <tr>
# <td><a href="/wiki/Amtlicher_Gemeindeschl%C3%BCssel" title="Amtlicher Gemeindeschlüssel">Gemeindeschlüssel</a>:</td>
# <td><span style="white-space:nowrap">02 0 00 000</span>
# </td></tr>], [18, <tr>
# <td><a href="/wiki/ISO_3166-2:DE" title="ISO 3166-2:DE">ISO 3166-2</a>:</td>
# <td>DE-HH
# </td></tr>], [19, <tr>
# <td><a href="/wiki/UN/LOCODE" title="UN/LOCODE">UN/LOCODE</a>:</td>
# <td><span style="white-space:nowrap">DE HAM</span>
# </td></tr>], [20, <tr>
# <td>Website:</td>
# <td><a class="external text" href="https://www.hamburg.de/stadt-staat/" rel="nofollow">www.hamburg.de</a>
# </td></tr>], [21, <tr>
# <th class="hintergrundfarbe5" colspan="2">Bevölkerung
# </th></tr>], [22, <tr>
# <td><a href="/wiki/Einwohner" title="Einwohner">Einwohner</a>:</td>
# <td>1.851.430 <small>(31. März 2021)</small><sup class="reference" id="cite_ref-statamt_5-0"><a href="#cite_note-statamt-5">[5]</a></sup>
# </td></tr>], [23, <tr>
# <td>– davon <a href="/wiki/Ausl%C3%A4nder" title="Ausländer">Ausländer</a>:</td>
# <td>312.802 <small>(März 2021)</small><sup class="reference" id="cite_ref-Ausländer_6-0"><a href="#cite_note-Ausländer-6">[6]</a></sup>
# </td></tr>], [24, <tr>
# <td>– davon mit<br/><a href="/wiki/Migrationshintergrund" title="Migrationshintergrund">Migrationshintergrund</a>:</td>
# <td>696.711 <small>(31. Dez. 2020)</small><sup class="reference" id="cite_ref-Statistik-Nord_2020_7-0"><a href="#cite_note-Statistik-Nord_2020-7">[7]</a></sup>
# </td></tr>], [25, <tr>
# <td>Ausländeranteil:</td>
# <td>16,9 % <small>(31. Dez. 2018)</small><sup class="reference" id="cite_ref-Ausländer_6-1"><a href="#cite_note-Ausländer-6">[6]</a></sup>
# </td></tr>], [26, <tr>
# <td>Migrationshintergrundanteil:</td>
# <td>36,7 % <small>(31. Dez. 2020)</small><sup class="reference" id="cite_ref-Statistik-Profile_2015_8-0"><a href="#cite_note-Statistik-Profile_2015-8">[8]</a></sup>
# </td></tr>], [27, <tr>
# <td>Einwohner <a href="/wiki/Metropolregion_Hamburg" title="Metropolregion Hamburg">Metropolregion</a>:</td>
# <td>~ 5.380.000 <small>(31. Dezember 2018)</small><sup class="reference" id="cite_ref-Metropolregion_Hamburg_9-0"><a href="#cite_note-Metropolregion_Hamburg-9">[9]</a></sup>
# </td></tr>], [28, <tr>
# <td><a href="/wiki/Bev%C3%B6lkerungsdichte" title="Bevölkerungsdichte">Bevölkerungsdichte</a>:</td>
# <td>2.522 Einw. pro km² <small>(31. Dez. 2019)</small>
# </td></tr>], [29, <tr>
# <td><a href="/wiki/Arbeitslosenstatistik" title="Arbeitslosenstatistik">Arbeitslosenquote</a>:</td>
# <td>6,5 % <small>(April 2022)</small><sup class="reference" id="cite_ref-10"><a href="#cite_note-10">[10]</a></sup>
# </td></tr>], [30, <tr>
# <th class="hintergrundfarbe5" colspan="2">Geographie
# </th></tr>], [31, <tr>
# <td><a href="/wiki/Geographische_Koordinaten" title="Geographische Koordinaten">geographische Lage</a>:</td>
# <td><span class="coordinates plainlinks-print" id="text_coordinates"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Hamburg&amp;language=de&amp;params=53.550556_N_9.993333_E_dim:40000_region:DE-HH_type:adm1st(1773218)"><span title="Breitengrad">53° 33′ <abbr title="Nord">N</abbr></span>, <span title="Längengrad">10° 0′ <abbr title="Ost">O</abbr></span></a></span><span class="geo noexcerpt" style="display:none"><span class="body"></span><span class="latitude">53.550556</span><span class="longitude">9.993333</span><span class="elevation"></span></span><span class="coordinates noprint" id="coordinates"><span title="Koordinatensystem WGS84">Koordinaten: </span><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=Hamburg&amp;language=de&amp;params=53.550556_N_9.993333_E_dim:40000_region:DE-HH_type:adm1st(1773218)"><span title="Breitengrad">53° 33′ <abbr title="Nord">N</abbr></span>, <span title="Längengrad">10° 0′ <abbr title="Ost">O</abbr></span></a></span>
# </td></tr>], [32, <tr>
# <td><a href="/wiki/H%C3%B6he" title="Höhe">Höhe</a>:</td>
# <td><span style="border-width:0px; padding:0px; margin:0px;">6 <abbr title="Meter über Normalhöhennull">m ü. <a href="/wiki/Normalh%C3%B6hennull" title="Normalhöhennull">NHN</a></abbr></span>
# </td></tr>], [33, <tr>
# <td><a href="/wiki/Fl%C3%A4cheninhalt" title="Flächeninhalt">Fläche</a>:</td>
# <td><a class="mw-redirect" href="/wiki/Gr%C3%B6%C3%9Fenordnung_(Fl%C3%A4che)#100_km²_bis_1000_km²" title="Größenordnung (Fläche)">755,09 km²</a><sup class="reference" id="cite_ref-11"><a href="#cite_note-11">[11]</a></sup><br/><small>(Rang: <a href="/wiki/Liste_der_deutschen_Bundesl%C3%A4nder_nach_Fl%C3%A4che" title="Liste der deutschen Bundesländer nach Fläche">15. als Land</a>, <a class="mw-redirect" href="/wiki/Liste_der_100_fl%C3%A4chengr%C3%B6%C3%9Ften_Gemeinden_Deutschlands" title="Liste der 100 flächengrößten Gemeinden Deutschlands">2. als Gemeinde</a>)</small>
# </td></tr>], [34, <tr>
# <td>Stadtgliederung:<sup class="reference" id="cite_ref-BezVG_12-0"><a href="#cite_note-BezVG-12">[12]</a></sup></td>
# <td><a href="/wiki/Bezirke_in_Hamburg" title="Bezirke in Hamburg">7 Bezirke, 104 Stadtteile</a>
# </td></tr>], [35, <tr>
# <th class="hintergrundfarbe5" colspan="2">Politik
# </th></tr>], [36, <tr>
# <td><a href="/wiki/Erster_B%C3%BCrgermeister" title="Erster Bürgermeister">Erster Bürgermeister</a>:</td>
# <td><a href="/wiki/Peter_Tschentscher" title="Peter Tschentscher">Peter Tschentscher</a> (SPD)
# </td></tr>], [37, <tr>
# <td><a href="/wiki/Erster_B%C3%BCrgermeister#Zweiter_Bürgermeister" title="Erster Bürgermeister">Zweite Bürgermeisterin</a>:</td>
# <td><a href="/wiki/Katharina_Fegebank" title="Katharina Fegebank">Katharina Fegebank</a> (Grüne)
# </td></tr>], [38, <tr>
# <td><a href="/wiki/Pr%C3%A4sident_der_Hamburgischen_B%C3%BCrgerschaft" title="Präsident der Hamburgischen Bürgerschaft">Bürgerschaftspräsidentin</a>:</td>
# <td><a href="/wiki/Carola_Veit" title="Carola Veit">Carola Veit</a> (SPD)
# </td></tr>], [39, <tr>
# <td>Regierende <a href="/wiki/Politische_Partei" title="Politische Partei">Parteien</a>:</td>
# <td><a class="mw-redirect" href="/wiki/SPD" title="SPD">SPD</a> und <a href="/wiki/B%C3%BCndnis_90/Die_Gr%C3%BCnen" title="Bündnis 90/Die Grünen">Grüne</a>
# </td></tr>], [40, <tr>
# <td colspan="2" style="text-align: center;"><a href="/wiki/Liste_der_Mitglieder_der_Hamburgischen_B%C3%BCrgerschaft_(22._Wahlperiode)" title="Liste der Mitglieder der Hamburgischen Bürgerschaft (22. Wahlperiode)">Sitzverteilung der 22. Bürgerschaft</a><br/>
# <div class="centered diagram noprint" style="width:14.4em; height:7.2em; padding:0.9em; overflow:hidden; background:white; text-align:center;"><div style="width:14.4em; height:7.2em; position:relative; -o-transform-origin:bottom center;-moz-transform-origin:bottom center;-webkit-transform-origin:bottom center;-ms-transform-origin:bottom center;transform-origin:bottom center; -moz-border-radius-topleft:7.2em; -webkit-border-top-left-radius:7.2em; border-top-left-radius:7.2em; -moz-border-radius-topright:7.2em;-webkit-border-top-right-radius:7.2em;border-top-right-radius:7.2em; background:#BE3075;">
# <div style="-o-transform:rotate(19.024390243902deg);-moz-transform:rotate(19.024390243902deg);-webkit-transform:rotate(19.024390243902deg);-ms-transform:rotate(19.024390243902deg);transform:rotate(19.024390243902deg); width:14.4em; height:7.2em; position:relative; -o-transform-origin:bottom center;-moz-transform-origin:bottom center;-webkit-transform-origin:bottom center;-ms-transform-origin:bottom center;transform-origin:bottom center; -moz-border-radius-topleft:7.2em; -webkit-border-top-left-radius:7.2em; border-top-left-radius:7.2em; -moz-border-radius-topright:7.2em;-webkit-border-top-right-radius:7.2em;border-top-right-radius:7.2em; background:#E3000F;">
# <div style="-o-transform:rotate(79.024390243902deg);-moz-transform:rotate(79.024390243902deg);-webkit-transform:rotate(79.024390243902deg);-ms-transform:rotate(79.024390243902deg);transform:rotate(79.024390243902deg); width:14.4em; height:7.2em; position:relative; -o-transform-origin:bottom center;-moz-transform-origin:bottom center;-webkit-transform-origin:bottom center;-ms-transform-origin:bottom center;transform-origin:bottom center; -moz-border-radius-topleft:7.2em; -webkit-border-top-left-radius:7.2em; border-top-left-radius:7.2em; -moz-border-radius-topright:7.2em;-webkit-border-top-right-radius:7.2em;border-top-right-radius:7.2em; background:#46962b;">
# <div style="-o-transform:rotate(48.292682926829deg);-moz-transform:rotate(48.292682926829deg);-webkit-transform:rotate(48.292682926829deg);-ms-transform:rotate(48.292682926829deg);transform:rotate(48.292682926829deg); width:14.4em; height:7.2em; position:relative; -o-transform-origin:bottom center;-moz-transform-origin:bottom center;-webkit-transform-origin:bottom center;-ms-transform-origin:bottom center;transform-origin:bottom center; -moz-border-radius-topleft:7.2em; -webkit-border-top-left-radius:7.2em; border-top-left-radius:7.2em; -moz-border-radius-topright:7.2em;-webkit-border-top-right-radius:7.2em;border-top-right-radius:7.2em; background:#ffff00;">
# <div style="-o-transform:rotate(1.4634146341463deg);-moz-transform:rotate(1.4634146341463deg);-webkit-transform:rotate(1.4634146341463deg);-ms-transform:rotate(1.4634146341463deg);transform:rotate(1.4634146341463deg); width:14.4em; height:7.2em; position:relative; -o-transform-origin:bottom center;-moz-transform-origin:bottom center;-webkit-transform-origin:bottom center;-ms-transform-origin:bottom center;transform-origin:bottom center; -moz-border-radius-topleft:7.2em; -webkit-border-top-left-radius:7.2em; border-top-left-radius:7.2em; -moz-border-radius-topright:7.2em;-webkit-border-top-right-radius:7.2em;border-top-right-radius:7.2em; background:#000000;">
# <div style="-o-transform:rotate(21.951219512195deg);-moz-transform:rotate(21.951219512195deg);-webkit-transform:rotate(21.951219512195deg);-ms-transform:rotate(21.951219512195deg);transform:rotate(21.951219512195deg); width:14.4em; height:7.2em; position:relative; -o-transform-origin:bottom center;-moz-transform-origin:bottom center;-webkit-transform-origin:bottom center;-ms-transform-origin:bottom center;transform-origin:bottom center; -moz-border-radius-topleft:7.2em; -webkit-border-top-left-radius:7.2em; border-top-left-radius:7.2em; -moz-border-radius-topright:7.2em;-webkit-border-top-right-radius:7.2em;border-top-right-radius:7.2em; background:#009ee0;">
# <div style="-o-transform:rotate(10.243902439024deg);-moz-transform:rotate(10.243902439024deg);-webkit-transform:rotate(10.243902439024deg);-ms-transform:rotate(10.243902439024deg);transform:rotate(10.243902439024deg); width:14.4em; height:7.2em; -o-transform-origin:bottom center;-moz-transform-origin:bottom center;-webkit-transform-origin:bottom center;-ms-transform-origin:bottom center;transform-origin:bottom center; background:white;"><div style="-o-transform:scale(0);-moz-transform:scale(0);-webkit-transform:scale(0);-ms-transform:scale(0);transform:scale(0); width:100%;"><span style="display:inline-block;background:#BE3075;width:10.569105691057%;overflow:hidden;"> </span><span style="display:inline-block;background:#E3000F;width:43.90243902439%;overflow:hidden;"> </span><span style="display:inline-block;background:#46962b;width:26.829268292683%;overflow:hidden;"> </span><span style="display:inline-block;background:#ffff00;width:0.81300813008128%;overflow:hidden;"> </span><span style="display:inline-block;background:#000000;width:12.195121951219%;overflow:hidden;"> </span><span style="display:inline-block;background:#009ee0;width:5.6910569105689%;overflow:hidden;"> </span></div>
# </div>
# </div></div></div></div></div></div><div style="width:5.4em; height:5.4em; margin:-2.7em auto; -moz-border-radius:2.7em; -webkit-border-radius:2.7em; border-radius:2.7em; -o-transform:translate(0,0);-moz-transform:translate(0,0);-webkit-transform:translate(0,0);-ms-transform:translate(0,0);transform:translate(0,0); background:white;"></div>
# </div>
# <p><br/>
# </p>
# </td></tr>], [41, <tr>
# <td><a href="/wiki/Sitzverteilung_in_den_deutschen_Landesparlamenten" title="Sitzverteilung in den deutschen Landesparlamenten">Sitzverteilung in der<br/>Hamburgischen<br/>Bürgerschaft</a> 2020<br/>(123 Sitze):<sup class="reference" id="cite_ref-13"><a href="#cite_note-13">[13]</a></sup></td>
# <td>
# <table>
# <tbody><tr>
# <td><li style="list-style-type: none; list-style-image: none; margin: 0;"><span style="border-left: 1.2em solid; border-left-color: #E3000F; padding-left: 0.4em;" title="Farbe #E3000F">﻿</span><a href="/wiki/SPD_Hamburg" title="SPD Hamburg">SPD</a></li></td>
# <td>54
# </td></tr>
# <tr>
# <td><li style="list-style-type: none; list-style-image: none; margin: 0;"><span style="border-left: 1.2em solid; border-left-color: #46962b; padding-left: 0.4em;" title="Farbe #46962b">﻿</span><a href="/wiki/B%C3%BCndnis_90/Die_Gr%C3%BCnen_Hamburg" title="Bündnis 90/Die Grünen Hamburg">Grüne</a></li></td>
# <td>33
# </td></tr>
# <tr>
# <td><li style="list-style-type: none; list-style-image: none; margin: 0;"><span style="border-left: 1.2em solid; border-left-color: #000000; padding-left: 0.4em;" title="Schwarz">﻿</span><a href="/wiki/CDU_Hamburg" title="CDU Hamburg">CDU</a></li></td>
# <td>15
# </td></tr>
# <tr>
# <td><li style="list-style-type: none; list-style-image: none; margin: 0;"><span style="border-left: 1.2em solid; border-left-color: #BE3075; padding-left: 0.4em;" title="Farbe #BE3075">﻿</span><a href="/wiki/Die_Linke_Hamburg" title="Die Linke Hamburg">Linke</a></li></td>
# <td>13
# </td></tr>
# <tr>
# <td><li style="list-style-type: none; list-style-image: none; margin: 0;"><span style="border-left: 1.2em solid; border-left-color: #009ee0; padding-left: 0.4em;" title="Farbe #009ee0">﻿</span><a href="/wiki/AfD_Hamburg" title="AfD Hamburg">AfD</a></li></td>
# <td><span style="visibility:hidden;">0</span>7
# </td></tr>
# <tr>
# <td><li style="list-style-type: none; list-style-image: none; margin: 0;"><span style="border-left: 1.2em solid; border-left-color: #ffff00; padding-left: 0.4em;" title="Gelb">﻿</span><a href="/wiki/FDP_Hamburg" title="FDP Hamburg">FDP</a></li></td>
# <td><span style="visibility:hidden;">0</span>1
# </td></tr></tbody></table>
# </td></tr>], [42, <tr>
# <td><li style="list-style-type: none; list-style-image: none; margin: 0;"><span style="border-left: 1.2em solid; border-left-color: #E3000F; padding-left: 0.4em;" title="Farbe #E3000F">﻿</span><a href="/wiki/SPD_Hamburg" title="SPD Hamburg">SPD</a></li></td>
# <td>54
# </td></tr>], [43, <tr>
# <td><li style="list-style-type: none; list-style-image: none; margin: 0;"><span style="border-left: 1.2em solid; border-left-color: #46962b; padding-left: 0.4em;" title="Farbe #46962b">﻿</span><a href="/wiki/B%C3%BCndnis_90/Die_Gr%C3%BCnen_Hamburg" title="Bündnis 90/Die Grünen Hamburg">Grüne</a></li></td>
# <td>33
# </td></tr>], [44, <tr>
# <td><li style="list-style-type: none; list-style-image: none; margin: 0;"><span style="border-left: 1.2em solid; border-left-color: #000000; padding-left: 0.4em;" title="Schwarz">﻿</span><a href="/wiki/CDU_Hamburg" title="CDU Hamburg">CDU</a></li></td>
# <td>15
# </td></tr>], [45, <tr>
# <td><li style="list-style-type: none; list-style-image: none; margin: 0;"><span style="border-left: 1.2em solid; border-left-color: #BE3075; padding-left: 0.4em;" title="Farbe #BE3075">﻿</span><a href="/wiki/Die_Linke_Hamburg" title="Die Linke Hamburg">Linke</a></li></td>
# <td>13
# </td></tr>], [46, <tr>
# <td><li style="list-style-type: none; list-style-image: none; margin: 0;"><span style="border-left: 1.2em solid; border-left-color: #009ee0; padding-left: 0.4em;" title="Farbe #009ee0">﻿</span><a href="/wiki/AfD_Hamburg" title="AfD Hamburg">AfD</a></li></td>
# <td><span style="visibility:hidden;">0</span>7
# </td></tr>], [47, <tr>
# <td><li style="list-style-type: none; list-style-image: none; margin: 0;"><span style="border-left: 1.2em solid; border-left-color: #ffff00; padding-left: 0.4em;" title="Gelb">﻿</span><a href="/wiki/FDP_Hamburg" title="FDP Hamburg">FDP</a></li></td>
# <td><span style="visibility:hidden;">0</span>1
# </td></tr>], [48, <tr>
# <td><a href="/wiki/Politik_in_Hamburg" title="Politik in Hamburg">letzte Parlamentswahl</a>:</td>
# <td><a href="/wiki/B%C3%BCrgerschaftswahl_in_Hamburg_
,219,201,208,205,209,216,223,228,206,236,212,241,207,250,212,257,205,258,197,253,193,251,180,253,171,232,165,205,172,198,169,180,178,171,168,167,177,147,172,147,179,145,177,143,186,143,192,117,194,84,192" href="/wiki/Bezirk_Hamburg-Mitte" shape="poly" title="Hamburg-Mitte"/><area alt="Niedersachsen" coords="1,178,41,181,36,198,43,209,36,216,34,229,45,234,44,245,57,243,57,265,92,295,107,281,119,277,122,289,115,312,127,312,140,306,143,303,156,314,172,305,186,290,190,284,195,263,217,283,225,298,238,303,247,313,265,329,291,329,309,328,313,310,333,298,340,291,352,298,358,298,358,352,74,352,75,287,0,286" href="/wiki/Niedersachsen" shape="poly" title="Niedersachsen"/><area alt="Schleswig-Holstein" coords="344,291,352,298,359,297,357,0,1,0,0,176,21,178,23,156,30,130,32,108,44,113,45,127,56,131,54,141,66,157,79,146,93,132,112,91,121,86,154,92,157,61,185,62,195,66,199,62,198,53,206,42,198,37,210,26,225,34,250,7,267,8,276,19,269,35,258,41,245,61,260,76,272,88,275,101,290,105,285,115,272,120,270,132,276,150,259,156,251,167,256,174,251,181,250,194,258,196,257,206,268,218,281,210,286,221,298,236,312,250,322,264,331,274,334,280,340,272,344,272,349,278" href="/wiki/Schleswig-Holstein" shape="poly" title="Schleswig-Holstein"/><area alt="Insel Neuwerk (zu HH-Mitte)" coords="2,287,74,287,75,352,0,352" href="/wiki/Hamburg-Mitte" shape="poly" title="Insel Neuwerk (zu HH-Mitte)"/></map><img alt="Karte" data-file-height="548" data-file-width="558" decoding="async" height="354" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d3/Hamburg%2C_administrative_divisions_%28%2Bdistricts_-boroughs_-pop%29_-_de_-_colored.svg/360px-Hamburg%2C_administrative_divisions_%28%2Bdistricts_-boroughs_-pop%29_-_de_-_colored.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d3/Hamburg%2C_adm ...
# </td></tr>], [53, <tr>
# <th class="hintergrundfarbe5" colspan="2">Logo
# </th></tr>], [54, <tr>
# <td colspan="2"><div class="center"><div class="floatnone"><a class="image" href="/wiki/Datei:Hamburg-logo.svg" title="Offizielles Logo der Freien und Hansestadt Hamburg"><img alt="Offizielles Logo der Freien und Hansestadt Hamburg" data-file-height="48" data-file-width="105" decoding="async" height="114" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/52/Hamburg-logo.svg/250px-Hamburg-logo.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/52/Hamburg-logo.svg/375px-Hamburg-logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/52/Hamburg-logo.svg/500px-Hamburg-logo.svg.png 2x" width="250"/></a></div></div>
# </td></tr>]]

# %%
print(rows[22].text)
# Out:
# Einwohner:
# 1.851.430 (31. März 2021)[5]

# %% [markdown]
# Eine weitere Möglichkeit, Elemente von einer Webseite zu extrahieren, sind [CSS-Selektoren](https://www.w3schools.com/cssref/css_selectors.asp). CSS-Selektoren ermöglichen die präzise Auswahl von Elementen im HTML-Code. Die Funktionen `find()` und `find_all()` unterstützen CSS-Selektoren nicht. Daher muss man in diesem Fall die Funktion `select()` von *BeautifulSoup* verwenden:

# %%
einwohner = bs.select('table.wikitable:nth-child(2) > tbody:nth-child(1) > tr:nth-child(23) > td:nth-child(2)')[0].get_text().split(' ')[0]

# %%
print(einwohner)
# Out:
# 1.851.430
